# %% [markdown]
# # LSTM - Time Series Dataset
#
# - 서울시 기후 데이터 : 2011년 1월 1일 ~ 2019년 12월 31일
# - https://data.kma.go.kr/cmmn/main/do
# - 기후통계분석 -> 기온분석 -> 기간(20110101 ~ 20191231) -> 검색 -> CSV 다운로드
# - Seoul_Temp.csv
#
# # Impot Packages
#
# - Packages

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM

# %% [markdown]
# # 1. Colab File Upload

# %% [markdown]
# > ## 1) 'Seoul_temp.csv' 파일을 Colab에 업로드 후 진행

# %%
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/Seoul_Temp.csv'
temp = pd.read_csv(url)

temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3287 non-null   object
#  1   avg     3287 non-null   float64
#  2   min     3287 non-null   float64
#  3   max     3287 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 102.8+ KB

# %%
temp.head()
# Out:
#          date  avg   min  max
# 0  2011-01-01 -6.8 -10.4 -2.9
# 1  2011-01-02 -5.4  -8.5 -1.2
# 2  2011-01-03 -4.5  -8.5 -0.3
# 3  2011-01-04 -3.9  -7.4 -1.7
# 4  2011-01-05 -4.0  -7.7 -1.8

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# > ## 1) 일일 평균온도('avg') 변화 시각화
#
# - 일일 평균온도 변화에 일정한 패턴 확인

# %%
temp_data = temp[['avg']]
plt.figure(figsize = (12, 5))
plt.plot(temp_data)
plt.show()

# %% [markdown]
# > ## 2) Normalization
#
# - tanh Activation 적용을 위해 -1 ~ 1 범위로 정규화

# %%
scaler = MinMaxScaler(feature_range = (-1, 1))
temp_data = scaler.fit_transform(temp_data)

# %% [markdown]
# > ## 3) Train vs. Test Split
#
# - Train_Dataset : 2011년 1월 1일 ~ 2017년 12월 31일
# - Test_Dataset : 2018년 1월 1일 ~ 2019년 12월 31일

# %%
train = temp_data[0 : 2557]
test = temp_data[2557 :]

# %%
train
# Out:
# array([[-0.67010309],
#        [-0.61237113],
#        [-0.57525773],
#        ...,
#        [-0.30309278],
#        [-0.33195876],
#        [-0.40206186]])

# %% [markdown]
# # 3. 시계열 데이터 처리 함수

# %% [markdown]
# > ## 1) 시계열 학습용 데이터 생성 함수 정의
#
# - X : 학습 평균온도 데이터
# - y : 정답 평균온도 데이터
# - 일정 기간의 X로 y를 예측하도록 학습

# %%
def create_dataset(time_data, look_back = 1):
    data_X, data_y = [], []

    for i in range(len(time_data) - look_back):
        data_X.append(time_data[i:(i + look_back), 0])   # i ~ look_back 날까지를 X
        data_y.append(time_data[i + look_back, 0])       # X 마지막 날의 다음날을 y

    return np.array(data_X), np.array(data_y)

# %% [markdown]
# > ## 2) look_back 기간 설정 후 학습데이터 생성
#
# - 180일 기간 평균온도로 다음날 평균온도 예측 데이터 생성

# %%
look_back = 180 

train_X, train_y = create_dataset(train, look_back)    # train을 X, y로 나눈다.  
test_X, test_y = create_dataset(test, look_back)       # test을 X, y로 나눈다. 

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180), (2377,), (550, 180), (550,))

# %%
train_y
# Out:
# array([ 0.59175258,  0.64536082,  0.62886598, ..., -0.30309278,
#        -0.33195876, -0.40206186])

# %% [markdown]
# > ## 3) Tensor Reshape

# %%
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180, 1), (2377,), (550, 180, 1), (550,))

# %% [markdown]
# # 4. LSTM Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
model = Sequential()
model.add(LSTM(64,
               input_shape = (None, 1)))
model.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# - model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                16896
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
model.compile(loss = 'mean_squared_error',
              optimizer = 'adam')

# %% [markdown]
# > ## 3) Model Fit
#
# - 약 5분

# %%
# %%time

hist = model.fit(train_X, train_y,
                 epochs = 200,
                 batch_size = 16,
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/200
# 149/149 [==============================] - 33s 13ms/step - loss: 0.0536 - val_loss: 0.0153
# Epoch 2/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0169 - val_loss: 0.0137
# Epoch 3/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0145 - val_loss: 0.0126
# Epoch 4/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0149 - val_loss: 0.0112
# Epoch 5/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 0.0106
# Epoch 6/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0114 - val_loss: 0.0091
# Epoch 7/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 8/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0103 - val_loss: 0.0079
# Epoch 9/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 0.0099
# Epoch 10/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0092 - val_loss: 0.0080
# Epoch 11/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 12/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0075
# Epoch 13/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 14/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0078
# Epoch 15/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 16/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 17/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 18/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 19/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 20/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 21/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 22/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 23/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0087
# Epoch 24/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0074
# Epoch 25/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 26/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 27/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - val_loss: 0.0073
# Epoch 28/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 29/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 30/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 31/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 32/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 33/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 34/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 35/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 36/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 37/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 38/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 39/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0073
# Epoch 40/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 41/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 42/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 43/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 44/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 45/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0073
# Epoch 46/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 47/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 48/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 49/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 50/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 51/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 52/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 53/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 54/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0072
# Epoch 55/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 56/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 57/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 58/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 59/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 60/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 61/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 62/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 63/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0072
# Epoch 64/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 65/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 66/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0072
# Epoch 67/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 68/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 69/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 70/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0072
# Epoch 71/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 72/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 73/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 74/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 75/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 76/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 77/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 78/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 79/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 80/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0073
# Epoch 81/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 82/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 83/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 84/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 85/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 86/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 87/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 88/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 89/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 90/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 91/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 92/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0077
# Epoch 93/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 0.0081
# Epoch 94/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 95/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 96/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0069 - val_loss: 0.0077
# Epoch 97/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 98/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 99/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0071 - val_loss: 0.0080
# Epoch 100/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 101/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 102/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 103/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 104/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 105/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 106/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 107/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 108/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 109/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0073 - val_loss: 0.0083
# Epoch 110/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0078
# Epoch 111/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 112/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0068 - val_loss: 0.0082
# Epoch 113/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0079
# Epoch 114/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0081
# Epoch 115/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0086
# Epoch 116/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0081
# Epoch 117/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 118/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0097 - val_loss: 0.0089
# Epoch 119/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0089 - val_loss: 0.0077
# Epoch 120/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0087 - val_loss: 0.0076
# Epoch 121/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 122/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0077
# Epoch 123/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 124/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 125/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 126/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 127/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 128/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 129/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0082 - val_loss: 0.0077
# Epoch 130/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 131/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 132/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 133/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 134/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0081 - val_loss: 0.0076
# Epoch 135/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0078
# Epoch 136/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 137/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0078
# Epoch 138/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 139/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 140/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0079
# Epoch 141/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 142/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 0.0076
# Epoch 143/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 144/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 145/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 146/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 147/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0069 - val_loss: 0.0107
# Epoch 148/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0102 - val_loss: 0.0076
# Epoch 149/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 150/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0076 - val_loss: 0.0082
# Epoch 151/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 152/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - val_loss: 0.0075
# Epoch 153/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 154/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0073 - val_loss: 0.0080
# Epoch 155/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 156/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0074 - val_loss: 0.0082
# Epoch 157/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0081
# Epoch 158/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 159/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 160/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0077 - val_loss: 0.0083
# Epoch 161/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0080
# Epoch 162/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0089
# Epoch 163/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 164/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 165/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 166/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 167/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 168/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 169/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 170/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0072 - val_loss: 0.0085
# Epoch 171/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0069 - val_loss: 0.0084
# Epoch 172/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0073 - val_loss: 0.0096
# Epoch 173/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 174/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0082
# Epoch 175/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0087
# Epoch 176/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0067 - val_loss: 0.0088
# Epoch 177/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0067 - val_loss: 0.0085
# Epoch 178/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0089
# Epoch 179/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0086
# Epoch 180/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 181/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0085
# Epoch 182/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 183/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0065 - val_loss: 0.0087
# Epoch 184/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0065 - val_loss: 0.0095
# Epoch 185/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0091
# Epoch 186/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0069 - val_loss: 0.0086
# Epoch 187/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0090
# Epoch 188/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0065 - val_loss: 0.0102
# Epoch 189/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0097
# Epoch 190/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 191/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0097
# Epoch 192/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0062 - val_loss: 0.0097
# Epoch 193/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 194/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0060 - val_loss: 0.0098
# Epoch 195/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 196/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0091
# Epoch 197/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0061 - val_loss: 0.0101
# Epoch 198/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0061 - val_loss: 0.0099
# Epoch 199/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 200/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0091
# CPU times: user 4min 37s, sys: 41.4 s, total: 5min 18s
# Wall time: 5min 29s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()
# 150회가 넘어가면서 overfitting 경향이 있다

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model.evaluate(train_X, train_y, verbose = 0)
print('Train Score : ', trainScore)

testScore = model.evaluate(test_X, test_y, verbose = 0)
print('Test Score : ', testScore)
# Out:
# Train Score :  0.0058790529146790504
# Test Score :  0.00905489269644022

# %% [markdown]
# # 5. Model Predict

# %%
look_ahead = 550

xhat = test_X[0]  # 550행
predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size = 1)  # X_test 데이터로 예측
    predictions[i] = prediction                                   # look_ahead 만큼 예측
    xhat = np.vstack([xhat[1:], prediction])

plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')  # test_y 데이터
plt.legend()
plt.show()

# %% [markdown]
# ###
# #The End
# ###
