# %% [markdown]
# # Variational AutoEncoder(VAE)
#
# - Representation Learning(표현 학습)
#    - 개념 벡터(Concept Vector) : 잠재공간(Latent Space)이나 임베딩(Embedding)이 주어지면 이 공간의 어떤 방향은 원본 데이터의 변화를 인코딩한 출일 수 있음
#    - 개념 벡터의 연산으로 변형된 이미지를 복원(Decoding)하여 생성 가능
#
# - Example
#    - 원통의 '높이'와 '너비'
#       - 높이가 낮고 너비가 넓은 원통 이미지 생성
#    - 눈의 '크기' 및 '색', 머리카락의 '길이' 및 '색'
#       - 긴 검은 머리에 갈색의 큰 눈을 가진 이미지 생성
# - Decoder(Generator)학습을 위해 Encoder 사용
#
#
# # Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Load MNIST Dataset

# %% [markdown]
# > ## 1) X_train, X_test and y_train, y_test

# %%
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# > ## 2) Normalization and Reshape

# %%
X_train = X_train / 255. # 정규화
X_test = X_test / 255.

X_train = X_train.reshape(60000, 28 * 28) # 1차원으로 핀다
X_test = X_test.reshape(10000, 28 * 28)

X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %% [markdown]
# # 2. Keras Modeling with Functional API

# %% [markdown]
# > ## 1) 'Latent Space' Point Mapping
#
# - 각 이미지가 '잠재공간(Latent Space) 포인트' 주변의 '다변수 정규 분포(Mutivariate Normal Distribution)'에 매핑

# %%
from keras.layers import Input, Dense

input_img = Input(shape = (784, ))

encoded = Dense(256, activation = 'elu')(input_img)  # Input 256 layer로 encode
encoded = Dense(128, activation = 'elu')(encoded)    # 윗 줄의 encoded를 128 layer로 encode

# %% [markdown]
# - Variational(Latent Space) Layers
#    - 평균(mean)과 분산(log_var)으로 인코딩된 잠재공간(Latent Space) 포인트 부분

# %%
mean = Dense(2, name = 'mean')(encoded)   # 앞선 데이터의 정규 분포 평균 층 2개
log_var = Dense(2, name = 'var')(encoded) # 앞선 데이터의 정규 분포 분산 층 2개

# %% [markdown]
# > ## 2) 'Latent Space' Sampling
#
# - 잠재공간(Latent Space)의 잠재공간-포인트(z) 샘플링
#    - 정규분포상에서 무작위로 선택한 'epsilon'값 사용
#       - Encoding 결과값을 그대로 사용하면 항상 같은 결과만 생성
#       - 따라서 랜덤 샘플링을 통하여 기존 Data에 존재하지 않는 새로운 Image 생성
# - Lambda( ) : 임의의 파이썬 함수 객체를 Keras Layer로 생성
# - K.exp(log_var) : 로그분산 -> 표준편차 변환

# %%
from keras import backend as K
from keras.layers import Lambda

def sampling(args):
    mean, log_var = args
    epsilon = K.random_normal(shape = (100, 2), mean = 0., stddev = 1.0)
    return mean + K.exp(log_var) * epsilon

z = Lambda(sampling, output_shape = (2,))([mean, log_var])

# %% [markdown]
# > ## 3) 'encoder' Model

# %%
from keras.models import Model

encoder = Model(input_img, mean)  # encoder 모델엔 분산 층은 포함되지 않는다.

# %% [markdown]
# - encoder Model Summary

# %%
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# mean (Dense)                 (None, 2)                 258
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 4) 'generator' Model
#
# - Decoding Layer Structure

# %%
decoder_1 = Dense(128, activation = 'elu')
decoder_2 = Dense(256, activation = 'elu')
decoder_3 = Dense(784, activation = 'sigmoid')

# %% [markdown]
# - 랜덤 샘플링 '잠재공간-포인트(z)' 재구성

# %%
z_sample = decoder_1(z)
z_sample = decoder_2(z_sample)
z_sample = decoder_3(z_sample)

# %%
z_sample.shape
# Out:
# TensorShape([100, 784])

# %% [markdown]
# - Generator Layers

# %%
decoder_input = Input(shape = (2,))

y_gen = decoder_1(decoder_input)
y_gen = decoder_2(y_gen)
y_gen = decoder_3(y_gen)

# %% [markdown]
# - Build 'generator'

# %%
generator = Model(decoder_input, y_gen)

# %% [markdown]
# - 'generator' Model Summary

# %%
generator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  384
# _________________________________________________________________
# dense_3 (Dense)              multiple                  33024
# _________________________________________________________________
# dense_4 (Dense)              multiple                  201488
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. VAE Fit

# %% [markdown]
# > ## 1) 'vae' Model Define
#
# - Build 'vae' Model
#    - End-to-End AutoEncoder

# %%
vae = Model(input_img, z_sample) # encoder모델 + generator모델

# %% [markdown]
# - 'vae' Model Summary

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          200960      input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# mean (Dense)                    (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# var (Dense)                     (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (100, 2)             0           mean[0][0]
#                                                                  var[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 multiple             384         lambda[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 multiple             33024       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 multiple             201488      dense_3[0][0]
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
from keras import objectives

reconstruction_loss = objectives.binary_crossentropy(input_img, z_sample)
kl_loss = 0.0005 * K.mean(K.square(mean) + K.exp(log_var) - log_var - 1, axis = -1)

vae_loss = reconstruction_loss + kl_loss

# %% [markdown]
# - Add vae_loss

# %%
vae.add_loss(vae_loss)

# %% [markdown]
# - Compile with vae_loss

# %%
vae.compile(optimizer = 'adam')

# %% [markdown]
# > ## 3) Model Training
#
# - 약 8분

# %%
# %%time

vae.fit(X_train,
        shuffle = True,
        epochs = 300,
        batch_size = 100,
        validation_data = (X_test, None))
# Out:
# Epoch 1/300
# 600/600 [==============================] - 4s 3ms/step - loss: 0.2718 - val_loss: 0.2163
# Epoch 2/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2155 - val_loss: 0.2084
# Epoch 3/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2057 - val_loss: 0.2011
# Epoch 4/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1998 - val_loss: 0.1969
# Epoch 5/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1952 - val_loss: 0.1937
# Epoch 6/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1920 - val_loss: 0.1902
# Epoch 7/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1890 - val_loss: 0.1878
# Epoch 8/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1872 - val_loss: 0.1865
# Epoch 9/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1856 - val_loss: 0.1849
# Epoch 10/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1836 - val_loss: 0.1843
# Epoch 11/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1824 - val_loss: 0.1831
# Epoch 12/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1818 - val_loss: 0.1822
# Epoch 13/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1808 - val_loss: 0.1817
# Epoch 14/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1807 - val_loss: 0.1808
# Epoch 15/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1792 - val_loss: 0.1809
# Epoch 16/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1797 - val_loss: 0.1799
# Epoch 17/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1787 - val_loss: 0.1798
# Epoch 18/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1783 - val_loss: 0.1795
# Epoch 19/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1777 - val_loss: 0.1796
# Epoch 20/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1773 - val_loss: 0.1789
# Epoch 21/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1773 - val_loss: 0.1785
# Epoch 22/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1763 - val_loss: 0.1787
# Epoch 23/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1762 - val_loss: 0.1784
# Epoch 24/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1756 - val_loss: 0.1779
# Epoch 25/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1755 - val_loss: 0.1775
# Epoch 26/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1747 - val_loss: 0.1775
# Epoch 27/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1751 - val_loss: 0.1776
# Epoch 28/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1748 - val_loss: 0.1766
# Epoch 29/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1751 - val_loss: 0.1768
# Epoch 30/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1740 - val_loss: 0.1767
# Epoch 31/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1745 - val_loss: 0.1763
# Epoch 32/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1737 - val_loss: 0.1770
# Epoch 33/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1739 - val_loss: 0.1765
# Epoch 34/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1730 - val_loss: 0.1761
# Epoch 35/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1730 - val_loss: 0.1758
# Epoch 36/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1727 - val_loss: 0.1770
# Epoch 37/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1728 - val_loss: 0.1761
# Epoch 38/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1728 - val_loss: 0.1762
# Epoch 39/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1727 - val_loss: 0.1761
# Epoch 40/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1718 - val_loss: 0.1757
# Epoch 41/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1726 - val_loss: 0.1753
# Epoch 42/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1717 - val_loss: 0.1756
# Epoch 43/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1722 - val_loss: 0.1755
# Epoch 44/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1718 - val_loss: 0.1755
# Epoch 45/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1718 - val_loss: 0.1763
# Epoch 46/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1714 - val_loss: 0.1753
# Epoch 47/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1715 - val_loss: 0.1750
# Epoch 48/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1709 - val_loss: 0.1753
# Epoch 49/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1714 - val_loss: 0.1751
# Epoch 50/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1709 - val_loss: 0.1751
# Epoch 51/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1712 - val_loss: 0.1753
# Epoch 52/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1710 - val_loss: 0.1748
# Epoch 53/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1705 - val_loss: 0.1748
# Epoch 54/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1707 - val_loss: 0.1752
# Epoch 55/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1705 - val_loss: 0.1748
# Epoch 56/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1699 - val_loss: 0.1747
# Epoch 57/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1707 - val_loss: 0.1743
# Epoch 58/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1701 - val_loss: 0.1744
# Epoch 59/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1700 - val_loss: 0.1747
# Epoch 60/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1703 - val_loss: 0.1744
# Epoch 61/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1699 - val_loss: 0.1752
# Epoch 62/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1698 - val_loss: 0.1744
# Epoch 63/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1699 - val_loss: 0.1744
# Epoch 64/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1699 - val_loss: 0.1743
# Epoch 65/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1696 - val_loss: 0.1744
# Epoch 66/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1698 - val_loss: 0.1745
# Epoch 67/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1694 - val_loss: 0.1753
# Epoch 68/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1691 - val_loss: 0.1744
# Epoch 69/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1691 - val_loss: 0.1743
# Epoch 70/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1695 - val_loss: 0.1745
# Epoch 71/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1695 - val_loss: 0.1745
# Epoch 72/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1695 - val_loss: 0.1743
# Epoch 73/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1690 - val_loss: 0.1741
# Epoch 74/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1690 - val_loss: 0.1747
# Epoch 75/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1692 - val_loss: 0.1746
# Epoch 76/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1692 - val_loss: 0.1743
# Epoch 77/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1684 - val_loss: 0.1741
# Epoch 78/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1685 - val_loss: 0.1742
# Epoch 79/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1685 - val_loss: 0.1745
# Epoch 80/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1687 - val_loss: 0.1742
# Epoch 81/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1685 - val_loss: 0.1747
# Epoch 82/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1683 - val_loss: 0.1748
# Epoch 83/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1687 - val_loss: 0.1742
# Epoch 84/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1682 - val_loss: 0.1742
# Epoch 85/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1683 - val_loss: 0.1748
# Epoch 86/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1683 - val_loss: 0.1745
# Epoch 87/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1681 - val_loss: 0.1740
# Epoch 88/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1686 - val_loss: 0.1746
# Epoch 89/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1682 - val_loss: 0.1740
# Epoch 90/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1680 - val_loss: 0.1741
# Epoch 91/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1680 - val_loss: 0.1746
# Epoch 92/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1679 - val_loss: 0.1742
# Epoch 93/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1681 - val_loss: 0.1743
# Epoch 94/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1681 - val_loss: 0.1743
# Epoch 95/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1674 - val_loss: 0.1738
# Epoch 96/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1676 - val_loss: 0.1740
# Epoch 97/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1679 - val_loss: 0.1737
# Epoch 98/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1677 - val_loss: 0.1737
# Epoch 99/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1681 - val_loss: 0.1746
# Epoch 100/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1675 - val_loss: 0.1741
# Epoch 101/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1677 - val_loss: 0.1739
# Epoch 102/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1675 - val_loss: 0.1738
# Epoch 103/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1677 - val_loss: 0.1738
# Epoch 104/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1676 - val_loss: 0.1740
# Epoch 105/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1669 - val_loss: 0.1739
# Epoch 106/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1671 - val_loss: 0.1737
# Epoch 107/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1673 - val_loss: 0.1740
# Epoch 108/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1676 - val_loss: 0.1740
# Epoch 109/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1669 - val_loss: 0.1750
# Epoch 110/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1674 - val_loss: 0.1740
# Epoch 111/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1668 - val_loss: 0.1740
# Epoch 112/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1673 - val_loss: 0.1740
# Epoch 113/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1670 - val_loss: 0.1738
# Epoch 114/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1669 - val_loss: 0.1744
# Epoch 115/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1672 - val_loss: 0.1741
# Epoch 116/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1673 - val_loss: 0.1738
# Epoch 117/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1670 - val_loss: 0.1736
# Epoch 118/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1671 - val_loss: 0.1740
# Epoch 119/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1668 - val_loss: 0.1741
# Epoch 120/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1667 - val_loss: 0.1738
# Epoch 121/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1667 - val_loss: 0.1736
# Epoch 122/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1668 - val_loss: 0.1736
# Epoch 123/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1668 - val_loss: 0.1740
# Epoch 124/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1665 - val_loss: 0.1742
# Epoch 125/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1664 - val_loss: 0.1746
# Epoch 126/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1664 - val_loss: 0.1739
# Epoch 127/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1667 - val_loss: 0.1738
# Epoch 128/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1662 - val_loss: 0.1737
# Epoch 129/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1662 - val_loss: 0.1740
# Epoch 130/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1666 - val_loss: 0.1742
# Epoch 131/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1665 - val_loss: 0.1744
# Epoch 132/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1665 - val_loss: 0.1738
# Epoch 133/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1742
# Epoch 134/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1737
# Epoch 135/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1740
# Epoch 136/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1662 - val_loss: 0.1742
# Epoch 137/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1738
# Epoch 138/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1664 - val_loss: 0.1742
# Epoch 139/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1742
# Epoch 140/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1661 - val_loss: 0.1742
# Epoch 141/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1663 - val_loss: 0.1743
# Epoch 142/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1661 - val_loss: 0.1744
# Epoch 143/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1663 - val_loss: 0.1738
# Epoch 144/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1748
# Epoch 145/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1661 - val_loss: 0.1739
# Epoch 146/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1737
# Epoch 147/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1659 - val_loss: 0.1749
# Epoch 148/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1659 - val_loss: 0.1746
# Epoch 149/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1657 - val_loss: 0.1744
# Epoch 150/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1746
# Epoch 151/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1741
# Epoch 152/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1659 - val_loss: 0.1746
# Epoch 153/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1652 - val_loss: 0.1744
# Epoch 154/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1743
# Epoch 155/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1654 - val_loss: 0.1738
# Epoch 156/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1743
# Epoch 157/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1741
# Epoch 158/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1657 - val_loss: 0.1742
# Epoch 159/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1743
# Epoch 160/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1658 - val_loss: 0.1740
# Epoch 161/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1654 - val_loss: 0.1742
# Epoch 162/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1653 - val_loss: 0.1740
# Epoch 163/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1649 - val_loss: 0.1743
# Epoch 164/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1655 - val_loss: 0.1750
# Epoch 165/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1654 - val_loss: 0.1749
# Epoch 166/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1744
# Epoch 167/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1660 - val_loss: 0.1744
# Epoch 168/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1657 - val_loss: 0.1744
# Epoch 169/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1745
# Epoch 170/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1652 - val_loss: 0.1746
# Epoch 171/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1652 - val_loss: 0.1741
# Epoch 172/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1749
# Epoch 173/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1652 - val_loss: 0.1742
# Epoch 174/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1653 - val_loss: 0.1742
# Epoch 175/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1656 - val_loss: 0.1751
# Epoch 176/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1654 - val_loss: 0.1741
# Epoch 177/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1654 - val_loss: 0.1739
# Epoch 178/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1651 - val_loss: 0.1746
# Epoch 179/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1652 - val_loss: 0.1739
# Epoch 180/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1650 - val_loss: 0.1743
# Epoch 181/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1742
# Epoch 182/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1741
# Epoch 183/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1741
# Epoch 184/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1743
# Epoch 185/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1655 - val_loss: 0.1746
# Epoch 186/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1747
# Epoch 187/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1746
# Epoch 188/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1746
# Epoch 189/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1651 - val_loss: 0.1746
# Epoch 190/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1753
# Epoch 191/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1649 - val_loss: 0.1746
# Epoch 192/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1649 - val_loss: 0.1754
# Epoch 193/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1749
# Epoch 194/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1651 - val_loss: 0.1746
# Epoch 195/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1650 - val_loss: 0.1745
# Epoch 196/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1745
# Epoch 197/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1650 - val_loss: 0.1744
# Epoch 198/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1749
# Epoch 199/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1644 - val_loss: 0.1742
# Epoch 200/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1641 - val_loss: 0.1749
# Epoch 201/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1742
# Epoch 202/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1645 - val_loss: 0.1749
# Epoch 203/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1748
# Epoch 204/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1642 - val_loss: 0.1753
# Epoch 205/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1644 - val_loss: 0.1746
# Epoch 206/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1751
# Epoch 207/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1756
# Epoch 208/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1645 - val_loss: 0.1748
# Epoch 209/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1743
# Epoch 210/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1648 - val_loss: 0.1748
# Epoch 211/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1650 - val_loss: 0.1747
# Epoch 212/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1745
# Epoch 213/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1644 - val_loss: 0.1746
# Epoch 214/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1645 - val_loss: 0.1750
# Epoch 215/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1746
# Epoch 216/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1644 - val_loss: 0.1749
# Epoch 217/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1641 - val_loss: 0.1745
# Epoch 218/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1749
# Epoch 219/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1647 - val_loss: 0.1746
# Epoch 220/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1747
# Epoch 221/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1645 - val_loss: 0.1754
# Epoch 222/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1755
# Epoch 223/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1646 - val_loss: 0.1753
# Epoch 224/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1641 - val_loss: 0.1754
# Epoch 225/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1642 - val_loss: 0.1752
# Epoch 226/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1752
# Epoch 227/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1642 - val_loss: 0.1748
# Epoch 228/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1639 - val_loss: 0.1751
# Epoch 229/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1746
# Epoch 230/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1748
# Epoch 231/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1752
# Epoch 232/300
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1639 - val_loss: 0.1751
# Epoch 233/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1642 - val_loss: 0.1754
# Epoch 234/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1749
# Epoch 235/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1753
# Epoch 236/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1753
# Epoch 237/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1752
# Epoch 238/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1751
# Epoch 239/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1751
# Epoch 240/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1639 - val_loss: 0.1754
# Epoch 241/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1749
# Epoch 242/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1749
# Epoch 243/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1747
# Epoch 244/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1749
# Epoch 245/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1749
# Epoch 246/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1750
# Epoch 247/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1748
# Epoch 248/300
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1636 - val_loss: 0.1750
# Epoch 249/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1751
# Epoch 250/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1753
# Epoch 251/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1634 - val_loss: 0.1751
# Epoch 252/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1753
# Epoch 253/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1755
# Epoch 254/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1634 - val_loss: 0.1756
# Epoch 255/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1753
# Epoch 256/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1752
# Epoch 257/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1754
# Epoch 258/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1752
# Epoch 259/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1756
# Epoch 260/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1752
# Epoch 261/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1761
# Epoch 262/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1757
# Epoch 263/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1639 - val_loss: 0.1757
# Epoch 264/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1752
# Epoch 265/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1756
# Epoch 266/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1634 - val_loss: 0.1752
# Epoch 267/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1753
# Epoch 268/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1640 - val_loss: 0.1759
# Epoch 269/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1755
# Epoch 270/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1753
# Epoch 271/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1757
# Epoch 272/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1755
# Epoch 273/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1638 - val_loss: 0.1753
# Epoch 274/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1630 - val_loss: 0.1757
# Epoch 275/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1631 - val_loss: 0.1757
# Epoch 276/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1634 - val_loss: 0.1756
# Epoch 277/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1755
# Epoch 278/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1756
# Epoch 279/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1628 - val_loss: 0.1759
# Epoch 280/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1631 - val_loss: 0.1760
# Epoch 281/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1757
# Epoch 282/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1759
# Epoch 283/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1759
# Epoch 284/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1636 - val_loss: 0.1757
# Epoch 285/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1634 - val_loss: 0.1757
# Epoch 286/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1630 - val_loss: 0.1758
# Epoch 287/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1754
# Epoch 288/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1757
# Epoch 289/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1632 - val_loss: 0.1759
# Epoch 290/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1628 - val_loss: 0.1758
# Epoch 291/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1629 - val_loss: 0.1756
# Epoch 292/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1629 - val_loss: 0.1765
# Epoch 293/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1635 - val_loss: 0.1756
# Epoch 294/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1637 - val_loss: 0.1758
# Epoch 295/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1628 - val_loss: 0.1754
# Epoch 296/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1630 - val_loss: 0.1756
# Epoch 297/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1630 - val_loss: 0.1760
# Epoch 298/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1628 - val_loss: 0.1757
# Epoch 299/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1629 - val_loss: 0.1762
# Epoch 300/300
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1633 - val_loss: 0.1760
# CPU times: user 8min 19s, sys: 39.6 s, total: 8min 58s
# Wall time: 7min 12s

# %% [markdown]
# # 4. 'Latent Space' Visualization

# %% [markdown]
# > ## 1) Classes in the Latent Space

# %%
X_test_latent = encoder.predict(X_test, batch_size = 100)

plt.figure(figsize = (12, 10))
plt.scatter(X_test_latent[:, 0], X_test_latent[:, 1], c = y_test)
plt.colorbar()
plt.show()

# %% [markdown]
# > ## 2) Display 2D Manifold(20 * 20)

# %%
from scipy.stats import norm

n = 20
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit
plt.figure(figsize = (10, 10))
plt.imshow(figure, cmap = 'Greys_r')
plt.show()

# %% [markdown]
# # 5. 'generator' Test

# %% [markdown]
# > ## 1) 'encoder' Test (784 -> 2)

# %%
encoded_latent = encoder.predict(X_test)
encoded_latent.shape
# Out:
# (10000, 2)

# %% [markdown]
# > ## 2) 'generator' Test (2 -> 784)

# %%
generated_imgs = generator.predict(encoded_latent)
generated_imgs.shape
# Out:
# (10000, 784)

# %% [markdown]
# > ## 3) Generating Visualization
#
# - 복원이 아닌 생성된 이미지들

# %%
n = 10 

plt.figure(figsize = (20, 4))
for i in range(n):
    
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(generated_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ###
# # The End
# ###
