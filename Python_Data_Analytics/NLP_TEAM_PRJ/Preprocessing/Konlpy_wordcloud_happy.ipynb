# %% [markdown]
# # Konlpy를 활용한 단어빈도분석 및 Wordcloud

# %% [markdown]
# > ## 1) 한글 폰트 설치

# %% [markdown]
# - 나눔폰트 설치

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %% [markdown]
# - 설치 확인

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()

[f for f in sys_font if 'Nanum' in f]
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumBarunGothicLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBrush.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunpenR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumPen.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunpenB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareEB.ttf']

# %%
import matplotlib.pyplot as plt

path = '/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
fm._rebuild()
# Out:
# NanumGothic

# %% [markdown]
# - 적용됐는지 확인

# %%
plt.title('안녕')

# 오류가 안뜨는걸로 봐서 적용은 된 것 같은데... 이상하다 뭐지
# 런타임 다시 시작해주니까 됐다

# 맨 처음 설치 후 런타임을 다시 시작해주어야 적용이 되는 듯
# Out:
# Text(0.5, 1.0, '안녕')

# %% [markdown]
# > ## 2) Konlpy와 wordcloud 설치

# %% [markdown]
# - konlpy, wordcloud 설치

# %%
# !pip install konlpy wordcloud
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.4MB/s
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.4MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/cd/a5/9781e2ef4ca92d09912c4794642c1653aea7607f473e156cf4d423a881a1/JPype1-1.2.1-cp37-cp37m-manylinux2010_x86_64.whl (457kB)
#      |████████████████████████████████| 460kB 47.5MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: beautifulsoup4, colorama, JPype1, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.2.1 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %% [markdown]
# - 텍스트파일 불러오기
#   - one_off_conversation_happy_for_konlpy.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/one_off_conversation_happy_for_konlpy.txt'
# Out:
# -rw------- 1 root root 307319 Apr 12 01:43 '/content/drive/My Drive/Colab Notebooks/datasets/one_off_conversation_happy_for_konlpy.txt'

# %%
from konlpy.tag import Twitter
from collections import Counter

# %%
# 왼쪽 파일에 텍스트 파일 올려 놓고 불러올 수 있다.
file = open('one_off_conversation_happy_for_konlpy.txt','r')

lists = file.readlines()

file.close()

lists
# Out:
# ['오라버니 해피투게더 봤어요\n',
#  '우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다\n',
#  '웃긴 거 알죠\n',
#  '덕분에 주방에서 요리하는 게 엄청 좋아졌어요\n',
#  '마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다\n',
#  '어떻게 여성 요리사보다 더 인기가 많으신지 저도 늘 반찬 만들 때 따라 하고 있답니다\n',
#  '우리에게 맛있는 음식을 전하시는 맥주 부님 당신 멋져\n',
#  '활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러브\n',
#  '그리고 100일도 축하해요\n',
#  '응원합니다 그리고 사랑합니다 파이팅\n',
#  '형님이 올해 우리 팀으로 온다고 해서 얼마나 기뻤는지 몰라요\n',
#  '예 500일 축하해요\n',
#  '생일 진심으로 축하해요\n',
#  '축하\n',
#  '요리가 차암쉽쥬\n',
#  '10년 뒤 손 편지 쓰고 꼭 이 감회도 갈게요\n',
#  '요리의 매력에 빠졌어요\n',
#  '300일 너무너무 축하해요\n',
#  '항상 밝은 에너지 덕분에 힘이 납니다\n',
#  '대단하신 우리 선생님 파이팅요\n',
#  '파이팅\n',
#  '제일처럼 기쁘고 좋은데\n',
#  '생일 축하해요\n',
#  '덕분에 요리가 즐거워요\n',
#  '800일 축하해요\n',
#  '이런 오늘 신문을 보니 엘지가 올 시즌을 포기한다고 나왔더라고요\n',
#  '내일 생일이라 한번 가보려고요\n',
#  '너무너무 좋아요\n',
#  '역시 프로입니다\n',
#  '1위 한 것 너무 축하해요♡\n',
#  '앞으로 언제나 함께 있을게요\n',
#  '건강한 하루요\n',
#  '하루에 2만 명 넘고 너무 좋겠네요\n',
#  '7500일 축하해요\n',
#  '축하드려요\n',
#  '그게 훨씬 귀엽고 더 어려 보여요 진짜\n',
#  '정말 행복해요\n',
#  '딸 바보 되시겠네요\n',
#  '파이팅\n',
#  '파이팅\n',
#  '항상 좋은 일 있길 바랄게요\n',
#  '오빠의 유쾌한 웃음소리가 들리는듯하네요\n',
#  '선수 파이팅\n',
#  '매번 좋은 정보감사합니다\n',
#  '오늘 이 600일이 되는 날이에요♡♡\n',
#  '오늘이 바로 세븐틴 700일이 되는 날이에요\n',
#  '대상 수상 축하해요\n',
#  '생일 진심 축하드려요\n',
#  '세븐틴 예쁘다\n',
#  '무한도전에서 연기 너무 잘 하셨어요\n',
#  '자랑스럽네요\n',
#  '응원할게요\n',
#  '요즘 대세시죠\n',
#  '울 오빠는 일 등 신랑감\n',
#  '꼭 봤으면 하는 영화 1위\n',
#  '님을 보고 요리에 대해 관심이 생겼어요\n',
#  '오빠 생일 축하해요\n',
#  '일과처럼 들어오는 카페가 되었네요\n',
#  '나이에 상관없이 진짜 열심히 뛰어주는 우리 아저씨 파이팅입니다\n',
#  '오늘 콘서트 했는데 다치지 말고 숙소 잘 들어가요\n',
#  '날씨는 춥고 행복한 일도 없지만 그래도 우리 모두 파이팅입니다\n',
#  '님 응원도 하고요\n',
#  '나도 외국에서 응원할게\n',
#  '게다가 위트도 있으시고 편안한 인상 너무 좋습니다\n',
#  '형님의 생일을 진심으로 축하축하합니다\n',
#  '팬클럽 창단식 해요\n',
#  '어색하면서도 건방지지만 병풍 같은 형님 정말 축하드립니다\n',
#  '이번에 1루수로 기용하신 것 너무 잘하셨네요\n',
#  '너무 반갑습니다\n',
#  '움직이는 물체를 100 잡아내니 야간에 가게에 혼자 있어서 무섭지가 않아요\n',
#  '일단 다른 말이 필요 없을 듯님 수고하셨습니다\n',
#  '기분 좋은 맘으로 요리를 하면 맛도 업\n',
#  '오빠가 선수의 위치에서 떠나는 그날까지\n',
#  '늘 웃음을 주는 님 생일을 진심으로 축하합니다\n',
#  '마음도 넓고 굳세니 잘할 거임\n',
#  '벌써 9월 5일이라는 시간이 다가왔네요\n',
#  '오늘 하루도 수고하셨어요\n',
#  '다른 사람들이 오빠 보고 다진 상이라고 해도 전 오빠를 좋아할 거예요\n',
#  '그럼 오빠 오늘 하루도행쇼\n',
#  '누나 생일 축하드려요\n',
#  '항상 응원합니다\n',
#  '내일과 또 제가 가는 내일모레 팬미팅도 멤버들과 함께 즐거운 추억 많이 만들어요\n',
#  '전개 인적으로 수록곡 중에 웃음꽃이라는 노래가 참 좋은데 오늘 뮤직뱅크에서 이렇게 들으니까 또 기분이 새롭네요\n',
#  '세븐틴 보컬팀 리더 천재 작곡가 생일 축하해요\n',
#  '파이팅 선수 항상 당신을 응원합니다\n',
#  '요즘 부쩍\n',
#  '진짜 많이 기다렸던 공개 카페가 드디어 열렸어요\n',
#  '카페에서 몇 번 뵈었죠\n',
#  '형님이 열애설이 진짜라면 축하드리고요\n',
#  '오빠들 덕에 재미있는 크리스마스이브가 이렇게 마무리돼서 기쁘고 오빠들도 메리 크리스마스\n',
#  '오늘은 무한도전하는 날\n',
#  '2016년 마무리 이쁘게 하고 2017년은 또 새롭게 같이 시작해봐요\n',
#  '음식도 웃으면서 기분 좋게 만들어야 더 맛있죠\n',
#  '같이 가요\n',
#  '님 멋지세요\n',
#  '정말 재미있어요\n',
#  '저도 오빠 무지 좋아해요\n',
#  '우하하하 하하하 그럼\n',
#  '본인이 만족하고 행복해하니 팬 입장으로서도 뿌듯하네요\n',
#  '정말 멋졌어요\n',
#  '태어나 줘서 너무 고맙고 세븐틴이어서 너무 고마워요\n',
#  '너무도 이쁘고 멋진 미소이심\n',
#  '다음 시즌 때는 도시락 싸 들고 응원 갈게요\n',
#  '파이팅 대한민국 만세\n',
#  '요즘은 스포츠 뉴스를 보면 너무 기분 좋은 거 있죠\n',
#  '최우수 상은커녕 우수상도 못 받으셔서 mbc 뭐 이런 데가 다 있나 했더니 대상을 받으실 줄이야\n',
#  '다시 한번 생일 축하하고\n',
#  '신바람 나는 LG\n',
#  '400일 정말 축하해\n',
#  '하지만 괜찮아요\n',
#  '정말 진심으로 축하드려요\n',
#  '그리고 밸런타인데이♡\n',
#  '노래 정말 좋고 수고했어요\n',
#  '암튼 올 시즌 첫 홈런 축하드립니다\n',
#  '다음 시즌 땐 고\n',
#  '게다가 곧 있으면 생일\n',
#  '우히히 어제 무한도전 너무 재밌게 봤어요\n',
#  '내일 시험 끝나니까 내일 편지는 더 길게 쓸게요\n',
#  '그리고 열심히 노래 들어서 꼭 1등 시켜줄게요\n',
#  '홍홍홍 홍왜 이렇게 잘 생겨졌냐면서\n',
#  '아쉽지만 축하해요\n',
#  '하하하 결혼도 축하하고요\n',
#  '안녕 오늘 더쇼 1위 진짜 진짜 축하하고\n',
#  '생일 축하해요\n',
#  '1시간 동안 재밌게 잘 볼게요\n',
#  '오빠 생일 축하해요\n',
#  '잊지 못할 크리스마스 선물 줘서 진짜 고맙고 앞으로도 절대 잊지 못할 것 같아요\n',
#  '이제 확실히 폼 떨어진 줄 알았더니 귀신같이 다시 골 머신 됨\n',
#  '기자 싱글벙글 곧 댓글 1500개\n',
#  '유명 짤 하나 탄생했네\n',
#  '역시\n',
#  '축하합니다 행복하세요\n',
#  '나이스 4명 깔았다\n',
#  '이 젊은이들이 있기에 아직은 희망을 가져봅니다\n',
#  '엘지 져서 기분 좋은 사람\n',
#  '파이팅\n',
#  '덕분에 너무 재미있었음\n',
#  '오늘 촬영하는 거 봤는데 존 나 잘생김\n',
#  '봐라 얼마나 억울하냐\n',
#  '또 이걸 해냅니다\n',
#  '축하해요\n',
#  '올해는 케 베스의 하였네 누굴 줘도 이상하지 않아다 인정이야\n',
#  '캬 장관이고 자연의 아름다움이 느껴지네\n',
#  '이제 시작이다\n',
#  '오 엠비시 자네 왔는가\n',
#  '연예인들 전부 이러면 악플러들 많이 사라질 텐데 잘했다\n',
#  '기상캐스터 머리 보니 날씨 짐작이 갑니다\n',
#  '여기 댓글도 아주 난리 났네 대박 나자\n',
#  '인물도 곱고 맘씨도 아름다워라♡♡♡\n',
#  '최고\n',
#  '너 진짜 웃겨 인정 이제야 재능을 살리는 듯\n',
#  '진짜 이쁘다\n',
#  '노래는 지금 들어도 정말 좋은데 다시 재결합을 한다니까 너무 기대되네요\n',
#  '잘 되어서 기분 좋네\n',
#  '너무 귀엽고 웃김\n',
#  '결혼하고 싶어요\n',
#  '어머님들 표정이 진짜 재밌었음 진짜 리얼 표정\n',
#  '오락가락이 붙었다\n',
#  '우리나라는 양호한 거네 위로가 된다\n',
#  '이런 저질 프로가 폐지되어서 정말 행복합니다 대한민국 만세\n',
#  '진짜 고생했다 받을만했음\n',
#  '정말 대단하고 멋지십니다\n',
#  '후반에 중앙이 동이 신의 한 수였다\n',
#  '나도 친구분처럼 가장 웃기다고 생각했었는데 지금은 정말 멋있는 개그맨이 된 듯\n',
#  '삼촌 축하해요♡\n',
#  '아는 형님 진짜 개 재밌음\n',
#  '언제 봐도 늘 멋져요♡\n',
#  '경기가 기대된다\n',
#  '18년 뒤면 그래도 살아 잇네 다행\n',
#  '힘내세요\n',
#  '내 고향 울진\n',
#  '더울 땐 사무실이 짱\n',
#  '흥해라\n',
#  '풍악을 울려라\n',
#  '오호호호 내일 하는군요\n',
#  '파이팅\n',
#  '축하합니다\n',
#  '요즘 배우 참 이쁘던데\n',
#  '신범죄 구단 엔씨 축하한다\n',
#  '정말 국내에선 톱타자보다 못했으나 국제경기에 가면 상당히 강했나 보네 내년 시즌 기대해도 좋다\n',
#  '미안하다 우리가 승리다\n',
#  '연기 너무 잘하셔서 호감\n',
#  '연기는 연기고 사생활은 사생활일 뿐 축하\n',
#  '오 드디어 열 일하는\n',
#  '축하드려요\n',
#  '대전 날씨 매우 맑음\n',
#  '똑똑하다 그랬는데\n',
#  '기부천사\n',
#  '어제 너무 재밌게 봤어요 오늘도 기대합니다\n',
#  '머 머리 아재들 희소식 노벨상감\n',
#  '파이팅\n',
#  '연기 너무 잘해요\n',
#  '조기에 빠른 대처를 하신 기장 및 승무원 그리고 지시에 따라주신 승객까지 모두 잘하셨습니다\n',
#  '오늘 지렸다\n',
#  '보면서 너무 흐뭇함\n',
#  '너무 잘하는 데 더 더 잘 되라\n',
#  '축하드려요\n',
#  '흥해라 흥해라\n',
#  '오늘 12시에 음원 나와요 많이 들어주세요\n',
#  '좋아요 맨날 들어야지 힘\n',
#  '멋지다 추진력\n',
#  '수술 찬성할 때 정말 리액션 귀여웠음\n',
#  '얼굴부터 마음까지 예쁜 우리 언니 응원할게요\n',
#  '연말에 배우 볼 수 있다 좋다\n',
#  '기아가 영입할 듯 35년 기아 팬이\n',
#  '대상 축하드립니다\n',
#  '무한상사 야유회 때 정말 웃겼는데 아쉽네요\n',
#  '이 나이에 이 정도 활약하는 거 보면 전성기 때 epl 갔으면 씹어 먹었을 듯\n',
#  '난 코빅에서부터 좋았어 이대로 고정까지 가라근데 안티가 별로 없네 머리 스타일이 초딩 같음까 불까 불한 초딩\n',
#  '나이스 샷\n',
#  '이태원 바에서 봤는데 성격 엄청 좋아 보임 물론 얼굴도 예쁨행쇼\n',
#  '공민왕 후손인가\n',
#  '연기 인정하죠 매력적이고\n',
#  '너무도 착하고 천사 같은 파이팅\n',
#  '좋은 관계 잘 유지하세요 결혼까지 가면 좋지만\n',
#  '차우찬 가지고 지레 발은 좀 너무하지 않냐\n',
#  '어딜 가나 박자 놓치는 고문관 한 둘은 나오는데 오늘 집회 촛불 소 등 완벽했음\n',
#  '물들어오니까 제트엔진 달았네\n',
#  '여전히 두산이 최강이네 이리 보고 저리 봐도 4명이 다 잘해\n',
#  '핸드폰인 증보다 아이 핀 인증이 아주 조금 더 편하더라\n',
#  '임신이면 누가 뭐라 하냐 둘 다 성인인데 축하할 일이지\n',
#  '아직도 안 믿기지만 항상 응원할게♡♡♡\n',
#  '연기 너무 잘해요 너무 보고 싶어요\n',
#  '수상 축하드립니다\n',
#  '기대기대 믿고 봅니다♡\n',
#  '앞으로 많이 행복하자\n',
#  '특검 잘하고 있다\n',
#  '기아가 승리한다\n',
#  '멋지다 파이팅 오래 살아라\n',
#  '오늘도 남의 불행에 저절로 웃음이 나옵니다\n',
#  '저거다 저게 바로 내가 기다리던 내 햄버거야\n',
#  '이쁘다 잘 되어서 흥하길\n',
#  '이거 보면 진짜 자기관리가 대단하다 최고의 선수다움\n',
#  '추워서 좋다\n',
#  '축하해 ♡ ♡♡\n',
#  '이 기사 개 꿀 잼\n',
#  '졸아웃긴다 주사\n',
#  '어려워지기 전에 기능통과하고 쉬워진 도로 주행 통과 후진 따위 안하고 통과앙 개꿀띠\n',
#  '너무 몰입되어서 오랜만에 좋은 드라마 봅니다 연기를 너무 잘하세요\n',
#  '노래가 좋아\n',
#  '멋진\n',
#  '6만 원짜리 중고자전거 사서 3달째 출퇴근하는데 배도 들어가고 자전거 값은 뽑음\n',
#  '너무 신선하고 재밌어서\n',
#  '배우 응원하고 기대합니다\n',
#  '진짜 골키퍼 하드 케리로 승점 5점 땄네\n',
#  '우리 집은 xp 아직도 잘 쓰는 중 사이트 안되는 건 크롬 써서 하고\n',
#  '봐라 결국 돌아오잖니\n',
#  '감사합니다\n',
#  '무조건 1번을 외치던 우리 아버지도 이제 슬슬 욕하기 시작\n',
#  '폭스바겐 같은 삼류 기업이랑은 as나 서비스의 질이 틀리구먼 허허\n',
#  '무조건 본다 파이팅\n',
#  '예전에 술 마시고 냉장고에 볼 일본 사연 웃겼는데\n',
#  '대 놓고 ppl이 어색하지 않은 이상한 드라마\n',
#  '축하해요 언니\n',
#  '응원합니다 꼭 대상 받으시길\n',
#  '첼시가 이길 텐데\n',
#  '믿고 보는 감독님 빨리 보고 싶다\n',
#  '기대기 대왕 기대\n',
#  '역시 실력자들\n',
#  '오랜만에 시원하다\n',
#  '완전 귀요미\n',
#  '무도는 레전드만 내보내도 6개월은 때울 수 있음\n',
#  '멋져 멋져다 멋져\n',
#  '멋지다 금메달감이다\n',
#  '악마의 연기 선곡은 진짜 신의 한 수 중간에 흉내 내는 건 진짜\n',
#  '구속 안 된 게 내가 기분이 좋네\n',
#  '더더더 흥해라\n',
#  '축하드려 요♡♡\n',
#  '사이다다\n',
#  '속이 다시 원합니다\n',
#  '기자님 예쁘세요\n',
#  '역시 알아서 잘해주네요 쭉쭉 갑시다\n',
#  '티베트 가기 편하겠네\n',
#  '오 그렇네 재밌었던 영화\n',
#  '막내야 돌아와서 반가웠어 앞으로 더 분발하자\n',
#  '날씨 좋다\n',
#  '파이팅 항상 응원할게요\n',
#  '기사를 잘 쓰시네요 본방사수\n',
#  '역시 명불허 전 박효갓\n',
#  '족발 예약한 시간 됐구나\n',
#  '재미나겠어요 파이팅\n',
#  '진짜 눈 깜빡이는 시간도 아까운 드라마\n',
#  '나오니 더욱 재미나겠네요 기다려집니다\n',
#  '회복하셨다니 다행입니다 응원합니다\n',
#  '믿고 보는 배우 본방사수\n',
#  '비가 촉촉이 와서 좋네요\n',
#  '프로야구 발전을 위해서 1라운드만 하기로 했습니다\n',
#  '잘생겼다 귀엽고 섹시하고 매력이 많아\n',
#  '대단하다 대단해\n',
#  '크면 좋은 것이다 아빠를 자랑스럽게 생각할 수 있어\n',
#  '진짜 재밌었다 마지막까지\n',
#  '삿포로 맥주 너무 맛있다\n',
#  '축하한 다축 하한 다 멋지다 멋지다\n',
#  '안 본 사이더 예뻐지셨어요\n',
#  '여태 본 의학드라마 중 단연 최고\n',
#  '미쳐 활동 때 배추 머리는 대박 카리스마개 쩔어\n',
#  '대박 못하는 게 뭐예요\n',
#  '돌아가면서 뽀뽀해주고 싶다♡\n',
#  '콜라도 마셔보고 저 영감 땡잡았네\n',
#  '홈런에 무너져버렸네 엔씨 축하드려요\n',
#  '엘지 파이팅입니다\n',
#  '저희도 형님 오실 때마다 반갑고 좋습니다\n',
#  '라이브 듣고 완전 소름 기대된다\n',
#  '예능이 무한도전이 전과 이후로 나뉘듯 드라마도 도깨비 이전과 이후로 나뉠 듯 정말 기똥찬 드라마나 왔네요\n',
#  '노래는 시바가 훨씬 좋다 그리고 귀엽고 좋다 활동을 몇 번만 더하면 역주행한다\n',
#  'X 맨 부활인가요\n',
#  '존재감 쩔었음\n',
#  '진심으로 축하드려요 대박 나세요\n',
#  '야식은 치킨이 진리 군\n',
#  '정말 웃김 재밌어 스트레스 빵\n',
#  '두 분 축하드려요 나도 결혼하고 싶다\n',
#  '축구 잘 해\n',
#  '날씨 관심 없고 기상캐스터 보러 온 당데헿\n',
#  '항상 행복하세요 좋은 곡으로 만나요\n',
#  '우연적으로 파여진 흔적 가지고 망상이 심한 사람들 보면 참개울가에 굴러다니는 돌도 잘 찾아보슈재미난 모양 많수다\n',
#  '도전한 자는 멋지다\n',
#  '난 남잔데 멋진 모습 보는 게 더 좋더라 암 낫게 이\n',
#  '한화에서 유일하게 관리받는 분\n',
#  '신선하다 그리고 지루하지 않아보면서 힐링이 되는 기분이다\n',
#  '나라를 구한다는 게 이런 거지\n',
#  '아 막판에 ses 콘셉트 콘서트 보고 배꼽 빠지는 줄\n',
#  '둘 다 잘생겼으니까 인기 있지\n',
#  '지금 생각하면 유익한 프로그램이었던 듯\n',
#  '드라마화가 뭐 나귀가 좀 특별나게 재밌었지만 이것도 좀 재밌어요\n',
#  '이렇다 저렇다 기자들의 말이 많지만 무한도전 특유의 재미가 있으니 그냥 믿고 봅니다\n',
#  '우리 변호사님 최고라지요\n',
#  '난 일단 비주얼 최고인\n',
#  '기사에 임신으로 두 배의 기쁨이라니\n',
#  '누가 봐도 아버지와 딸인데\n',
#  '미세먼지에 시달리다 보니 장맛비 소식이 이렇게 반갑네요\n',
#  '하면서 비교하면서 재밌었는데\n',
#  '기도하는 입보다 돕는 손이 더 이쁘다\n',
#  '보면 떠올라\n',
#  '너무 예쁘고 사랑스러워요\n',
#  '몰랐는데 훤칠하고 멋있음\n',
#  '진심으로 축하해요\n',
#  '토트넘의 승리\n',
#  '요즘 최고 재미나도 노래도 멋졌음\n',
#  '기사 볼 때마다 그냥 흐뭇하다\n',
#  '앞으로도 아이들의 건강한 웃음을 기대하겠습니다\n',
#  '기부를 하는 본인이 더 행복하고 마음이 따뜻해진다는 걸\n',
#  '와 축하축하 작가 감독 배우다들 덕분에 드라마 잘 보고 있어요\n',
#  '누나 예뻐요\n',
#  '그동안 수고 많으셨습니다\n',
#  '유용한 정보인듯합니다\n',
#  '찬성하는 정책이다\n',
#  '어제 나올 때마다 웃은 듯\n',
#  '금연한 돈으로 기부까지\n',
#  '웬만하면 글 안 남기는데 정말 대단하세요♡\n',
#  '멀리서나마 응원하고 있어요\n',
#  '축하드립니다\n',
#  '진짜 둘 보면 저절로 엄마 미소가 지어진다\n',
#  '그래도 이제 밤엔 시원해서 좋아요\n',
#  '근데 피디는 개 웃기다\n',
#  '참 괜찮네\n',
#  '재미있을 듯 파이팅\n',
#  '시체 팔이 실패 개꿀 잼\n',
#  '남자 크루 같았으면 snl 폐지하자고 난리 블루스를 쳤을 텐데\n',
#  '어제 재밌게 봤는데\n',
#  '제가 하고 싶었던 걸 해주시니 가슴이 뻥 뚫리는 기분이네요\n',
#  '노래도 좋은데\n',
#  '특검 확고한 의지가 엿보이네\n',
#  '신곡 반갑네요\n',
#  '꿀이로 구나 둘이 붙어 있는 씬케미 최고\n',
#  '솔직히 안 오니까 좋기만 하다\n',
#  '난 달이랑 태양 보고 지구가 둥근 줄 알았다\n',
#  '아수라가 생각보다 재미가 없었고 러키가 생각보다 너무 재밌어서 입소문으로 대박 난\n',
#  '진짜 존 멋개멋\n',
#  '솔직히 기분 좋다\n',
#  '난무도 만의 콩트 되게 좋아요\n',
#  '축하드려요\n',
#  '여성분들 시청률이 꽤 놓은데 역사를 알고 보는 입장에서 너무 흥미진진합니다\n',
#  '넘어지는 장면은 진짜 혼자 시트콤 찍는 줄\n',
#  '기대보다 빨리 실현되어 너무나 행복하네요\n',
#  '보수의 해체를 축하한다\n',
#  '여름은 끝자락에 시원하고 만\n',
#  '올해 한번 일 내보자 감독님 한화이글스 파이팅\n',
#  '그 와중에 던파는 재밌더라\n',
#  '앗싸꽃 피는 춘삼월 좋은 소식 대한민국 방방곡곡 울려 퍼지겠네\n',
#  '앞으로도 좋은 배우가 되었으면 좋겠다\n',
#  '얼마나 꿈같을까 짝짝짝\n',
#  '님이 진짜 좋아하심\n',
#  '넥센 파이팅\n',
#  '저희 집도 아이들과 소 등 했어요\n',
#  '좋음\n',
#  '새로운 역사의 시작을 준비해주세요\n',
#  '아기들 다행이다\n',
#  '그래 하나 줘야지 축하합니다\n',
#  '그냥 감동이네요\n',
#  '너무나 재미있음\n',
#  '어머님 너무 재미나요\n',
#  '파이팅♡\n',
#  '첫 등장할 때 너무 예뻤음\n',
#  '대상 축하드려요\n',
#  '멋지고 자랑스러운 우리 국민\n',
#  '누나는 식빵 구울 때가 젤 멋있어요\n',
#  '와 다행이다\n',
#  '태극기 걸은 게 맘에 듭니다\n',
#  '골 진짜 멋있게 들어갔다\n',
#  '그래도 인생 드라마는 확정인 듯\n',
#  '대상 후보랑 숏터뷰 형식으로 얘기하는 거웃 겨서 그거 보고 껐다\n',
#  '임신 축하드려요\n',
#  '30초 요리\n',
#  '아이돌 중에서 미모 탑비다 진짜\n',
#  '존잼\n',
#  '안 데려오길 잘했다\n',
#  '완전 뿌듯\n',
#  '너무 귀엽네\n',
#  '생활 속의 작은 기쁨\n',
#  '그러지 말고 한 번 더 보자\n',
#  '이제 연말이네요\n',
#  '면접 안 보고 바로 최종 합격은 아님\n',
#  '국군장병 전우들아 수고해요\n',
#  '아기 엄마들의 전투 육아 스토리를 이모티콘으로 만들어봤어요\n',
#  '애들 편도나 기관지 쪽에 좋은 제품들 주길래 혹하는 마음에 해봤어요\n',
#  '그 여자애가 연예인을 좋아해서 전에 생일 때도 앨범을 사줬는데 좋아하더라고요\n',
#  '부산에 부릉부릉 갔는데 해운대에 바다 보러 가서 맛나게 스파게티도 먹어주시고\n',
#  '일하면서 들었는데 커플 탄생인 거 같더라\n',
#  '외모상으로 똑 부러지고 야무질 거 같은 느낌 드는 여자\n',
#  '어떻게 하다 보니 운 좋게 취업 안 되면 오라는 회사 한 군데를 알게 되었는데요\n',
#  '나 말년휴가 나왔다 복귀하면 제대한다\n',
#  '남중 남고를 지내왔던 저에게 디자인대학은 정말 꿈만 같은 곳이었습니다\n',
#  '오늘도 500원짜리 5개 100원짜리 2개 주웠네\n',
#  '심장이 쿵쾅 쿵쾅 그날을 잊을 수가 없다\n',
#  '4월에 첫 출근한 인턴인데 5월 4일 샌드위치 데이에 회사 쉰다고 하더라고요\n',
#  '아침에 눈뜨자마자\n',
#  '근데 발렌티인데 이 대전 고급 초콜릿이랑 백화점에서 옷 사줬어요 편지도 쓰고요\n',
#  '다음 주부터 사각 턱이랑 광대 눈 상담받으러 상담 투어 갑니다\n',
#  '어차피 전 중국어를 공부할 생각이라 여기 신청했는데 보니까 괜찮은 거 같아서 남겨봅니다\n',
#  '아 아무튼 좋네요 0\n',
#  '귀가 따뜻해\n',
#  '다들 응원 열심히 해봐요\n',
#  '제가 아직 취진 생이라 돈은 별로 없어서 고민 중이었는데 지금 세일도 많이 한다고 하더라고요\n',
#  '여긴 수수료도 안 받더라고요\n',
#  '지금은 22살 아기는 이 제도로 됐어요\n',
#  '꽃다발 하나 선물해보세요\n',
#  '인맥도 환영합니다\n',
#  '교복은 진짜 얘만큼 잘 어울리는 애 없음\n',
#  '오늘은 치즈김밥 줘서 덕분에 먹으면서 아침 맞이했다\n',
#  '나처럼 지금 돌침대에 누워있으니까 시원하기만 한데\n',
#  '빼고 다 내 스타일이야 넌 내 것\n',
#  '천생 여자 같은 느낌이야\n',
#  '사진은 이뻐서\n',
#  '나 자신이 대견해\n',
#  '그걸 해줘야 릴랙스도 되고 복근이 이쁘게 생긴단다\n',
#  '우리다 잘 될 거예요\n',
#  '친구 추가할게요\n',
#  '아 진짜 덕분에 오랜만에 실컷 웃네요\n',
#  '지난 삼성전에서 6실점하고 승리하신 것 너무 축하축하드리고요\n',
#  '우리 모두에게 진정한 도움이 되는 셰프님 국민 셰프님입니다\n',
#  '반찬을 너무 쉽게 척척 만드시네요\n',
#  '재밌고 늘 행복해진답니다\n',
#  '히히 안녕하세요\n',
#  '오빤 언제나 저에겐 최고에 요오홍홍\n',
#  '그리고 대상 축하드립니다\n',
#  '오빠 아프다는 소식 듣고 눈앞이 캄캄했는데 오늘 그 어둠이 조금이라도 사라졌어요\n',
#  '이따 뵈어요\n',
#  '그래도 이름이 있는 것만으로 만족합니다\n',
#  '어제 너무 좋았습니다\n',
#  '건강하시고 행복하세요\n',
#  '흑 역사라 하긴 뭐 한데 그 내가 쓴 댓글 보기 하는 거 있잖아\n',
#  '상큼한 트레이닝복 화보 촬영 중인 나\n',
#  '외모는 충분히 이쁘다\n',
#  '제대해서 좋아\n',
#  '끝까지 응원한다\n',
#  '솔직히 요 신인 거지\n',
#  '잔머리 하나는 진짜 갑인 것 같아요\n',
#  '4개월 조금 넘은 아기입니다\n',
#  '이러는데 너무 귀여워 죽겠다\n',
#  '노래도 좋고\n',
#  '세븐틴에게 조공을 바치며 살아가겠습니다\n',
#  'TV에서 자주 뵙는데 멋지십니다\n',
#  '너무너무 좋다\n',
#  '오늘 대 박세일 가로 스틱 분유사 가지고 왔어요\n',
#  '이것도 아무 말 대잔치인데 기분이 상하지\n',
#  '제주도 여행 계획 중입니다\n',
#  '결과적으로 여자친구가 한번 눈감아준답니다\n',
#  '수고가 많으시네요 참 멋있어요 참 멋져요 앞으로\n',
#  '멋진 님\n',
#  '정말 오랜만에 아름다운 연기를 볼 수 있게 되어서 정말 기뻤어요\n',
#  '메리 크리스마스\n',
#  '오빠의 행동 하나하나가 우리에게 즐거움을 주네요\n',
#  '생일 맞으신 거 정말 진심으로 축하드려요\n',
#  '오빠 감정 최고예요\n',
#  '너무 훌륭했어요\n',
#  '제가 여기 동호회에 클럽을 만들었거든요\n',
#  '서로 의식하게 되고 좋아하게 된 시기가 겹쳐서 너무 신기해요\n',
#  '궁금해서 여기 눈팅하고 있는데 이거 너무 웃김\n',
#  '글 정리 같은 거랄까 그냥 깔끔한 걸 좋아해요\n',
#  '24년 동안 결심 못했던 다이어트님 덕분에 2주 넘게 다이어트 중\n',
#  '무조건 증정이니 해볼 만한 이벤트 같네요\n',
#  '헬스장 몇 년 다녀보니까 느끼는 건데 새해 첫 평일에는 사람들이 엄청 많습니다\n',
#  '안녕하세요\n',
#  '오늘 판에 들어와 보았는데 메인에 있어서 놀랐어요\n',
#  '응원할게요 새해 복 많이 받으세요\n',
#  '항상 팬들이 응원하고 있답니다\n',
#  '선수 너무너무 수고 많았어요\n',
#  '선수가 1루로 복귀한다니 참으로 기쁜 소식이군요\n',
#  '생일 진심으로 축하하고 좋은 하루 보내요\n',
#  '생일 축하합니다\n',
#  '생일 축하해요\n',
#  '2일 후면 팬 된지 딱 1년 되네요\n',
#  '우와 이번 활동 많이 수고했어요\n',
#  '오늘 너무 자랑스럽고요\n',
#  '3월 내내 멤버들 생일이 없어서 축하글 오랜만에 써요\n',
#  '다시 한번 축하축하\n',
#  '유재석 주니어의 탄생을 축하드려요\n',
#  '이번 해투는 가요제 이후로 절제 일로 웃긴 몸 개그와 언변이었다고 생각합니다\n',
#  '님 파이팅입니다\n',
#  '나오신다길래 좋아서 히히 히다 보고 이름을 쳐 봤는데 팬카페가 나오더라고요\n',
#  '언제 어디서나 기분 좋게 바라볼 수 있는 분\n',
#  '진심으로 생일 축하한다\n',
#  '오늘 밤 SBS11시 25분 첫 방송\n',
#  '생일 축하해♡아\n',
#  '오빠 참 좋아요\n',
#  '아시아 투어 건강하게 잘 갔다 와요\n',
#  '선생님 요리 정말 재미있어요\n',
#  '만능 간장으로 채소 요리도 쉽게\n',
#  '맥주 부님 덕분에 요리가 갈수록 스피드하고 맛이 있어지는 거 같아요\n',
#  '오라버니 하늘이 파랗게 있으니 날씨가 좋더라고요\n',
#  '선수의 LG 팬으로서 진심으로 축하드리고요\n',
#  '꼭 본방사수해서 시청 잘할게요\n',
#  '그리고 실검 1위도 축하해요\n',
#  '나도\n',
#  '개설한 지 5주년이 됐네요\n',
#  '앞으로도 무한도전에서 더욱더 좋은 모습 재미있는 모습 기대할게요\n',
#  '진심으로 생일 축하드려요\n',
#  '생일 축하해\n',
#  '형은 언제나 최고였고 앞으로도 최고의 선수일 거예요\n',
#  '아 오늘 생일이네요\n',
#  '파이팅\n',
#  '오빠 오늘 무도 정말 재밌게 봤어요\n',
#  '오늘 드디어 데뷔 600일\n',
#  '덕을 보네요\n',
#  '요리 프로그램이 한 다음날은 우리 집 메뉴가 풍성해집니다\n',
#  '대기록 달성 축하해요\n',
#  '오늘 공개 카페 왔다 갔죠\n',
#  '진짜 너무너무 진심으로 너의 탄생일을 축하한다\n',
#  '웃고 싶을 땐 형만 보는 듯\n',
#  '오빠 생일 축하해요\n',
#  '역시 오빠 생일이니까 사진은 오랜만에 오빠 짧은 머리로\n',
#  '새해가 밝네요\n',
#  '와우 진짜 오랜만에 여기 왔어요\n',
#  '데뷔한 지 얼마 안 된 것 같지만 벌써 1주년이 지나고 오빠도 데뷔하고 두 번째 생일이네요\n',
#  '티브이에서 자주 뵈니 좋습니다\n',
#  '제가 오빠를 좋아한 건 94년 오빠가 데뷔했을 때죠\n',
#  '그렇게 최고 자리에 있으면서도 끊임없이 발전하는 모습이 너무 보기 좋네요\n',
#  '그리고 새해 복 많이 받으세요\n',
#  '형님 사실이면 축하드립니다\n',
#  '생일 축하드리고요\n',
#  '마음이지만 정말로 생일 축하드립니다\n',
#  '항상 건강하시고 이번 우승 축하합니다\n',
#  '백주부님은 사람을 즐겁게 만드는 행복 바이러스\n',
#  '그럼 내일을 위해 고고싱\n',
#  '어제 자기 전만 해도 18등이었는데 지금 4등이 나올랐어요\n',
#  '내일부터 추석 연휴에요 오빠\n',
#  '오늘은 벌써 제가 오빠를 좋아하게 된 지 90일\n',
#  '정말 정말 열심히 하는 모습 보기 좋습니다\n',
#  '방송에서 본 모습이 너무 좋아 보여요\n',
#  '이쁜 아♡\n',
#  '세상에 어떤 일이 있더라도 저에게 있어서는 최고입니다\n',
#  '파이팅\n',
#  '오빠 생일 축하해요♡\n',
#  '오빠 안녕하세요\n',
#  '만능 간장으로 꽈리고추볶음 엄청 맛나서 맛 들여서 매일 해먹고요\n',
#  '95년도에 일본과 친선경기 때 처음 선수를 보고 팬이 되었습니다\n',
#  '그리고 생일 축하해요\n',
#  '그러니깐 내가 초등학교 4학년 때부터 형을 좋아했어요\n',
#  '오늘은 해토 촬영 날이자 무도하는 날\n',
#  '백 선생님 얼굴만 봐도 절로 입가에 미소가\n',
#  '마지막으로 다시 700일 축하해요\n',
#  '컴백까지 건강 챙기시고 멋있는 모습으로 만나요\n',
#  '역시 오빠를 알아보시는 분이 계시군요\n',
#  '독특한 억양이 너무 멋있습니다\n',
#  '일단 400일 축하해\n',
#  '역시 기대를 저버리지 않네요\n',
#  '2010올림픽이 열릴 밴쿠버 경기장에선 세 대륙 첫 우승\n',
#  '아이스쇼로 스트레스가 날아갔어요\n',
#  '이번 아이스쇼에 갔었어요\n',
#  '그래서 선수도 좋아해요\n',
#  '그럼 저는 티켓팅하러\n',
#  '앞으로도 영원히 사람을 사랑할 것을 맹세합니다\n',
#  '세상에 하나뿐인 든든한 총괄리더 생일 축하해\n',
#  '선수 파이팅\n',
#  '주말이 되면 무도 볼 생각에 진짜 좋더라고요 유느님 활약 기대됩니다\n',
#  'LG 파이팅 파이팅\n',
#  '글 남겨요\n',
#  '그렇게 살다 보면 언젠가는 사람들이 알아주는 날이 오는 법이다\n',
#  '다시 한번 정말 축하드립니다\n',
#  '내일모레가 방학이에요\n',
#  '생일 축하해\n',
#  '오빠 아까 해투 잘 봤어요\n',
#  '내일 데뷔 1주년이니까 멤버들 전체한테 한번 적으러 올게요\n',
#  '생일 축하해요\n',
#  '오늘 저녁 시간에도 맥주 부님 만 세요\n',
#  '무한도전 지피지기\n',
#  '그래도 1kg이 빠졌어요\n',
#  '오빠 21번째 생일 정말 축하해요\n',
#  '오빠들1위 축하해요\n',
#  '시간이 늦었지만 오빠 생일 축하해\n',
#  '진심으로 축하해\n',
#  '저는 취미로 요리를 좋아하는 사람인데 제가 평소에 원했던 프로그램입니다\n',
#  '님 덕분에 아빠들의 요리 솜씨가 상향 평준화되어버려서 제 희소성이 떨어져 버렸거든요\n',
#  '엘지 파이팅\n',
#  '존재 자체만으로 큰 기쁨이었어요\n',
#  '너무 축하드려요\n',
#  '그리고 요즘에 너무 뿌듯해요\n',
#  '다음번에는 꼭 1위시 켜드릴 수 있도록 노력하겠습니다\n',
#  '팬들을 위해서 열심히 싸워주십시오\n',
#  '오늘 장이었어요\n',
#  '세븐틴 만세 만세 만만세\n',
#  '다 비켜 우리 오빠가 최고야\n',
#  '축하합니다 축하합니다\n',
#  '세븐틴에게 지금이 소중한 추억으로 기억되고 있는 것 같아내가 다 뿌듯하네\n',
#  '정말 생일 축하해요\n',
#  '앞으로는 다이아 길만 걷게 해줄게요\n',
#  '어제 전주 삼 성문회 회관에서 콘서트 봤지요\n',
#  '오라버니 또다시 5월 셋째 주가 시작하네요\n',
#  '오빠 졸업 축하하고\n',
#  '우리 함께 가요\n',
#  '챔피언 답습니다\n',
#  '32로 삼성에 지고 있다가 선수가 솔로홈런으로 동점을 만들었네요\n',
#  '최고\n',
#  '진심으로 축하합니다\n',
#  '새해 복 많이 받으시고 올해도 건강하시고 파이팅 하세요\n',
#  '프로로 영입한다네요\n',
#  '파이팅\n',
#  '텔레비전에서 수다 떨 때나 애드리브 할 때 눈웃음이 멋져요\n',
#  '오늘 저는 정말 힐링을 했어요\n',
#  '02년도부터 두각을 보이는 선수들 또한 돌아온 가세한다면\n',
#  '정말 기쁩니다\n',
#  '언니가 한 경기를 매일 되풀이하며 보고 있습니다\n',
#  '그래서 바로 다음 카페를 가입하고 메찾사를 가입했습니다\n',
#  '이번에 꼭 1위 시켜줄게요♡\n',
#  '팬카페 지기님 차 한 잔 마시며 잠시 휴식을 취하려 할 때 방 안의 다른 친구 TV를 켜면 자주 눈에 띄시네요 반갑습니다\n',
#  '항상 기다릴 테니까\n',
#  '오빠 이기세로 2008년에도 한자리하는 거야\n',
#  '제가 가입한 지 얼마 안 되고 제가 그렇게 열렬히 카페 활동하지 않지만 가입했다는 것만으로도 기분 좋은 거요\n',
#  '앞으로 더욱 멋진 모습 기대할게요\n',
#  '좋아 올해는 뭔가 필이 온다\n',
#  '광주엔 계속 비가 온다던데\n',
#  '두 손 꼭 잡고 들었어요\n',
#  '언제까지나 응원하고 기억할게요\n',
#  '연습생 때는 그냥 빨리 데뷔했으면 좋겠다 했는데 이젠 일위도 하고 너무 자랑스럽다\n',
#  '방송 잘 보고 있습니다\n',
#  '각자 21살 20살 생일이네요\n',
#  '아 귀여워 이번엔 꼭 보러 가야지\n',
#  '후반으로 갈수록 존잼\n',
#  '결과와 관계없이 그저 멤버들이 즐겁고 행복하게 원 없이 활동하는 모습 보고 싶네요\n',
#  '에 이날도 더운데요 친이랑 시원한 모텔이 나가야겠다\n',
#  '냠냠냠 모든 음식은 맛있게 먹어야 합니다 특히 야식\n',
#  '대박 은근히 섹시한 계속 기다리게 됨\n',
#  '댓글 보고 있는 모양임 죄다 반대 하나씩\n',
#  '혼자서 던지고 치고받고 다하겠구나♡\n',
#  '윤아 연기 잘하고 이쁘고 매력 있어\n',
#  '그 이후로 대폭 망\n',
#  '예쁜 아기랑 행복하게 사세요\n',
#  '힘내세요 선수\n',
#  '아싸 수요일 개이득\n',
#  '임신 축하드려요 누나\n',
#  '오늘 너무 웃겨서 앞니 빠지는 줄 알았음 눈치 보며 흘린 밥풀 주워 먹고 표정\n',
#  '오늘 너무 웃겼어요\n',
#  '주모 연중무휴입니까\n',
#  '왜 난 말하는데 당황하는 모습에 개 웃겼는데\n',
#  '역시 설날엔 설날도\n',
#  '성실하고 묵묵하고 좋지\n',
#  '오이 거 보자마자 대박을 외쳤음\n',
#  '대한민국에서 모르는 사람듵 있을까요\n',
#  '진짜 맨유 시절 역대 최고의 크랙이 지기가 막혔는데 진짜\n',
#  '어짱구엉덩이 네울라울라\n',
#  '그 와중에 게임하는 개웃김\n',
#  '아 진짜 전 잼이었다\n',
#  '기아가 내년에 우승하겠군요 축하합니다\n',
#  '와대 박화이팅\n',
#  '말로 웃겨서 큰소리로 웃게 한 아저씨는 처음\n',
#  '님이 나쁜 놈이 아니라 너무나 좋은 거\n',
#  '공동 수상 진심으로 축하합니다\n',
#  '고소한 참기름 냄새가 솔솔\n',
#  '재밌음\n',
#  '생각만 해도 웃김 기대돼요 파이팅\n',
#  '연기 폭만 하고 먹고살기 힘들지\n',
#  '감방 동기 됐네\n',
#  '어머 언니들이 기사 너무 좋은데 어떡하지\n',
#  '자전거가 최고\n',
#  '형님의 리\n',
#  '근데 진짜 잘생겼네 원빈 급이다\n',
#  '이따가 또 가야지\n',
#  '아 이건 정말 신의 한 수예요\n',
#  '사진 절묘하게 잘 골랐네\n',
#  '정말 기다려지네요 대장 최고\n',
#  '진짜 제일 좋아하는 야구선수 진심 멋지다\n',
#  '조만간 스카우터들 한국방문할 듯\n',
#  '올해 최고 의학드라마는 태양의 후예\n',
#  '이거 성공하면 우리나라 캐릭터 하나 건지는 거임\n',
#  '이런 것 너무 좋아질 투 귀여울 것 같음\n',
#  '갓 현주 연기 좋아요♡♡\n',
#  '내 나왔어요 꺄\n',
#  '축하드립니다\n',
#  '금요일 토요일이 제일로 기다려지는 일인입니다 너무 재미나요\n',
#  '이러다 무투표당선되는 거 아니냐\n',
#  '능력 있는 어른의 모습 멋있어요♡\n',
#  '다행이다 또 충돌 일어날까 봐 10일부터 끌고 왔는데 못 들어오게 하면 더 열받아서 무슨 일 나는데 법원 잘했네 잘했어 아저씨들 고생하셨어요 다치지 마세요\n',
#  '자신 있네 금요일이라 했다\n',
#  '스마트폰 꼭 봐야 편하다 왜냐하면 스마트폰은 내 친구니까 스마트폰 하트\n',
#  '파이팅\n',
#  '걸그룹 대 첩보다 이게 훨씬 더 재미있다\n',
#  '좋았어 우리 동네에 오신다\n',
#  '계주는 역시 방탄소년단\n',
#  '능력자의 메뚜기 바지 벗길 때 가장 기억에 남는다\n',
#  '예쁘게 사는 배우네\n',
#  '기아타이거즈 ♡ ♡♡\n',
#  '유부녀 축하합니다\n',
#  '아침부터 로또번호 불러주네\n',
#  '드디어\n',
#  '잘 어울리는데 그냥 결혼해라\n',
#  '무도 입성이라니까\n',
#  '역시 한국이 제일 안전해\n',
#  '그다지 나 잼일 거 같고 그냥 섭외한다면 섭외능력에 감탄할 뿐 솔직히 재미는 없을 거 같다 족구하고 물공 헤딩하고 그런 거 하고 끝나겠지 오히려 메기 잡기는 꿀 잼일 거 같다\n',
#  '항상 응원하고 있어요\n',
#  '둘 다 잘생겼다\n',
#  'JTBC 같은 언론이 있기에 저러는 거다\n',
#  '케이팝스타 마지막이라 그런가 참가자 실력도 좋고 완전 꿀 잼\n',
#  '싼 맛 엘지 굿 경험자임\n',
#  '착하고 열심히 하는 게 다른 자질보다 백 번 낫다\n',
#  '오랜만에 훈훈한 뉴스네요\n',
#  '결방은 싫지만 연속 방송해주고 스페셜도 보여준다니 그냥 넘어가야지\n',
#  '진짜 호주 가서 외국인들이랑 같이 롤 하는데 한국 사람이라서 영어 잘못한다니까 한국 사람 아냐고 물어봄 무조건\n',
#  '어디서나 인정받는 배우님 자랑스러워요\n',
#  '역시 우린 짱깨와 다른 민족이었어\n',
#  '축하드립니다\n',
#  '혼자 식사하기엔 곰탕이 최고\n',
#  '콘서트 와이프 손잡고 가자고 해야겠다\n',
#  '너무 잘 어울리고 이쁜 커플\n',
#  '정말 웃기다\n',
#  '원인 규명이 되었다니 다행이네요 보완작업 잘 하고 기능 추가해서 완벽한 갤노트 8이 빨리 나오길 기다리고 있겠습니다\n',
#  '이렇게 보니까 잘 어울린다\n',
#  '오래간만에 좋은 소식 들어서 기분 좋네요\n',
#  '오늘날 잘 잡았어 날씨 끝장이다 5000만 집결\n',
#  '다저스 큰일 났네\n',
#  '좋은 연기 보여주세요 응원합니다\n',
#  '슬슬 생길 때 됐지\n',
#  '님짱\n',
#  '너무 재미있음 오늘 보러 갔다 왔는데 또 보고 싶음\n',
#  '재미나네\n',
#  '위원 정말 사이다입니다 멋지십니다\n',
#  '준비 잘해서 좋은 멤버들이랑 데뷔했으면 좋겠다 응원합니다\n',
#  '처음엔 음악 대장의 팬이었다면 이젠 국가 스테인리스강의 팬이다\n',
#  '저런 것이 고소해서 합의금 뜯으면 꿀\n',
#  '축하해\n',
#  '싱그러운 청춘 사극 분위기 너무 좋고 눈 호강도 제대로 한다\n',
#  '이런 거 보면 헬 조선이긴 한데 한국에서 태어난 걸 감사해야 되는구나\n',
#  '레고는 시티 시리즈 가꿀 잼이었는데 도로 판 사서 건물들 세워놓고\n',
#  '빨리 꺼지세요 속이 시원하다\n',
#  '게임방 가서 사광 클릭해서 대기 4600명 뚫고 성공\n',
#  '악 누구인 줄\n',
#  '앞으로는 행복하렴\n',
#  '신곡 지붕킥 하자\n',
#  '평화로운 시위로 믿음을 만들었기에 가능했다고 봅니다\n',
#  '엘지 축하해요 기아 몫까지 최선을 다해 좋은 결과 얻길\n',
#  '그래 아주 잘했어요\n',
#  '시상식 3대 기획사 잔치인데 올해 YG 부재에 방탄이 좋은 기회를 받았네요\n',
#  '오늘 치킨 시켜 먹어야지\n',
#  'sk에서 시구까지 하고 이미 그는 sk 레전드입니다\n',
#  '호구든 거품이든 뒷돈이든 난 모르겠고 영입 참 잘했다\n',
#  '15년 전 영종도 칼국숫집에서 뵈었는데 건강하세요♡♡♡\n',
#  '고유어는 아름답다\n',
#  'VR로 즐길 듯 기대되네\n',
#  '전복 이름 지어준 거 겁나 웃김\n',
#  '너보다 걔가 낫다\n',
#  '확실한 부정 웃겨요\n',
#  '조만간 구속수사\n',
#  '내 아들도 재학생 군 복무 중으로 자랑스럽네요\n',
#  '뒷북 꿀 잼\n',
#  '내 일한 화승 기아 엘지 패하면 재밌어지겠다\n',
#  '굿 꿩 먹고 알 먹고 누이 좋고 매부 좋고\n',
#  '2007년 전국의 텔미 열풍은 잊을 수 없다\n',
#  '비 좀 와라 좋은 현상임 굿굿\n',
#  '난 암전 게임 재밌었음 재치 있더라 귀여웠음\n',
#  '진지하게 기사 읽다가 사진 보고 뿜었다\n',
#  '다른 배우분들도 잘하셨지만 정말 받을만한 분이 받은 겁니다\n',
#  '미리\n',
#  '오 선택 잘했다 롱런하길\n',
#  '커플 대상 응원합니다\n',
#  '보고 싶었어요 멋있는\n',
#  '사이다 속 시원하다\n',
#  '예감 적중\n',
#  '너무 이쁘다♡\n',
#  '능청스럽게 비굴한 연기도 잘하고 귀엽고 사랑스러운 연기도 잘하고 자연스럽게 잘해 잘해 예뻐 죽겠어\n',
#  '생각보다 조합이 상상 안 감 그렇지만 축하합니다\n',
#  '누나 수고했어요\n',
#  '대선 축하합니다\n',
#  'NC 코리안시리즈 진출 축하드립니다\n',
#  '이아 대개 그 좀 할 줄 아네\n',
#  '하야하기 좋은 날씨네요\n',
#  '어제 나온 부부 너무 보기 좋더라 좋았고\n',
#  '검은 사제들에서의 카리스마 짱\n',
#  '역시 명불허전 똥싸개\n',
#  '우리 나란 아직 판매 중 희귀템 구매원하면 사면됨\n',
#  '의사봉 두드리는 소리가 저리 경쾌할 줄 누가 암\n',
#  '하드캐리♡\n',
#  '수원 햇빛 좋다\n',
#  '그나마 다행히 기각 폰은 안됐네 탄핵 폰\n',
#  '운동복처럼 쭉쭉 늘어나는 정장 너무 좋다\n',
#  '나의 멘토이자 우상 파이팅 행복하세요\n',
#  '이형 대상 받는데 왜 내가 다 기분이 좋냐\n',
#  '얼굴 이미 다 팔렸는데 왜 가려\n',
#  '또 둿 목잡네\n',
#  '은근 개장하지\n',
#  '옛날부터 존 날인데 왜 안 뜨나 했었는데 이번에 배역 제대로 맡아서 뜨나 보다\n',
#  '훈훈한 비주얼에 따뜻한 연출 기대할게요\n',
#  '이름 그대로 가요계의 신화\n',
#  '대일본제국 만세 천황폐하 만세\n',
#  '떠난 레전드 감독의 자리를 이어받을 듯\n',
#  '길 가다가 포켓몬고 하다 정신이 팔린 새끼가 지나가다가 똥 밟은 거 본 적 있다 뒤에서 가는데 얼마나 웃기던지\n',
#  '만세 당선 축하합니다\n',
#  '어떤 영화일지 너무 기대됩니다 파이팅\n',
#  '대박 날 만함 시청률 30는 나와줘야지 기존 잼 꿀 잼\n',
#  '존 나야무지게 달리네\n',
#  '진짜 나랑 개그코드가 너무 똑같아서 배꼽 잡고 웃는다 너무 재밌어\n',
#  '응원합니다 파이팅\n',
#  '이참에 화성산업 주식이나 사볼까\n',
#  'Vip룸에서 tv보며 팝콘 먹던 순시 리뜬금 없는 팩폭\n',
#  '좋은 일 했네요\n',
#  '선발 로테이션 지맘대로 조절해가며 충분히 표적 등판시킬 듯\n',
#  '잘생겼다\n',
#  '\n',
#  '슈돌 섭 외력 우주 돌파\n',
#  '존 나 잘하네\n',
#  '앜 진짜 겁나 웃곀\n',
#  '축하드려요\n',
#  '복귀 찬성\n',
#  '파이팅\n',
#  '타령이 제일 웃기네\n',
#  '어야 음악 좋다 다다\n',
#  '개 웃길 듯\n',
#  '축하합니다 너무 잘 됐네요\n',
#  '우린 가장 재밌어\n',
#  '오늘은 일주일 동안 기다렸어요\n',
#  '발가락이 닮았어요\n',
#  '누나 나랑 사귀자\n',
#  '노력하는 모습 보기 좋아요\n',
#  '반함♡ ♡♡\n',
#  '멋지다\n',
#  '경질이나 자진사퇴 기사가 났으면 여권을 불태워버렸을 텐데 한 해 동안 수고 많았어 메이저 가서도 승승장구하기를\n',
#  '둘 다 순수하고 묘한 자기만의 세계가 어울림 어서 결혼 갑시다\n',
#  '눈 해주고 발해줘서 다른 애들 조지는 건 진짜 쩔었다\n',
#  '조금 뻔하긴 하지만 연출이 지린다 진짜\n',
#  '사람 참 괜찮네\n',
#  '남자가 봐도 멋있다 말 진짜 잘한다\n',
#  '켜야 아들 잘생겼다\n',
#  '진심 축하드려요 한국 영화계의 큰 경사네요\n',
#  '선수 축하합니다 진정한 프로 인간승리\n',
#  '형님 얼굴도 멋있으시고 행동도 멋있으십니다\n',
#  '이쁘다 좋아요 노래 잘 부르세요\n',
#  '땀 노예 선수처럼 대박 치길\n',
#  '눈물이 나는 기사네요 모두들 고생하셨습니다\n',
#  '어제 귀여워 죽는 줄\n',
#  '야구는 어디서 하든 똑같다는 말 멋지다\n',
#  '조연들이 좋네요\n',
#  '멋지다\n',
#  '정말 멋있다 마음까지도\n',
#  '어휴 드디어 가네 이제 다시 무도 봐야겠다\n',
#  '역시 갓 짜장\n',
#  '대상 받는 것보다 눈물 나긴 처음\n',
#  '연기 진짜 잘한다 마지막 신보고 눈물이 줄줄 흘렀다\n',
#  '가족 건강하게 해줘\n',
#  '엄마의 힘은 위대하다\n',
#  '너무 대단하시다 감동\n',
#  '하나님의 기적 잘 보았습니다\n',
#  '둘이 결혼하면 안 되나 잘 어울리는데\n',
#  '대한민국 사법정의를 바로 세우기 위해 밤낮없이 일하시는 법관님들 존경합니다 파이팅\n',
#  '예술가는 예술로 사회를 이야기하고 지켜 나가야 할 책임이 있다고 말한 피카소처럼 선생님의 처한 사회와 상황을 외면하지 않겠다는 맹세에 존경을 표합니다\n',
#  'KBS 특파원은 뉴스에서 보니까 지금 중국 상해에서 계속 계시던데 역시나 기자라서 그런지 글과 기사도 참 잘 쓰시네요\n',
#  '무엇보다 연기 앞에서 진지하고 성실한 부분이 박수받아 마땅한 듯\n',
#  '대한 국민 만세\n',
#  '뭔가 이 뉴스가 엄청 위로가 된다\n',
#  '오오 체험기 쓰시다니 노력하시네요\n',
#  '내 이상형인 누나다\n',
#  '선수 그동안 기아에서 정말 수고했어요 삼성가서도 응원 많이 할게요 파이팅\n',
#  '역시 이야\n',
#  '헐온 일 2년 동안 대박 너무 축하드려요 선남선녀\n',
#  '역시 멋진 사람\n',
#  '인생인처럼\n',
#  '우리 대한민국 국민들 정말 위대하십니다\n',
#  '자기관리 철저한 사람의 지가 약해서 실패하는 일인으로 존경스럽습니다\n',
#  '역할도 크다\n',
#  '형사랑 합니다\n',
#  '무엇을 하든 자연스럽고 척이 없는데 그게 다선하고 센스 있어서 너무 좋음\n',
#  '최고다\n',
#  '나는 운동경기장에서 국민의례할 때 국가에 대한 자부심을 느낀다\n',
#  '사극해도 한 번 더 보고 싶네요 강력 추천♡♡\n',
#  '자랑스러운 대한민국 국민들95가 새 역사를 만들 것입니다\n',
#  '얼굴에 한민족의 점잖음이 기품이 묻어나네\n',
#  '두 분 축하드려요 다른 드라마에서 다시 같이 연기하는 것보다 싶네요\n',
#  '감동이네요 파이팅\n',
#  '와 개간지다\n',
#  '나의 황제는이다\n',
#  '토트넘 동료들이 훈련 때 보면 잘한다 함 갑자기 잘하는 게 아니라 원래부터 잘했다 함 놀랄 일도 아니라 함\n',
#  '본방사수할게요\n',
#  '3주간 너무 재밌었어 요만 세\n',
#  '멋있다\n',
#  '음색에는 어떤 특별한 울림이 있어 자꾸 듣고 싶어진다 이번에 정말 개취\n',
#  '진짜 겸손하다\n',
#  '양키스는 좀 먼 이야기 같긴 한데 어쨌든 지금 엘지 진짜 잘 함타팀 팬이지만 이건 정말 인정\n',
#  '멋진 친구네요\n',
#  '신의 얼굴 등골이 오싹하더라 표현 정말 좋았어\n',
#  '역시 재미있음♡♡\n',
#  '한국 좀비 영화 중에선 기대 이상\n',
#  '솔직히 연기 잘함\n',
#  '연기가 잘해\n',
#  '투표 개표가 이렇게 흥미진진할 수가\n',
#  '멋있다\n',
#  '고급스럽게 아름답다\n',
#  '아직도 이렇게 천사같이 좋은 분이 계시다니요\n',
#  '대상 타는 거 보려고 이 시간까지 봤다 정말 기쁘고 속 시원하다 축하드립니다\n',
#  '가슴 뭉클하다\n',
#  '전율이 믿을 수 없어 고마워요 슈 돌\n',
#  '노르웨이 교도소는 한국호텔보다 좋던데 방은 좀 작지만 탈옥 빼고는 웬만큼 할 수 있는 건 다 되는 거 같고 면회실 보고 레스토랑인 줄\n',
#  '감동이네요 눈물 난다\n',
#  '연기 진짜 잘하시던데\n',
#  '진정한 여왕님 말씀 잘 들었습니다\n',
#  '오늘 첼시 경기력 지림\n',
#  '첫사랑이 이루어졌네\n',
#  '밖에서 일하시는 분들 힘내세요 파이팅\n',
#  '때문에 심장 미치잖아\n',
#  '사랑할 수밖에 없는 남자\n',
#  '어느 한 곳이라도 특출나게 크고 있는 이들이 있어 다행이다\n',
#  '날로 잘생겨져가네\n',
#  '의리 한번 죽이네\n',
#  '갑인 듯\n',
#  '나는 이래서 좋다\n',
#  '엄마 미소\n',
#  '극찬한 이유가 있었어\n',
#  '코끝 찡하게 하네요 파이팅\n',
#  '안녕하세 요입니다♡\n',
#  '당연히 받을 줄 알았다 이젠 대한민국을 대표하는 에이스 투수\n',
#  '압도적이다 진짜\n',
#  '멋지십니다 박수\n',
#  '눈치 보지 않고 하고자 하는 말씀 시원시원하게 해주시는 모습 멋있습니다\n',
#  '이 정도면 리버풀 승리\n',
#  '윗입술이 너무 귀여워요\n',
#  '좋은 기사 한참 동안 읽었네요\n',
#  '40대 남자 가수들 중에 음원차트 올킬 할 수 있는 건밖에 없을 듯\n',
#  '명절 부모님 생신 처갓집 어른 생신 어버이날에 당연하다는 듯 집에 가자고 하는 집사람이 정말 너무 고맙네요\n',
#  '연기 존 나 잘해우는 데 너무 슬프더라 개 좋아\n',
#  '너무너무 재미있는 드라마\n',
#  '솔직히 제일 잘했지\n',
#  '과연 좋아했을만하 군\n',
#  '외압에 굴하지 않고 오뚝이처럼 일어선 대한민국의 진정한 영웅이다\n',
#  '대륙은 뭐든 스케일이 남달라\n',
#  '잘생겼다\n',
#  '80년이면 거의 37년을 연구했다는 건데 훌륭하오 일본인이지만 존경스럽소\n',
#  '위대한 대한민국 민중의 역사적 승리의 날로 오늘을 기억하라\n',
#  '진실하게 말하는 모습 인상 깊습니다\n',
#  '어떻게 이런 대사들을 쓸 수 있는지 알다가도 모르겠구나\n',
#  '패션의 완성은 얼굴을 결혼식에서 증명하는구먼\n',
#  '파이널 보스\n',
#  '언니는 백야행 때도 정말 아름다웠다고 생각함\n',
#  '잘한 다♡ ♡♡\n',
#  '너무 귀여우심\n',
#  '멋있어요\n',
#  '축하합니다 자랑스럽네요\n',
#  '수요일 목요일이 기다려집니다 너무 재밌고 본방사수\n',
#  '드디어 가을야구의 주인공으로 자리 잡을 날이 오네요 감사합니다\n',
#  '너무 재미남 너무 존 잘 아 설레는데 코믹한 연기도 너무 잘해\n',
#  '잘 됐네 성공하시길\n',
#  '영화는 다 본 듯 연기 최고야\n',
#  '무도는 제게 참 소중한 프로예요 감사합니다\n',
#  '티브이에 안 나오는 건 잘한 결정 임진 정한 아버지네요\n',
#  '남자인 내가 봐도 잘 생겨 보이는데 여자들은 오죽할까\n',
#  '만세 만만세\n',
#  '맞는 말씀에 찬성 1표\n',
#  '스타끼리의 만남이라 잘 어울리네요\n',
#  '나도 같이 울었음\n',
#  '역시 얼굴 도착해 몸매 도착해 마음씨는 말할 것도 없네\n',
#  '형님 축하\n',
#  '우와 울컥했다 감동\n',
#  '진짜 참다운 선생님들이시네\n',
#  '책장 움직이는 거 멋있었어\n',
#  '진짜 명장이다\n',
#  '우리키 지환 갔지 환은 사랑입니다 문천 재도 멀티홈런 멋졌어요\n',
#  '누나 가슴속에 3천 원쯤은 있는 거잖아요 파이팅\n',
#  '힘들게 돌아온 길 좋은 결과로 이어졌으면 좋겠네요 선수 파이팅\n',
#  '비투비 파이팅 한 곡마저 잘렸지만 계속 응원할게요♡\n',
#  '형님 대단하십니다 존경합니다\n',
#  '제 인생 최고의 드라마였습니다\n',
#  '멋지다 역시\n',
#  '진심 멋지다고 생하셨어요\n',
#  '힘내세요 2017년 파이팅\n',
#  '재밌게 보고 있어요 이렇게 좋은 일을 하시는 걸 보면 정말 마음이 따뜻한 사람 같아요 앞으로도 좋은 활약 기대합니다\n',
#  '그냥 보기만 해도 기분이 좋아지는 매력이 있다 마냥 흐뭇해지더라\n',
#  '진짜 진짜 축하해 진짜 대단하다\n',
#  '어머나 머리 스타일 하나로 이렇게 바뀌는구나 귀엽네\n',
#  '직접 가서 보니 오히려 기부하시던데 어르신들이\n',
#  '여전히 멋있는 모습으로 멋있는 생각을 가지고 있네요 당신의 길을 응원합니다\n',
#  '우리의 꿈과 희망 청소년들 멋있고 고마워 그리고 너네 젊은이 부러워\n',
#  '기부했는데 역시 친하게 지내는 그룹끼리♡방탄소년단 분들 마음씨 너무 착하세요\n',
#  '인간 본받을만한 사람이다\n',
#  '♡ ♡ 멋짐\n',
#  '기대해봅니다 파이팅\n',
#  ...]

# %% [markdown]
# - 형태소 분석기 나누기

# %%
twitter = Twitter() 
morphs = [] 
 
for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('오라버니', 'Noun'), ('해피투게더', 'Noun'), ('봤어요', 'Verb'), ('\n', 'Foreign')], [('우리', 'Noun'), ('모두', 'Noun'), ('LG', 'Alpha'), ('선수', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('선전', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있게', 'Adjective'), ('기를', 'Verb'), ('넣어', 'Verb'), ('줍시다', 'Verb'), ('\n', 'Foreign')], [('웃긴', 'Verb'), ('거', 'Noun'), ('알', 'Noun'), ('죠', 'Josa'), ('\n', 'Foreign')], [('덕분', 'Noun'), ('에', 'Josa'), ('주방', 'Noun'), ('에서', 'Josa'), ('요리', 'Noun'), ('하는', 'Verb'), ('게', 'Noun'), ('엄청', 'Adverb'), ('좋아졌어요', 'Verb'), ('\n', 'Foreign')], [('마지막', 'Noun'), ('순간', 'Noun'), ('손가락', 'Noun'), ('으로', 'Josa'), ('총', 'Noun'), ('을', 'Josa'), ('만들어', 'Verb'), ('쏘실', 'Verb'), ('때', 'Noun'), ('에는', 'Josa'), ('제', 'Noun'), ('가', 'Josa'), ('직접', 'Noun'), ('맞는', 'Verb'), ('것', 'Noun'), ('같습니다', 'Adjective'), ('\n', 'Foreign')], [('어떻게', 'Adjective'), ('여성', 'Noun'), ('요리사', 'Noun'), ('보다', 'Josa'), ('더', 'Noun'), ('인기', 'Noun'), ('가', 'Josa'), ('많으', 'Adjective'), ('신지', 'Noun'), ('저', 'Noun'), ('도', 'Josa'), ('늘', 'Noun'), ('반찬', 'Noun'), ('만들', 'Verb'), ('때', 'Noun'), ('따라', 'Verb'), ('하고', 'Verb'), ('있답니다', 'Adjective'), ('\n', 'Foreign')], [('우리', 'Noun'), ('에게', 'Josa'), ('맛있는', 'Adjective'), ('음식', 'Noun'), ('을', 'Josa'), ('전', 'Noun'), ('하시는', 'Verb'), ('맥주', 'Noun'), ('부', 'Noun'), ('님', 'Suffix'), ('당신', 'Noun'), ('멋져', 'Adjective'), ('\n', 'Foreign')], [('활동', 'Noun'), ('혜택', 'Noun'), ('으로', 'Josa'), ('오션월드', 'Noun'), ('입장권', 'Noun'), ('2', 'Number'), ('매', 'Noun'), ('까지', 'Josa'), ('주는', 'Verb'), ('폴', 'Noun'), ('인', 'Noun'), ('러브', 'Noun'), ('\n', 'Foreign')], [('그리고', 'Conjunction'), ('100일', 'Number'), ('도', 'Foreign'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('응원', 'Noun'), ('합니다', 'Verb'), ('그리고', 'Conjunction'), ('사랑', 'Noun'), ('합니다', 'Verb'), ('파이팅', 'Noun'), ('\n', 'Foreign')], [('형님', 'Noun'), ('이', 'Josa'), ('올해', 'Noun'), ('우리', 'Noun'), ('팀', 'Noun'), ('으로', 'Josa'), ('온다고', 'Verb'), ('해서', 'Verb'), ('얼마나', 'Noun'), ('기뻤는지', 'Adjective'), ('몰라요', 'Verb'), ('\n', 'Foreign')], [('예', 'Noun'), ('500일', 'Number'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('생일', 'Noun'), ('진심', 'Noun'), ('으로', 'Josa'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('축하', 'Noun'), ('\n', 'Foreign')], [('요리', 'Noun'), ('가', 'Josa'), ('차암쉽쥬', 'Noun'), ('\n', 'Foreign')], [('10년', 'Number'), ('뒤', 'Noun'), ('손', 'Noun'), ('편지', 'Noun'), ('쓰고', 'Verb'), ('꼭', 'Noun'), ('이', 'Noun'), ('감회', 'Noun'), ('도', 'Josa'), ('갈게요', 'Verb'), ('\n', 'Foreign')], [('요리', 'Noun'), ('의', 'Josa'), ('매력', 'Noun'), ('에', 'Josa'), ('빠졌어요', 'Verb'), ('\n', 'Foreign')], [('300일', 'Number'), ('너무', 'Adverb'), ('너무', 'Adverb'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('항상', 'Noun'), ('밝은', 'Verb'), ('에너지', 'Noun'), ('덕분', 'Noun'), ('에', 'Josa'), ('힘', 'Noun'), ('이', 'Josa'), ('납니다', 'Verb'), ('\n', 'Foreign')], [('대단하신', 'Adjective'), ('우리', 'Noun'), ('선생님', 'Noun'), ('파이팅', 'Noun'), ('요', 'Josa'), ('\n', 'Foreign')], [('파이팅', 'Noun'), ('\n', 'Foreign')], [('제일', 'Noun'), ('처럼', 'Josa'), ('기쁘고', 'Adjective'), ('좋은데', 'Adjective'), ('\n', 'Foreign')], [('생일', 'Noun'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('덕분', 'Noun'), ('에', 'Josa'), ('요리', 'Noun'), ('가', 'Josa'), ('즐거워요', 'Adjective'), ('\n', 'Foreign')], [('800일', 'Number'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('이런', 'Adjective'), ('오늘', 'Noun'), ('신문', 'Noun'), ('을', 'Josa'), ('보니', 'Verb'), ('엘지', 'Noun'), ('가', 'Josa'), ('올', 'Verb'), ('시즌', 'Noun'), ('을', 'Josa'), ('포기', 'Noun'), ('한다고', 'Verb'), ('나왔더라고요', 'Verb'), ('\n', 'Foreign')], [('내일', 'Noun'), ('생일', 'Noun'), ('이라', 'Josa'), ('한번', 'Noun'), ('가보려고요', 'Verb'), ('\n', 'Foreign')], [('너무', 'Adverb'), ('너무', 'Adverb'), ('좋아요', 'Adjective'), ('\n', 'Foreign')], [('역시', 'Noun'), ('프로', 'Noun'), ('입니다', 'Adjective'), ('\n', 'Foreign')], [('1', 'Number'), ('위', 'Noun'), ('한', 'Verb'), ('것', 'Noun'), ('너무', 'Adverb'), ('축하', 'Noun'), ('해요', 'Verb'), ('♡', 'Foreign'), (' ...

# %% [markdown]
# - 명사만 골라내기

# %%
noun_list1=[] 
for sentence in morphs :
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word) and ("나" not in word): 
            noun_list1.append(word) 
print(noun_list1)
# Out:
# ['오라버니', '해피투게더', '우리', '모두', '선수', '선전', '수', '거', '알', '덕분', '주방', '요리', '게', '마지막', '순간', '손가락', '총', '때', '제', '직접', '여성', '요리사', '더', '인기', '신지', '저', '늘', '반찬', '때', '우리', '음식', '전', '맥주', '부', '당신', '활동', '혜택', '오션월드', '입장권', '매', '폴', '인', '러브', '축하', '응원', '사랑', '파이팅', '형님', '올해', '우리', '팀', '예', '축하', '생일', '진심', '축하', '축하', '요리', '차암쉽쥬', '뒤', '손', '편지', '꼭', '이', '감회', '요리', '매력', '축하', '항상', '에너지', '덕분', '힘', '우리', '선생님', '파이팅', '파이팅', '제일', '생일', '축하', '덕분', '요리', '축하', '오늘', '신문', '엘지', '시즌', '포기', '생일', '한번', '역시', '프로', '위', '축하', '앞', '하루', '하루', '명', '축하', '축하', '그게', '더', '진짜', '정말', '딸', '바보', '파이팅', '파이팅', '항상', '일', '오빠', '웃음소리', '선수', '파이팅', '매번', '정보', '오늘', '이', '날', '오늘이', '바로', '세븐', '틴', '날', '대상', '수상', '축하', '생일', '진심', '축하', '세븐', '틴', '무한도전', '연기', '응원', '요즘', '세시', '울', '오빠', '일', '등', '신랑감', '꼭', '영화', '위', '님', '보고', '요리', '대해', '관심', '오빠', '생일', '축하', '일과', '카페', '진짜', '우리', '아저씨', '파이팅', '오늘', '콘서트', '숙소', '날씨', '일도', '우리', '모두', '파이팅', '응원', '외국', '응원', '게다가', '위트', '인상', '형님', '생일', '진심', '축하', '축하', '팬클럽', '창', '단식', '해', '병풍', '형님', '정말', '축하', '이번', '루수', '기용', '물체', '야간', '가게', '혼자', '일단', '다른', '말', '필요', '듯', '수고', '기분', '맘', '요리', '맛', '업', '오빠', '선수', '위치', '그날', '늘', '웃음', '생일', '진심', '축하', '마음', '거임', '벌써', '시간', '오늘', '하루', '수고', '다른', '사람', '오빠', '보고', '상이', '해도', '전', '오빠', '거', '오빠', '오늘', '하루', '행쇼', '생일', '축하', '항상', '응원', '또', '제', '모레', '팬미팅', '멤버', '추억', '전개', '인적', '수록', '곡', '중', '웃음꽃', '노래', '오늘', '뮤직뱅크', '또', '기분', '세븐', '틴', '보컬', '팀', '리더', '천재', '작곡가', '생일', '축하', '파이팅', '선수', '항상', '당신', '응원', '요즘', '부쩍', '진짜', '공개', '카페', '카페', '몇', '번', '형님', '열애설', '진짜', '라면', '축하', '오빠', '덕', '크리스마스이브', '마무리', '오빠', '메리', '크리스마스', '오늘', '무한도전', '날', '마무리', '또', '시작', '음식', '기분', '더', '가요', '정말', '저', '오빠', '무지', '우하하하', '하하', '본인', '팬', '입장', '정말', '세븐', '틴', '미소', '이심', '다음', '시즌', '때', '도시락', '응원', '파이팅', '대한민국', '만세', '요즘', '스포츠', '뉴스', '기분', '거', '최우수', '상', '우수상', '못', '뭐', '데', '대상', '줄', '다시', '한번', '생일', '축하', '신바람', '정말', '축하', '정말', '진심', '축하', '밸런타인데이', '노래', '정말', '수고', '시즌', '첫', '홈런', '축하', '다음', '시즌', '땐', '고', '게다가', '곧', '생일', '우히히', '어제', '무한도전', '시험', '편지', '더', '노래', '꼭', '홍홍홍', '홍왜', '면서', '축하', '하하', '결혼', '축하', '안녕', '오늘', '더쇼', '위', '진짜', '진짜', '축하', '생일', '축하', '동안', '오빠', '생일', '축하', '크리스마스', '선물', '진짜', '앞', '절대', '이제', '폼', '줄', '귀신', '다시', '골', '머신', '기자', '싱글벙글', '곧', '댓글', '개', '유명', '짤', '탄생', '역시', '축하', '명', '이', '젊은이', '은', '희망', '엘지', '기분', '사람', '파이팅', '덕분', '오늘', '촬영', '거', '존', '또', '걸', '축하', '올해', '케', '베스', '누굴', '인정', '캬', '장관', '자연', '움', '이제', '시작', '오', '엠', '비시', '자네', '연예', '전부', '악플러', '기상캐스터', '머리', '날씨', '짐작', '여기', '댓글', '아주', '난리', '대박', '인물', '곱', '맘씨', '최고', '너', '진짜', '인정', '이제야', '재능', '듯', '진짜', '노래', '지금', '정말', '다시', '재결합', '기대', '기분', '결혼', '어머님', '표정', '진짜', '진짜', '리얼', '표정', '오락가락', '양호', '거', '위로', '질', '프로', '폐지', '정말', '대한민국', '만세', '진짜', '고생', '정말', '후반', '중앙', '동이', '신의', '수', '친구', '가장', '생각', '지금', '정말', '개그맨', '듯', '삼촌', '축하', '형님', '진짜', '개', '언제', '늘', '경기', '기대', '뒤', '살', '다행', '고향', '울진', '땐', '사무실', '짱', '흥', '풍악', '파이팅', '축하', '요즘', '배우', '범죄', '구단', '엔씨', '축하', '정말', '톱', '타자', '국제', '경기', '가면', '시즌', '우리', '승리', '연기', '호감', '연기', '연기', '사생활', '사생활', '일', '뿐', '축하', '오', '열', '일', '축하', '대전', '날씨', '매우', '맑음', '기부', '천사', '어제', '오늘', '머', '머리', '재', '희소식', '노벨상', '감', '파이팅', '연기', '조기', '대처', '기장', '및', '승무원', '지시', '승객', '모두', '오늘', '데', '더', '더', '축하', '흥', '흥', '오늘', '음원', '힘', '추진', '수술', '찬성', '때', '정말', '리액션', '얼굴', '마음', '우리', '언니', '응원', '연말', '배우', '볼', '수', '기아', '입', '듯', '기아', '팬', '대상', '축하', '무한상사', '야유회', '때', '정말', '이', '이', '정도', '활약', '거', '전성기', '때', '듯', '난', '코빅', '고정', '가라', '안티', '별로', '머리', '스타일', '초딩', '불', '초딩', '샷', '이태원', '바', '성격', '보임', '얼굴', '행쇼', '공민왕', '후손', '연기', '인정', '매력', '천사', '파이팅', '관계', '유지', '결혼', '가면', '차우찬', '가지', '지레', '발', '좀', '박자', '문관', '둘', '오늘', '집회', '촛불', '소', '등', '제트엔진', '두산', '최강', '보고', '저리', '명', '핸드폰', '증보', '아이', '핀', '인증', '아주', '조금', '더 ...

# %% [markdown]
# - 빈도수대로 정렬

# %%
count1 = Counter(noun_list1)
print(count1)
# Out:
# Counter({'축하': 359, '정말': 316, '진짜': 303, '거': 235, '파이팅': 193, '응원': 161, '항상': 161, '오늘': 158, '최고': 157, '오빠': 156, '선수': 153, '요리': 143, '수': 140, '연기': 136, '보고': 133, '우리': 131, '때': 130, '감사': 128, '모습': 121, '더': 104, '사람': 104, '이': 102, '듯': 100, '저': 98, '역시': 94, '생일': 91, '수고': 91, '안': 91, '게': 89, '생각': 81, '감동': 79, '사랑': 78, '진심': 78, '말': 74, '그': 74, '선생님': 70, '앞': 70, '일': 70, '지금': 70, '분': 70, '팬': 69, '국민': 69, '특검': 66, '대박': 65, '제': 62, '덕분': 61, '드라마': 60, '마음': 58, '대한민국': 57, '요': 55, '모두': 53, '이제': 53, '고생': 53, '존경': 53, '맥주': 52, '다시': 52, '음식': 51, '엘지': 51, '기사': 51, '위': 50, '전': 49, '부': 49, '또': 49, '어제': 49, '형': 49, '노래': 48, '배우': 48, '이번': 47, '경기': 47, '그냥': 47, '개': 46, '날': 44, '늘': 43, '당신': 43, '요즘': 43, '팀': 42, '알': 41, '댓글': 41, '기대': 41, '좀': 41, '형님': 40, '기분': 39, '방송': 39, '얼굴': 38, '중': 37, '줄': 37, '꼭': 36, '두': 36, '집': 36, '영화': 35, '볼': 35, '난': 35, '남자': 35, '백': 35, '매력': 34, '한번': 34, '대상': 34, '못': 34, '노력': 34, '레시피': 34, '제일': 33, '시즌': 33, '해': 33, '만': 33, '그동안': 33, '보기': 33, '처음': 33, '살': 32, '감독': 32, '글': 32, '한국': 32, '대통령': 32, '시간': 31, '번': 31, '다른': 30, '마지막': 29, '하루': 29, '만세': 29, '정도': 29, '계속': 29, '둘': 28, '삼성': 28, '네': 28, '뭐': 27, '완전': 27, '위해': 27, '프로그램': 27, '맛': 26, '걸': 26, '너': 26, '눈': 26, '보': 26, '도움': 26, '모든': 26, '세계': 26, '눈물': 26, '힘': 25, '존': 25, '다행': 25, '짱': 25, '사진': 25, '레전드': 24, '끝': 24, '용기': 24, '정보': 23, '날씨': 23, '결혼': 23, '아주': 23, '아이': 23, '꿀': 23, '건': 23, '주부': 23, '함': 23, '박수': 23, '기자': 22, '준비': 22, '여자': 22, '여러분': 22, '활동': 21, '동안': 21, '언니': 21, '재미': 21, '왜': 21, '오라버니': 20, '프로': 20, '시작': 20, '다음': 20, '친구': 20, '가지': 20, '자기': 20, '임': 20, '뉴스': 19, '데': 19, '머리': 19, '역사': 19, '인생': 19, '야구': 19, '님': 18, '카페': 18, '웃음': 18, '미소': 18, '가장': 18, '매우': 18, '엄마': 18, '애': 18, '우승': 18, '갓': 18, '올해': 17, '해도': 17, '첫': 17, '선물': 17, '여기': 17, '승리': 17, '소식': 17, '복': 17, '제대로': 17, '명': 16, '희망': 16, '인정': 16, '흥': 16, '기아': 16, '거지': 16, '세상': 16, '유느님': 16, '니': 16, '최선': 16, '목소리': 16, '감격': 16, '오': 15, '감': 15, '활약': 15, '조금': 15, '원': 15, '더욱': 15, '작가': 15, '돈': 15, '가슴': 15, '아침': 15, '티브이': 15, '길': 15, '때문': 15, '연아': 15, '뒤': 14, '바로': 14, '관심': 14, '멤버': 14, '남': 14, '일본': 14, '아빠': 14, '저희': 14, '웃기': 14, '아기': 14, '속': 14, '느낌': 14, '곳': 14, '수가': 14, '후': 14, '매일': 14, '기억': 14, '대한': 14, '결정': 14, '시민': 14, '무대': 14, '편지': 13, '무한도전': 13, '콘서트': 13, '벌써': 13, '덕': 13, '잼': 13, '달': 13, '무도': 13, '온': 13, '꿈': 13, '몸': 13, '자체': 13, '감탄': 13, '준': 13, '표': 13, '미국': 13, '밥': 13, '설명': 13, '세븐': 12, '틴': 12, '등': 12, '아저씨': 12, '상': 12, '장면': 12, '주': 12, '자신': 12, '새해': 12, '어디': 12, '건강': 12, '게임': 12, '음악': 12, '인간': 12, '추천': 12, '이상': 12, '영웅': 12, '눈빛': 12, '칭찬': 12, '로서': 12, '스타일': 11, '발': 11, '첼시': 11, '사이다': 11, '사수': 11, '비': 11, '한화': 11, '환영': 11, '이름': 11, '자주': 11, '데뷔': 11, '사실': 11, '젠': 11, '이건': 11, '굿': 11, '가족': 11, '중국': 11, '최고다': 11, '말씀': 11, '몸매': 11, '어머니': 11, '진': 11, '맘': 10, '몇': 10, '크리스마스': 10, '곧': 10, '골': 10, '캬': 10, '신의': 10, '언제': 10, '촛불': 10, '점': 10, '무조건': 10, '예전': 10, '본방': 10, '예능': 10, '이후': 10, '연예인': 10, '공부': 10, '얼마': 10, '컴백': 10, '역대': 10, '박': 10, '기회': 10, '아들': 10, '정의': 10, '이야기': 10, '센스': 10, '주인공': 10, '수비': 10, '신': 10, '걱정': 10, '남자친구': 10, '아르바이트': 10, '인기': 9, '인상': 9, '혼자': 9, '곡': 9, '입장': 9, '홈런': 9, '촬영': 9, '열': 9, '누가': 9, '실력': 9, '기': 9, '힐링': 9, '배': 9, '기쁨': 9, '밤': 9, '심': 9, '외모': 9, '식이': 9, '기록': 9, '세': 9, '차': 9, '뭔가': 9, '가야': 9, '저런': 9, '시위': 9, '승승장구': 9, '상황': 9, '무엇': 9, '표현': 9, '가을': 9, '정': 9, '마음씨': 9, '조언': 9, '부상': 9, '재료': 9, '영상': 9, '피겨': 9, '클래스': 9, '미래': 9, '지지': 9, '손': 8, '거임': 8, '가요': 8, '땐': 8, '표정': 8, '기부': 8, '찬성': 8, '입': 8, '별로': 8, '집회': 8, '관리': 8, '아버지': 8, '기업': 8, '자': 8, '개월': 8, '발전': 8, '소름': 8, '군': 8, '얘기': 8, '복귀': 8, '행동': 8, '자리': 8, '법': 8, '또한': 8, '면': 8, '가입': 8, '방': 8, '리': 8, '캐릭터': 8, '오히려': 8, '누구': 8, '그대로': 8, '이유': 8, '투수': 8, '연구': 8, '스타': 8, '여러': 8,  ...

# %%
# 위 셀과 같은 결과 
words1 = dict(count1.most_common())
print(words1)
# Out:
# {'축하': 359, '정말': 316, '진짜': 303, '거': 235, '파이팅': 193, '응원': 161, '항상': 161, '오늘': 158, '최고': 157, '오빠': 156, '선수': 153, '요리': 143, '수': 140, '연기': 136, '보고': 133, '우리': 131, '때': 130, '감사': 128, '모습': 121, '더': 104, '사람': 104, '이': 102, '듯': 100, '저': 98, '역시': 94, '생일': 91, '수고': 91, '안': 91, '게': 89, '생각': 81, '감동': 79, '사랑': 78, '진심': 78, '말': 74, '그': 74, '선생님': 70, '앞': 70, '일': 70, '지금': 70, '분': 70, '팬': 69, '국민': 69, '특검': 66, '대박': 65, '제': 62, '덕분': 61, '드라마': 60, '마음': 58, '대한민국': 57, '요': 55, '모두': 53, '이제': 53, '고생': 53, '존경': 53, '맥주': 52, '다시': 52, '음식': 51, '엘지': 51, '기사': 51, '위': 50, '전': 49, '부': 49, '또': 49, '어제': 49, '형': 49, '노래': 48, '배우': 48, '이번': 47, '경기': 47, '그냥': 47, '개': 46, '날': 44, '늘': 43, '당신': 43, '요즘': 43, '팀': 42, '알': 41, '댓글': 41, '기대': 41, '좀': 41, '형님': 40, '기분': 39, '방송': 39, '얼굴': 38, '중': 37, '줄': 37, '꼭': 36, '두': 36, '집': 36, '영화': 35, '볼': 35, '난': 35, '남자': 35, '백': 35, '매력': 34, '한번': 34, '대상': 34, '못': 34, '노력': 34, '레시피': 34, '제일': 33, '시즌': 33, '해': 33, '만': 33, '그동안': 33, '보기': 33, '처음': 33, '살': 32, '감독': 32, '글': 32, '한국': 32, '대통령': 32, '시간': 31, '번': 31, '다른': 30, '마지막': 29, '하루': 29, '만세': 29, '정도': 29, '계속': 29, '둘': 28, '삼성': 28, '네': 28, '뭐': 27, '완전': 27, '위해': 27, '프로그램': 27, '맛': 26, '걸': 26, '너': 26, '눈': 26, '보': 26, '도움': 26, '모든': 26, '세계': 26, '눈물': 26, '힘': 25, '존': 25, '다행': 25, '짱': 25, '사진': 25, '레전드': 24, '끝': 24, '용기': 24, '정보': 23, '날씨': 23, '결혼': 23, '아주': 23, '아이': 23, '꿀': 23, '건': 23, '주부': 23, '함': 23, '박수': 23, '기자': 22, '준비': 22, '여자': 22, '여러분': 22, '활동': 21, '동안': 21, '언니': 21, '재미': 21, '왜': 21, '오라버니': 20, '프로': 20, '시작': 20, '다음': 20, '친구': 20, '가지': 20, '자기': 20, '임': 20, '뉴스': 19, '데': 19, '머리': 19, '역사': 19, '인생': 19, '야구': 19, '님': 18, '카페': 18, '웃음': 18, '미소': 18, '가장': 18, '매우': 18, '엄마': 18, '애': 18, '우승': 18, '갓': 18, '올해': 17, '해도': 17, '첫': 17, '선물': 17, '여기': 17, '승리': 17, '소식': 17, '복': 17, '제대로': 17, '명': 16, '희망': 16, '인정': 16, '흥': 16, '기아': 16, '거지': 16, '세상': 16, '유느님': 16, '니': 16, '최선': 16, '목소리': 16, '감격': 16, '오': 15, '감': 15, '활약': 15, '조금': 15, '원': 15, '더욱': 15, '작가': 15, '돈': 15, '가슴': 15, '아침': 15, '티브이': 15, '길': 15, '때문': 15, '연아': 15, '뒤': 14, '바로': 14, '관심': 14, '멤버': 14, '남': 14, '일본': 14, '아빠': 14, '저희': 14, '웃기': 14, '아기': 14, '속': 14, '느낌': 14, '곳': 14, '수가': 14, '후': 14, '매일': 14, '기억': 14, '대한': 14, '결정': 14, '시민': 14, '무대': 14, '편지': 13, '무한도전': 13, '콘서트': 13, '벌써': 13, '덕': 13, '잼': 13, '달': 13, '무도': 13, '온': 13, '꿈': 13, '몸': 13, '자체': 13, '감탄': 13, '준': 13, '표': 13, '미국': 13, '밥': 13, '설명': 13, '세븐': 12, '틴': 12, '등': 12, '아저씨': 12, '상': 12, '장면': 12, '주': 12, '자신': 12, '새해': 12, '어디': 12, '건강': 12, '게임': 12, '음악': 12, '인간': 12, '추천': 12, '이상': 12, '영웅': 12, '눈빛': 12, '칭찬': 12, '로서': 12, '스타일': 11, '발': 11, '첼시': 11, '사이다': 11, '사수': 11, '비': 11, '한화': 11, '환영': 11, '이름': 11, '자주': 11, '데뷔': 11, '사실': 11, '젠': 11, '이건': 11, '굿': 11, '가족': 11, '중국': 11, '최고다': 11, '말씀': 11, '몸매': 11, '어머니': 11, '진': 11, '맘': 10, '몇': 10, '크리스마스': 10, '곧': 10, '골': 10, '캬': 10, '신의': 10, '언제': 10, '촛불': 10, '점': 10, '무조건': 10, '예전': 10, '본방': 10, '예능': 10, '이후': 10, '연예인': 10, '공부': 10, '얼마': 10, '컴백': 10, '역대': 10, '박': 10, '기회': 10, '아들': 10, '정의': 10, '이야기': 10, '센스': 10, '주인공': 10, '수비': 10, '신': 10, '걱정': 10, '남자친구': 10, '아르바이트': 10, '인기': 9, '인상': 9, '혼자': 9, '곡': 9, '입장': 9, '홈런': 9, '촬영': 9, '열': 9, '누가': 9, '실력': 9, '기': 9, '힐링': 9, '배': 9, '기쁨': 9, '밤': 9, '심': 9, '외모': 9, '식이': 9, '기록': 9, '세': 9, '차': 9, '뭔가': 9, '가야': 9, '저런': 9, '시위': 9, '승승장구': 9, '상황': 9, '무엇': 9, '표현': 9, '가을': 9, '정': 9, '마음씨': 9, '조언': 9, '부상': 9, '재료': 9, '영상': 9, '피겨': 9, '클래스': 9, '미래': 9, '지지': 9, '손': 8, '거임': 8, '가요': 8, '땐': 8, '표정': 8, '기부': 8, '찬성': 8, '입': 8, '별로': 8, '집회': 8, '관리': 8, '아버지': 8, '기업': 8, '자': 8, '개월': 8, '발전': 8, '소름': 8, '군': 8, '얘기': 8, '복귀': 8, '행동': 8, '자리': 8, '법': 8, '또한': 8, '면': 8, '가입': 8, '방': 8, '리': 8, '캐릭터': 8, '오히려': 8, '누구': 8, '그대로': 8, '이유': 8, '투수': 8, '연구': 8, '스타': 8, '여러': 8, '도': 8,  ...

# %% [markdown]
# - 워드 클라우드 만들기

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud1 = WordCloud(font_path = 'C:/Windows/Fonts/NanumGothicExtraBold.ttf', 
                       background_color='white',
                       colormap = "Accent_r", 
                       width=1500, 
                       height=1000).generate_from_frequencies(words1) 

plt.imshow(wordcloud1) 
plt.axis('off') 
plt.show()
# 내 ,나, 것을 제외했지만, 여전히 수, 거, 지금과 같은 명사가 많이 나온다.
# 많이 나오기를 기대했던 고유명사(이름)은 나오지 않았기 때문에, 제외 명사를 추가해서 재진행해보겠다.

# %% [markdown]
# - png 이미지 파일로 저장
#     - 왼쪽 파일에 올라감 -> 다운로드

# %%
wordcloud1.to_file('wordcloud_happy1.png')

# %%
# 워드 클라우드 다른 방식
tags = [{'color' : color(), 'tag' : n, 'size' : c/10}\
        for n, c, in count.most_common(50)]

pytagcloud.create_tag_image(\
                            tags, 'wordcloud.png', size = (800, 600),
                            fontname = 'Noto Sans CJK')
webbrowser.open('wordcloud.png')

# %% [markdown]
# ## 2차 시도
# - 제거 : 거, 수, 보고, 때, 더, 이, 듯, 저, 안, 게, 그, 앞, 분, 제, 요, 위, 전, 날, 알, 중, 줄, 두

# %%
noun_list=[] 
for sentence in morphs :
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word) and ("나" not in word) and ("거" not in word) and ("수" not in word) and ("보고" not in word) and ("때" not in word) and ("더" not in word) and ("이" not in word) and ("듯" not in word) and ("저" not in word) and ("안" not in word) and ("게" not in word) and ("그" not in word) and ("앞" not in word) and ("분" not in word) and ("제" not in word) and ("요" not in word) and ("위" not in word) and ("전" not in word) and ("날" not in word) and ("알" not in word) and ("중" not in word) and ("줄" not in word) and ("두" not in word): 
            noun_list.append(word) 
print(noun_list)
# Out:
# ['오라버니', '우리', '주방', '마지막', '순간', '손가락', '총', '직접', '여성', '인기', '신지', '늘', '반찬', '우리', '음식', '맥주', '부', '당신', '활동', '혜택', '오션월드', '입장권', '매', '폴', '인', '러브', '축하', '응원', '사랑', '형님', '올해', '우리', '팀', '예', '축하', '생일', '진심', '축하', '축하', '차암쉽쥬', '뒤', '손', '편지', '꼭', '감회', '매력', '축하', '항상', '에너지', '힘', '우리', '선생님', '생일', '축하', '축하', '오늘', '신문', '엘지', '시즌', '포기', '생일', '한번', '역시', '프로', '축하', '하루', '하루', '명', '축하', '축하', '진짜', '정말', '딸', '바보', '항상', '일', '오빠', '웃음소리', '매번', '정보', '오늘', '바로', '세븐', '틴', '대상', '축하', '생일', '진심', '축하', '세븐', '틴', '연기', '응원', '세시', '울', '오빠', '일', '등', '신랑감', '꼭', '영화', '님', '대해', '관심', '오빠', '생일', '축하', '일과', '카페', '진짜', '우리', '오늘', '콘서트', '숙소', '일도', '우리', '응원', '외국', '응원', '인상', '형님', '생일', '진심', '축하', '축하', '팬클럽', '창', '단식', '해', '병풍', '형님', '정말', '축하', '기용', '물체', '야간', '혼자', '일단', '다른', '말', '맘', '맛', '업', '오빠', '늘', '웃음', '생일', '진심', '축하', '마음', '벌써', '시간', '오늘', '하루', '다른', '사람', '오빠', '해도', '오빠', '오빠', '오늘', '하루', '행쇼', '생일', '축하', '항상', '응원', '또', '모레', '팬미팅', '멤버', '추억', '인적', '곡', '웃음꽃', '노래', '오늘', '뮤직뱅크', '또', '세븐', '틴', '보컬', '팀', '천재', '작곡가', '생일', '축하', '항상', '당신', '응원', '부쩍', '진짜', '공개', '카페', '카페', '몇', '번', '형님', '열애설', '진짜', '라면', '축하', '오빠', '덕', '마무리', '오빠', '메리', '크리스마스', '오늘', '마무리', '또', '시작', '음식', '정말', '오빠', '무지', '우하하하', '하하', '본인', '팬', '입장', '정말', '세븐', '틴', '미소', '다음', '시즌', '도시락', '응원', '대한민국', '만세', '스포츠', '뉴스', '상', '못', '뭐', '데', '대상', '다시', '한번', '생일', '축하', '신바람', '정말', '축하', '정말', '진심', '축하', '노래', '정말', '시즌', '첫', '홈런', '축하', '다음', '시즌', '땐', '고', '곧', '생일', '우히히', '시험', '편지', '노래', '꼭', '홍홍홍', '홍왜', '면서', '축하', '하하', '결혼', '축하', '오늘', '진짜', '진짜', '축하', '생일', '축하', '오빠', '생일', '축하', '크리스마스', '선물', '진짜', '절대', '폼', '귀신', '다시', '골', '머신', '기자', '싱글벙글', '곧', '댓글', '개', '유명', '짤', '탄생', '역시', '축하', '명', '은', '희망', '엘지', '사람', '오늘', '촬영', '존', '또', '걸', '축하', '올해', '케', '베스', '누굴', '인정', '캬', '장관', '자연', '움', '시작', '오', '엠', '비시', '자네', '연예', '악플러', '기상캐스터', '머리', '짐작', '여기', '댓글', '아주', '난리', '대박', '인물', '곱', '맘씨', '최고', '너', '진짜', '인정', '재능', '진짜', '노래', '지금', '정말', '다시', '재결합', '기대', '결혼', '어머님', '표정', '진짜', '진짜', '리얼', '표정', '오락가락', '양호', '질', '프로', '폐지', '정말', '대한민국', '만세', '진짜', '고생', '정말', '후반', '신의', '친구', '가장', '생각', '지금', '정말', '삼촌', '축하', '형님', '진짜', '개', '늘', '경기', '기대', '뒤', '살', '다행', '고향', '울진', '땐', '사무실', '짱', '흥', '풍악', '축하', '배우', '범죄', '구단', '엔씨', '축하', '정말', '톱', '타자', '경기', '가면', '시즌', '우리', '승리', '연기', '호감', '연기', '연기', '사생활', '사생활', '일', '뿐', '축하', '오', '열', '일', '축하', '매우', '맑음', '기부', '천사', '오늘', '머', '머리', '재', '희소식', '노벨상', '감', '연기', '조기', '대처', '기장', '및', '승무원', '지시', '승객', '오늘', '데', '축하', '흥', '흥', '오늘', '음원', '힘', '추진', '찬성', '정말', '리액션', '얼굴', '마음', '우리', '언니', '응원', '연말', '배우', '볼', '기아', '입', '기아', '팬', '대상', '축하', '무한상사', '야유회', '정말', '정도', '활약', '난', '코빅', '고정', '가라', '별로', '머리', '스타일', '초딩', '불', '초딩', '샷', '바', '성격', '보임', '얼굴', '행쇼', '공민왕', '후손', '연기', '인정', '매력', '천사', '관계', '유지', '결혼', '가면', '차우찬', '가지', '지레', '발', '좀', '박자', '문관', '둘', '오늘', '집회', '촛불', '소', '등', '최강', '명', '핸드폰', '증보', '핀', '인증', '아주', '조금', '임신', '누가', '둘', '성인', '축하', '항상', '응원', '연기', '축하', '특검', '기아', '승리', '오늘', '남', '불행', '웃음', '바로', '흥', '진짜', '자기', '관리', '최고', '움', '축하', '기사', '개', '꿀', '잼', '주사', '기능', '통과', '도로', '주행', '통과', '후진', '통과', '개꿀띠', '몰입', '만', '드라마', '연기', '노래', '원', '사서', '달', '출퇴근', '값', '배우', '응원', '진짜', '골키퍼', '하드', '케리', '승점', '점', '우리', '건', '크롬', '무조건', '번', '우리', '아버지', '슬슬', '욕', '시작', '폭스바겐', '삼류', '기업', '서비스', '질', '무조건', '술', '냉장고', '볼', '일본', '사연', '드라마', '축하', '언니', '응원', '꼭', '대상', '첼시', '감독', '대왕', '기대', '역시', '실력', '자', '만', '무도', '개월', '금메달', '감', '악마', '연기', '선곡', '진짜', '신의', '건', '진짜', '구속', '흥', '축하', '다시', '기자', '역시', '쭉쭉', '티베트', '가기', '오', '영화', '항상', '응원', '기사', '본방', '역시', '명', '불허', '박효갓', '족발', '예약', '시간', '재미', '진짜', '눈', '시간', '드라마', '재미', '기', '다행', '응원', '배우', '본방', '비', '촉촉', '프로야구', '라운드', '매력', '아빠', '자랑', '생각', '진짜', '마지막', '삿포로', '맥주', '축하', '다축', '하', '여태', '의학', '드라마', '단연', '최고', '활동', '배추', '머리',  ...

# %%
count = Counter(noun_list)
print(count)
# Out:
# Counter({'축하': 359, '정말': 316, '진짜': 303, '응원': 161, '항상': 161, '오늘': 158, '최고': 157, '오빠': 156, '연기': 136, '우리': 131, '감사': 128, '모습': 121, '사람': 104, '역시': 94, '생일': 91, '생각': 81, '감동': 79, '사랑': 78, '진심': 78, '말': 74, '선생님': 70, '일': 70, '지금': 70, '팬': 69, '국민': 69, '특검': 66, '대박': 65, '드라마': 60, '마음': 58, '대한민국': 57, '고생': 53, '존경': 53, '맥주': 52, '다시': 52, '음식': 51, '엘지': 51, '기사': 51, '부': 49, '또': 49, '형': 49, '노래': 48, '배우': 48, '경기': 47, '개': 46, '늘': 43, '당신': 43, '팀': 42, '댓글': 41, '기대': 41, '좀': 41, '형님': 40, '방송': 39, '얼굴': 38, '꼭': 36, '집': 36, '영화': 35, '볼': 35, '난': 35, '남자': 35, '백': 35, '매력': 34, '한번': 34, '대상': 34, '못': 34, '노력': 34, '레시피': 34, '시즌': 33, '해': 33, '만': 33, '보기': 33, '처음': 33, '살': 32, '감독': 32, '글': 32, '한국': 32, '대통령': 32, '시간': 31, '번': 31, '다른': 30, '마지막': 29, '하루': 29, '만세': 29, '정도': 29, '계속': 29, '둘': 28, '삼성': 28, '네': 28, '뭐': 27, '맛': 26, '걸': 26, '너': 26, '눈': 26, '보': 26, '도움': 26, '모든': 26, '세계': 26, '눈물': 26, '힘': 25, '존': 25, '다행': 25, '짱': 25, '사진': 25, '끝': 24, '용기': 24, '정보': 23, '결혼': 23, '아주': 23, '꿀': 23, '건': 23, '주부': 23, '함': 23, '기자': 22, '준비': 22, '여자': 22, '활동': 21, '언니': 21, '재미': 21, '왜': 21, '오라버니': 20, '프로': 20, '시작': 20, '다음': 20, '친구': 20, '가지': 20, '자기': 20, '임': 20, '뉴스': 19, '데': 19, '머리': 19, '역사': 19, '인생': 19, '야구': 19, '님': 18, '카페': 18, '웃음': 18, '미소': 18, '가장': 18, '매우': 18, '엄마': 18, '애': 18, '우승': 18, '갓': 18, '올해': 17, '해도': 17, '첫': 17, '선물': 17, '여기': 17, '승리': 17, '소식': 17, '복': 17, '명': 16, '희망': 16, '인정': 16, '흥': 16, '기아': 16, '세상': 16, '유느님': 16, '니': 16, '최선': 16, '목소리': 16, '감격': 16, '오': 15, '감': 15, '활약': 15, '조금': 15, '원': 15, '작가': 15, '돈': 15, '가슴': 15, '아침': 15, '길': 15, '연아': 15, '뒤': 14, '바로': 14, '관심': 14, '멤버': 14, '남': 14, '일본': 14, '아빠': 14, '웃기': 14, '아기': 14, '속': 14, '느낌': 14, '곳': 14, '후': 14, '매일': 14, '기억': 14, '대한': 14, '결정': 14, '시민': 14, '무대': 14, '편지': 13, '콘서트': 13, '벌써': 13, '덕': 13, '잼': 13, '달': 13, '무도': 13, '온': 13, '꿈': 13, '몸': 13, '자체': 13, '감탄': 13, '준': 13, '표': 13, '미국': 13, '밥': 13, '설명': 13, '세븐': 12, '틴': 12, '등': 12, '상': 12, '장면': 12, '주': 12, '자신': 12, '새해': 12, '어디': 12, '건강': 12, '음악': 12, '인간': 12, '추천': 12, '영웅': 12, '눈빛': 12, '칭찬': 12, '로서': 12, '스타일': 11, '발': 11, '첼시': 11, '비': 11, '한화': 11, '환영': 11, '자주': 11, '데뷔': 11, '사실': 11, '젠': 11, '굿': 11, '가족': 11, '최고다': 11, '말씀': 11, '몸매': 11, '어머니': 11, '진': 11, '맘': 10, '몇': 10, '크리스마스': 10, '곧': 10, '골': 10, '캬': 10, '신의': 10, '촛불': 10, '점': 10, '무조건': 10, '본방': 10, '예능': 10, '연예인': 10, '공부': 10, '얼마': 10, '컴백': 10, '역대': 10, '박': 10, '기회': 10, '아들': 10, '정의': 10, '센스': 10, '주인공': 10, '신': 10, '걱정': 10, '남자친구': 10, '인기': 9, '인상': 9, '혼자': 9, '곡': 9, '입장': 9, '홈런': 9, '촬영': 9, '열': 9, '누가': 9, '실력': 9, '기': 9, '힐링': 9, '배': 9, '기쁨': 9, '밤': 9, '심': 9, '외모': 9, '기록': 9, '세': 9, '차': 9, '뭔가': 9, '가야': 9, '승승장구': 9, '상황': 9, '무엇': 9, '표현': 9, '가을': 9, '정': 9, '마음씨': 9, '조언': 9, '부상': 9, '재료': 9, '영상': 9, '피겨': 9, '클래스': 9, '미래': 9, '지지': 9, '손': 8, '땐': 8, '표정': 8, '기부': 8, '찬성': 8, '입': 8, '별로': 8, '집회': 8, '관리': 8, '아버지': 8, '기업': 8, '자': 8, '개월': 8, '소름': 8, '군': 8, '얘기': 8, '복귀': 8, '행동': 8, '자리': 8, '법': 8, '또한': 8, '면': 8, '가입': 8, '방': 8, '리': 8, '캐릭터': 8, '오히려': 8, '누구': 8, '연구': 8, '스타': 8, '여러': 8, '도': 8, '구': 8, '연습': 8, '인성': 8, '삶': 8, '민주주의': 8, '경찰': 8, '막': 8, '진정': 8, '택배': 8, '방법': 8, '초보': 8, '작품': 8, '출연': 8, '시': 8, '인': 7, '라면': 7, '무지': 7, '움': 7, '어머님': 7, '천사': 7, '임신': 7, '욕': 7, '존재': 7, '비주': 7, '케미': 7, '생활': 7, '면접': 7, '커플': 7, '결과': 7, '서로': 7, '시기': 7, '정리': 7, '하늘': 7, '올림픽': 7, '테': 7, '무': 7, '놈': 7, '무슨': 7, '우린': 7, '국가': 7, '사극': 7, '소리': 7, '연출': 7, '정신': 7, '운동': 7, '아가': 7, '주신': 7, '빛': 7, '지원': 7, '마': 7, '월드': 7, '군인': 7, '모로': 7, '개인': 7, '학생': 7, '일만': 7, '양': 7, '폭발': 7, '손님': 7, '주시': 7, '남편': 7, '자신감': 7, '옆': 7, '순간': 6, '반찬': 6, '딸': 6, '매번': 6, '울': 6, '대해': 6, '일단': 6, '추억': 6, '공개': 6, '하하': 6, '고': 6, '탄생': 6, '인물': 6, '재능': 6, '가면': 6, '성격': 6, '금메달': 6, '카리스마': 6, '축구': 6, '암': 6, '해주시': 6, '의 ...

# %%
# value값 내림차순 정렬 : 위 셀과 같은 출력이네
import operator
sort_count = sorted(count.items(), key = operator.itemgetter(1), reverse = True)
print(sort_count)
# Out:
# [('축하', 359), ('정말', 316), ('진짜', 303), ('응원', 161), ('항상', 161), ('오늘', 158), ('최고', 157), ('오빠', 156), ('연기', 136), ('우리', 131), ('감사', 128), ('모습', 121), ('사람', 104), ('역시', 94), ('생일', 91), ('생각', 81), ('감동', 79), ('사랑', 78), ('진심', 78), ('말', 74), ('선생님', 70), ('일', 70), ('지금', 70), ('팬', 69), ('국민', 69), ('특검', 66), ('대박', 65), ('드라마', 60), ('마음', 58), ('대한민국', 57), ('고생', 53), ('존경', 53), ('맥주', 52), ('다시', 52), ('음식', 51), ('엘지', 51), ('기사', 51), ('부', 49), ('또', 49), ('형', 49), ('노래', 48), ('배우', 48), ('경기', 47), ('개', 46), ('늘', 43), ('당신', 43), ('팀', 42), ('댓글', 41), ('기대', 41), ('좀', 41), ('형님', 40), ('방송', 39), ('얼굴', 38), ('꼭', 36), ('집', 36), ('영화', 35), ('볼', 35), ('난', 35), ('남자', 35), ('백', 35), ('매력', 34), ('한번', 34), ('대상', 34), ('못', 34), ('노력', 34), ('레시피', 34), ('시즌', 33), ('해', 33), ('만', 33), ('보기', 33), ('처음', 33), ('살', 32), ('감독', 32), ('글', 32), ('한국', 32), ('대통령', 32), ('시간', 31), ('번', 31), ('다른', 30), ('마지막', 29), ('하루', 29), ('만세', 29), ('정도', 29), ('계속', 29), ('둘', 28), ('삼성', 28), ('네', 28), ('뭐', 27), ('맛', 26), ('걸', 26), ('너', 26), ('눈', 26), ('보', 26), ('도움', 26), ('모든', 26), ('세계', 26), ('눈물', 26), ('힘', 25), ('존', 25), ('다행', 25), ('짱', 25), ('사진', 25), ('끝', 24), ('용기', 24), ('정보', 23), ('결혼', 23), ('아주', 23), ('꿀', 23), ('건', 23), ('주부', 23), ('함', 23), ('기자', 22), ('준비', 22), ('여자', 22), ('활동', 21), ('언니', 21), ('재미', 21), ('왜', 21), ('오라버니', 20), ('프로', 20), ('시작', 20), ('다음', 20), ('친구', 20), ('가지', 20), ('자기', 20), ('임', 20), ('뉴스', 19), ('데', 19), ('머리', 19), ('역사', 19), ('인생', 19), ('야구', 19), ('님', 18), ('카페', 18), ('웃음', 18), ('미소', 18), ('가장', 18), ('매우', 18), ('엄마', 18), ('애', 18), ('우승', 18), ('갓', 18), ('올해', 17), ('해도', 17), ('첫', 17), ('선물', 17), ('여기', 17), ('승리', 17), ('소식', 17), ('복', 17), ('명', 16), ('희망', 16), ('인정', 16), ('흥', 16), ('기아', 16), ('세상', 16), ('유느님', 16), ('니', 16), ('최선', 16), ('목소리', 16), ('감격', 16), ('오', 15), ('감', 15), ('활약', 15), ('조금', 15), ('원', 15), ('작가', 15), ('돈', 15), ('가슴', 15), ('아침', 15), ('길', 15), ('연아', 15), ('뒤', 14), ('바로', 14), ('관심', 14), ('멤버', 14), ('남', 14), ('일본', 14), ('아빠', 14), ('웃기', 14), ('아기', 14), ('속', 14), ('느낌', 14), ('곳', 14), ('후', 14), ('매일', 14), ('기억', 14), ('대한', 14), ('결정', 14), ('시민', 14), ('무대', 14), ('편지', 13), ('콘서트', 13), ('벌써', 13), ('덕', 13), ('잼', 13), ('달', 13), ('무도', 13), ('온', 13), ('꿈', 13), ('몸', 13), ('자체', 13), ('감탄', 13), ('준', 13), ('표', 13), ('미국', 13), ('밥', 13), ('설명', 13), ('세븐', 12), ('틴', 12), ('등', 12), ('상', 12), ('장면', 12), ('주', 12), ('자신', 12), ('새해', 12), ('어디', 12), ('건강', 12), ('음악', 12), ('인간', 12), ('추천', 12), ('영웅', 12), ('눈빛', 12), ('칭찬', 12), ('로서', 12), ('스타일', 11), ('발', 11), ('첼시', 11), ('비', 11), ('한화', 11), ('환영', 11), ('자주', 11), ('데뷔', 11), ('사실', 11), ('젠', 11), ('굿', 11), ('가족', 11), ('최고다', 11), ('말씀', 11), ('몸매', 11), ('어머니', 11), ('진', 11), ('맘', 10), ('몇', 10), ('크리스마스', 10), ('곧', 10), ('골', 10), ('캬', 10), ('신의', 10), ('촛불', 10), ('점', 10), ('무조건', 10), ('본방', 10), ('예능', 10), ('연예인', 10), ('공부', 10), ('얼마', 10), ('컴백', 10), ('역대', 10), ('박', 10), ('기회', 10), ('아들', 10), ('정의', 10), ('센스', 10), ('주인공', 10), ('신', 10), ('걱정', 10), ('남자친구', 10), ('인기', 9), ('인상', 9), ('혼자', 9), ('곡', 9), ('입장', 9), ('홈런', 9), ('촬영', 9), ('열', 9), ('누가', 9), ('실력', 9), ('기', 9), ('힐링', 9), ('배', 9), ('기쁨', 9), ('밤', 9), ('심', 9), ('외모', 9), ('기록', 9), ('세', 9), ('차', 9), ('뭔가', 9), ('가야', 9), ('승승장구', 9), ('상황', 9), ('무엇', 9), ('표현', 9), ('가을', 9), ('정', 9), ('마음씨', 9), ('조언', 9), ('부상', 9), ('재료', 9), ('영상', 9), ('피겨', 9), ('클래스', 9), ('미래', 9), ('지지', 9), ('손', 8), ('땐', 8), ('표정', 8), ('기부', 8), ('찬성', 8), ('입', 8), ('별로', 8), ('집회', 8), ('관리', 8), ('아버지', 8), ('기업', 8), ('자', 8), ('개월', 8), ('소름', 8), ('군', 8), ('얘기', 8), ('복귀', 8), ('행동', 8), ('자리', 8), ('법', 8), ('또한', 8), ('면', 8), ('가입', 8), ('방', 8), ('리', 8), ('캐릭터', 8), ('오히려', 8), ('누구', 8), ('연구', 8), ('스타', 8), ('여러', 8), ('도', 8), ('구', 8), ('연습', 8), ('인성', 8), ('삶', 8), ('민주주의', 8), ('경찰', 8), ('막', 8), ('진정',  ...

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/NanumGothicExtraBold.ttf', 
                      background_color='white',
                      colormap = "Accent_r", 
                      width=1500, 
                      height=1000).generate_from_frequencies(count) 

plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()
# 고유명사는 특검, 연아, 삼성, 엘지, 기아 정도?

# %% [markdown]
# - png 이미지 파일로 저장
#     - 왼쪽 파일에 올라감 -> 다운로드

# %%
wordcloud.to_file('wordcloud_happy2.png')

# %% [markdown]
# ## 3차 시도
# - 일반명사와 고유명사만 뽑아오기

# %%
# 왼쪽 파일에 텍스트 파일 올려 놓고 불러올 수 있다.
file = open('one_off_conversation_happy_for_konlpy.txt','r')

lists = file.readlines()

file.close()

lists
# Out:
# ['오라버니 해피투게더 봤어요\n',
#  '우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다\n',
#  '웃긴 거 알죠\n',
#  '덕분에 주방에서 요리하는 게 엄청 좋아졌어요\n',
#  '마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다\n',
#  '어떻게 여성 요리사보다 더 인기가 많으신지 저도 늘 반찬 만들 때 따라 하고 있답니다\n',
#  '우리에게 맛있는 음식을 전하시는 맥주 부님 당신 멋져\n',
#  '활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러브\n',
#  '그리고 100일도 축하해요\n',
#  '응원합니다 그리고 사랑합니다 파이팅\n',
#  '형님이 올해 우리 팀으로 온다고 해서 얼마나 기뻤는지 몰라요\n',
#  '예 500일 축하해요\n',
#  '생일 진심으로 축하해요\n',
#  '축하\n',
#  '요리가 차암쉽쥬\n',
#  '10년 뒤 손 편지 쓰고 꼭 이 감회도 갈게요\n',
#  '요리의 매력에 빠졌어요\n',
#  '300일 너무너무 축하해요\n',
#  '항상 밝은 에너지 덕분에 힘이 납니다\n',
#  '대단하신 우리 선생님 파이팅요\n',
#  '파이팅\n',
#  '제일처럼 기쁘고 좋은데\n',
#  '생일 축하해요\n',
#  '덕분에 요리가 즐거워요\n',
#  '800일 축하해요\n',
#  '이런 오늘 신문을 보니 엘지가 올 시즌을 포기한다고 나왔더라고요\n',
#  '내일 생일이라 한번 가보려고요\n',
#  '너무너무 좋아요\n',
#  '역시 프로입니다\n',
#  '1위 한 것 너무 축하해요♡\n',
#  '앞으로 언제나 함께 있을게요\n',
#  '건강한 하루요\n',
#  '하루에 2만 명 넘고 너무 좋겠네요\n',
#  '7500일 축하해요\n',
#  '축하드려요\n',
#  '그게 훨씬 귀엽고 더 어려 보여요 진짜\n',
#  '정말 행복해요\n',
#  '딸 바보 되시겠네요\n',
#  '파이팅\n',
#  '파이팅\n',
#  '항상 좋은 일 있길 바랄게요\n',
#  '오빠의 유쾌한 웃음소리가 들리는듯하네요\n',
#  '선수 파이팅\n',
#  '매번 좋은 정보감사합니다\n',
#  '오늘 이 600일이 되는 날이에요♡♡\n',
#  '오늘이 바로 세븐틴 700일이 되는 날이에요\n',
#  '대상 수상 축하해요\n',
#  '생일 진심 축하드려요\n',
#  '세븐틴 예쁘다\n',
#  '무한도전에서 연기 너무 잘 하셨어요\n',
#  '자랑스럽네요\n',
#  '응원할게요\n',
#  '요즘 대세시죠\n',
#  '울 오빠는 일 등 신랑감\n',
#  '꼭 봤으면 하는 영화 1위\n',
#  '님을 보고 요리에 대해 관심이 생겼어요\n',
#  '오빠 생일 축하해요\n',
#  '일과처럼 들어오는 카페가 되었네요\n',
#  '나이에 상관없이 진짜 열심히 뛰어주는 우리 아저씨 파이팅입니다\n',
#  '오늘 콘서트 했는데 다치지 말고 숙소 잘 들어가요\n',
#  '날씨는 춥고 행복한 일도 없지만 그래도 우리 모두 파이팅입니다\n',
#  '님 응원도 하고요\n',
#  '나도 외국에서 응원할게\n',
#  '게다가 위트도 있으시고 편안한 인상 너무 좋습니다\n',
#  '형님의 생일을 진심으로 축하축하합니다\n',
#  '팬클럽 창단식 해요\n',
#  '어색하면서도 건방지지만 병풍 같은 형님 정말 축하드립니다\n',
#  '이번에 1루수로 기용하신 것 너무 잘하셨네요\n',
#  '너무 반갑습니다\n',
#  '움직이는 물체를 100 잡아내니 야간에 가게에 혼자 있어서 무섭지가 않아요\n',
#  '일단 다른 말이 필요 없을 듯님 수고하셨습니다\n',
#  '기분 좋은 맘으로 요리를 하면 맛도 업\n',
#  '오빠가 선수의 위치에서 떠나는 그날까지\n',
#  '늘 웃음을 주는 님 생일을 진심으로 축하합니다\n',
#  '마음도 넓고 굳세니 잘할 거임\n',
#  '벌써 9월 5일이라는 시간이 다가왔네요\n',
#  '오늘 하루도 수고하셨어요\n',
#  '다른 사람들이 오빠 보고 다진 상이라고 해도 전 오빠를 좋아할 거예요\n',
#  '그럼 오빠 오늘 하루도행쇼\n',
#  '누나 생일 축하드려요\n',
#  '항상 응원합니다\n',
#  '내일과 또 제가 가는 내일모레 팬미팅도 멤버들과 함께 즐거운 추억 많이 만들어요\n',
#  '전개 인적으로 수록곡 중에 웃음꽃이라는 노래가 참 좋은데 오늘 뮤직뱅크에서 이렇게 들으니까 또 기분이 새롭네요\n',
#  '세븐틴 보컬팀 리더 천재 작곡가 생일 축하해요\n',
#  '파이팅 선수 항상 당신을 응원합니다\n',
#  '요즘 부쩍\n',
#  '진짜 많이 기다렸던 공개 카페가 드디어 열렸어요\n',
#  '카페에서 몇 번 뵈었죠\n',
#  '형님이 열애설이 진짜라면 축하드리고요\n',
#  '오빠들 덕에 재미있는 크리스마스이브가 이렇게 마무리돼서 기쁘고 오빠들도 메리 크리스마스\n',
#  '오늘은 무한도전하는 날\n',
#  '2016년 마무리 이쁘게 하고 2017년은 또 새롭게 같이 시작해봐요\n',
#  '음식도 웃으면서 기분 좋게 만들어야 더 맛있죠\n',
#  '같이 가요\n',
#  '님 멋지세요\n',
#  '정말 재미있어요\n',
#  '저도 오빠 무지 좋아해요\n',
#  '우하하하 하하하 그럼\n',
#  '본인이 만족하고 행복해하니 팬 입장으로서도 뿌듯하네요\n',
#  '정말 멋졌어요\n',
#  '태어나 줘서 너무 고맙고 세븐틴이어서 너무 고마워요\n',
#  '너무도 이쁘고 멋진 미소이심\n',
#  '다음 시즌 때는 도시락 싸 들고 응원 갈게요\n',
#  '파이팅 대한민국 만세\n',
#  '요즘은 스포츠 뉴스를 보면 너무 기분 좋은 거 있죠\n',
#  '최우수 상은커녕 우수상도 못 받으셔서 mbc 뭐 이런 데가 다 있나 했더니 대상을 받으실 줄이야\n',
#  '다시 한번 생일 축하하고\n',
#  '신바람 나는 LG\n',
#  '400일 정말 축하해\n',
#  '하지만 괜찮아요\n',
#  '정말 진심으로 축하드려요\n',
#  '그리고 밸런타인데이♡\n',
#  '노래 정말 좋고 수고했어요\n',
#  '암튼 올 시즌 첫 홈런 축하드립니다\n',
#  '다음 시즌 땐 고\n',
#  '게다가 곧 있으면 생일\n',
#  '우히히 어제 무한도전 너무 재밌게 봤어요\n',
#  '내일 시험 끝나니까 내일 편지는 더 길게 쓸게요\n',
#  '그리고 열심히 노래 들어서 꼭 1등 시켜줄게요\n',
#  '홍홍홍 홍왜 이렇게 잘 생겨졌냐면서\n',
#  '아쉽지만 축하해요\n',
#  '하하하 결혼도 축하하고요\n',
#  '안녕 오늘 더쇼 1위 진짜 진짜 축하하고\n',
#  '생일 축하해요\n',
#  '1시간 동안 재밌게 잘 볼게요\n',
#  '오빠 생일 축하해요\n',
#  '잊지 못할 크리스마스 선물 줘서 진짜 고맙고 앞으로도 절대 잊지 못할 것 같아요\n',
#  '이제 확실히 폼 떨어진 줄 알았더니 귀신같이 다시 골 머신 됨\n',
#  '기자 싱글벙글 곧 댓글 1500개\n',
#  '유명 짤 하나 탄생했네\n',
#  '역시\n',
#  '축하합니다 행복하세요\n',
#  '나이스 4명 깔았다\n',
#  '이 젊은이들이 있기에 아직은 희망을 가져봅니다\n',
#  '엘지 져서 기분 좋은 사람\n',
#  '파이팅\n',
#  '덕분에 너무 재미있었음\n',
#  '오늘 촬영하는 거 봤는데 존 나 잘생김\n',
#  '봐라 얼마나 억울하냐\n',
#  '또 이걸 해냅니다\n',
#  '축하해요\n',
#  '올해는 케 베스의 하였네 누굴 줘도 이상하지 않아다 인정이야\n',
#  '캬 장관이고 자연의 아름다움이 느껴지네\n',
#  '이제 시작이다\n',
#  '오 엠비시 자네 왔는가\n',
#  '연예인들 전부 이러면 악플러들 많이 사라질 텐데 잘했다\n',
#  '기상캐스터 머리 보니 날씨 짐작이 갑니다\n',
#  '여기 댓글도 아주 난리 났네 대박 나자\n',
#  '인물도 곱고 맘씨도 아름다워라♡♡♡\n',
#  '최고\n',
#  '너 진짜 웃겨 인정 이제야 재능을 살리는 듯\n',
#  '진짜 이쁘다\n',
#  '노래는 지금 들어도 정말 좋은데 다시 재결합을 한다니까 너무 기대되네요\n',
#  '잘 되어서 기분 좋네\n',
#  '너무 귀엽고 웃김\n',
#  '결혼하고 싶어요\n',
#  '어머님들 표정이 진짜 재밌었음 진짜 리얼 표정\n',
#  '오락가락이 붙었다\n',
#  '우리나라는 양호한 거네 위로가 된다\n',
#  '이런 저질 프로가 폐지되어서 정말 행복합니다 대한민국 만세\n',
#  '진짜 고생했다 받을만했음\n',
#  '정말 대단하고 멋지십니다\n',
#  '후반에 중앙이 동이 신의 한 수였다\n',
#  '나도 친구분처럼 가장 웃기다고 생각했었는데 지금은 정말 멋있는 개그맨이 된 듯\n',
#  '삼촌 축하해요♡\n',
#  '아는 형님 진짜 개 재밌음\n',
#  '언제 봐도 늘 멋져요♡\n',
#  '경기가 기대된다\n',
#  '18년 뒤면 그래도 살아 잇네 다행\n',
#  '힘내세요\n',
#  '내 고향 울진\n',
#  '더울 땐 사무실이 짱\n',
#  '흥해라\n',
#  '풍악을 울려라\n',
#  '오호호호 내일 하는군요\n',
#  '파이팅\n',
#  '축하합니다\n',
#  '요즘 배우 참 이쁘던데\n',
#  '신범죄 구단 엔씨 축하한다\n',
#  '정말 국내에선 톱타자보다 못했으나 국제경기에 가면 상당히 강했나 보네 내년 시즌 기대해도 좋다\n',
#  '미안하다 우리가 승리다\n',
#  '연기 너무 잘하셔서 호감\n',
#  '연기는 연기고 사생활은 사생활일 뿐 축하\n',
#  '오 드디어 열 일하는\n',
#  '축하드려요\n',
#  '대전 날씨 매우 맑음\n',
#  '똑똑하다 그랬는데\n',
#  '기부천사\n',
#  '어제 너무 재밌게 봤어요 오늘도 기대합니다\n',
#  '머 머리 아재들 희소식 노벨상감\n',
#  '파이팅\n',
#  '연기 너무 잘해요\n',
#  '조기에 빠른 대처를 하신 기장 및 승무원 그리고 지시에 따라주신 승객까지 모두 잘하셨습니다\n',
#  '오늘 지렸다\n',
#  '보면서 너무 흐뭇함\n',
#  '너무 잘하는 데 더 더 잘 되라\n',
#  '축하드려요\n',
#  '흥해라 흥해라\n',
#  '오늘 12시에 음원 나와요 많이 들어주세요\n',
#  '좋아요 맨날 들어야지 힘\n',
#  '멋지다 추진력\n',
#  '수술 찬성할 때 정말 리액션 귀여웠음\n',
#  '얼굴부터 마음까지 예쁜 우리 언니 응원할게요\n',
#  '연말에 배우 볼 수 있다 좋다\n',
#  '기아가 영입할 듯 35년 기아 팬이\n',
#  '대상 축하드립니다\n',
#  '무한상사 야유회 때 정말 웃겼는데 아쉽네요\n',
#  '이 나이에 이 정도 활약하는 거 보면 전성기 때 epl 갔으면 씹어 먹었을 듯\n',
#  '난 코빅에서부터 좋았어 이대로 고정까지 가라근데 안티가 별로 없네 머리 스타일이 초딩 같음까 불까 불한 초딩\n',
#  '나이스 샷\n',
#  '이태원 바에서 봤는데 성격 엄청 좋아 보임 물론 얼굴도 예쁨행쇼\n',
#  '공민왕 후손인가\n',
#  '연기 인정하죠 매력적이고\n',
#  '너무도 착하고 천사 같은 파이팅\n',
#  '좋은 관계 잘 유지하세요 결혼까지 가면 좋지만\n',
#  '차우찬 가지고 지레 발은 좀 너무하지 않냐\n',
#  '어딜 가나 박자 놓치는 고문관 한 둘은 나오는데 오늘 집회 촛불 소 등 완벽했음\n',
#  '물들어오니까 제트엔진 달았네\n',
#  '여전히 두산이 최강이네 이리 보고 저리 봐도 4명이 다 잘해\n',
#  '핸드폰인 증보다 아이 핀 인증이 아주 조금 더 편하더라\n',
#  '임신이면 누가 뭐라 하냐 둘 다 성인인데 축하할 일이지\n',
#  '아직도 안 믿기지만 항상 응원할게♡♡♡\n',
#  '연기 너무 잘해요 너무 보고 싶어요\n',
#  '수상 축하드립니다\n',
#  '기대기대 믿고 봅니다♡\n',
#  '앞으로 많이 행복하자\n',
#  '특검 잘하고 있다\n',
#  '기아가 승리한다\n',
#  '멋지다 파이팅 오래 살아라\n',
#  '오늘도 남의 불행에 저절로 웃음이 나옵니다\n',
#  '저거다 저게 바로 내가 기다리던 내 햄버거야\n',
#  '이쁘다 잘 되어서 흥하길\n',
#  '이거 보면 진짜 자기관리가 대단하다 최고의 선수다움\n',
#  '추워서 좋다\n',
#  '축하해 ♡ ♡♡\n',
#  '이 기사 개 꿀 잼\n',
#  '졸아웃긴다 주사\n',
#  '어려워지기 전에 기능통과하고 쉬워진 도로 주행 통과 후진 따위 안하고 통과앙 개꿀띠\n',
#  '너무 몰입되어서 오랜만에 좋은 드라마 봅니다 연기를 너무 잘하세요\n',
#  '노래가 좋아\n',
#  '멋진\n',
#  '6만 원짜리 중고자전거 사서 3달째 출퇴근하는데 배도 들어가고 자전거 값은 뽑음\n',
#  '너무 신선하고 재밌어서\n',
#  '배우 응원하고 기대합니다\n',
#  '진짜 골키퍼 하드 케리로 승점 5점 땄네\n',
#  '우리 집은 xp 아직도 잘 쓰는 중 사이트 안되는 건 크롬 써서 하고\n',
#  '봐라 결국 돌아오잖니\n',
#  '감사합니다\n',
#  '무조건 1번을 외치던 우리 아버지도 이제 슬슬 욕하기 시작\n',
#  '폭스바겐 같은 삼류 기업이랑은 as나 서비스의 질이 틀리구먼 허허\n',
#  '무조건 본다 파이팅\n',
#  '예전에 술 마시고 냉장고에 볼 일본 사연 웃겼는데\n',
#  '대 놓고 ppl이 어색하지 않은 이상한 드라마\n',
#  '축하해요 언니\n',
#  '응원합니다 꼭 대상 받으시길\n',
#  '첼시가 이길 텐데\n',
#  '믿고 보는 감독님 빨리 보고 싶다\n',
#  '기대기 대왕 기대\n',
#  '역시 실력자들\n',
#  '오랜만에 시원하다\n',
#  '완전 귀요미\n',
#  '무도는 레전드만 내보내도 6개월은 때울 수 있음\n',
#  '멋져 멋져다 멋져\n',
#  '멋지다 금메달감이다\n',
#  '악마의 연기 선곡은 진짜 신의 한 수 중간에 흉내 내는 건 진짜\n',
#  '구속 안 된 게 내가 기분이 좋네\n',
#  '더더더 흥해라\n',
#  '축하드려 요♡♡\n',
#  '사이다다\n',
#  '속이 다시 원합니다\n',
#  '기자님 예쁘세요\n',
#  '역시 알아서 잘해주네요 쭉쭉 갑시다\n',
#  '티베트 가기 편하겠네\n',
#  '오 그렇네 재밌었던 영화\n',
#  '막내야 돌아와서 반가웠어 앞으로 더 분발하자\n',
#  '날씨 좋다\n',
#  '파이팅 항상 응원할게요\n',
#  '기사를 잘 쓰시네요 본방사수\n',
#  '역시 명불허 전 박효갓\n',
#  '족발 예약한 시간 됐구나\n',
#  '재미나겠어요 파이팅\n',
#  '진짜 눈 깜빡이는 시간도 아까운 드라마\n',
#  '나오니 더욱 재미나겠네요 기다려집니다\n',
#  '회복하셨다니 다행입니다 응원합니다\n',
#  '믿고 보는 배우 본방사수\n',
#  '비가 촉촉이 와서 좋네요\n',
#  '프로야구 발전을 위해서 1라운드만 하기로 했습니다\n',
#  '잘생겼다 귀엽고 섹시하고 매력이 많아\n',
#  '대단하다 대단해\n',
#  '크면 좋은 것이다 아빠를 자랑스럽게 생각할 수 있어\n',
#  '진짜 재밌었다 마지막까지\n',
#  '삿포로 맥주 너무 맛있다\n',
#  '축하한 다축 하한 다 멋지다 멋지다\n',
#  '안 본 사이더 예뻐지셨어요\n',
#  '여태 본 의학드라마 중 단연 최고\n',
#  '미쳐 활동 때 배추 머리는 대박 카리스마개 쩔어\n',
#  '대박 못하는 게 뭐예요\n',
#  '돌아가면서 뽀뽀해주고 싶다♡\n',
#  '콜라도 마셔보고 저 영감 땡잡았네\n',
#  '홈런에 무너져버렸네 엔씨 축하드려요\n',
#  '엘지 파이팅입니다\n',
#  '저희도 형님 오실 때마다 반갑고 좋습니다\n',
#  '라이브 듣고 완전 소름 기대된다\n',
#  '예능이 무한도전이 전과 이후로 나뉘듯 드라마도 도깨비 이전과 이후로 나뉠 듯 정말 기똥찬 드라마나 왔네요\n',
#  '노래는 시바가 훨씬 좋다 그리고 귀엽고 좋다 활동을 몇 번만 더하면 역주행한다\n',
#  'X 맨 부활인가요\n',
#  '존재감 쩔었음\n',
#  '진심으로 축하드려요 대박 나세요\n',
#  '야식은 치킨이 진리 군\n',
#  '정말 웃김 재밌어 스트레스 빵\n',
#  '두 분 축하드려요 나도 결혼하고 싶다\n',
#  '축구 잘 해\n',
#  '날씨 관심 없고 기상캐스터 보러 온 당데헿\n',
#  '항상 행복하세요 좋은 곡으로 만나요\n',
#  '우연적으로 파여진 흔적 가지고 망상이 심한 사람들 보면 참개울가에 굴러다니는 돌도 잘 찾아보슈재미난 모양 많수다\n',
#  '도전한 자는 멋지다\n',
#  '난 남잔데 멋진 모습 보는 게 더 좋더라 암 낫게 이\n',
#  '한화에서 유일하게 관리받는 분\n',
#  '신선하다 그리고 지루하지 않아보면서 힐링이 되는 기분이다\n',
#  '나라를 구한다는 게 이런 거지\n',
#  '아 막판에 ses 콘셉트 콘서트 보고 배꼽 빠지는 줄\n',
#  '둘 다 잘생겼으니까 인기 있지\n',
#  '지금 생각하면 유익한 프로그램이었던 듯\n',
#  '드라마화가 뭐 나귀가 좀 특별나게 재밌었지만 이것도 좀 재밌어요\n',
#  '이렇다 저렇다 기자들의 말이 많지만 무한도전 특유의 재미가 있으니 그냥 믿고 봅니다\n',
#  '우리 변호사님 최고라지요\n',
#  '난 일단 비주얼 최고인\n',
#  '기사에 임신으로 두 배의 기쁨이라니\n',
#  '누가 봐도 아버지와 딸인데\n',
#  '미세먼지에 시달리다 보니 장맛비 소식이 이렇게 반갑네요\n',
#  '하면서 비교하면서 재밌었는데\n',
#  '기도하는 입보다 돕는 손이 더 이쁘다\n',
#  '보면 떠올라\n',
#  '너무 예쁘고 사랑스러워요\n',
#  '몰랐는데 훤칠하고 멋있음\n',
#  '진심으로 축하해요\n',
#  '토트넘의 승리\n',
#  '요즘 최고 재미나도 노래도 멋졌음\n',
#  '기사 볼 때마다 그냥 흐뭇하다\n',
#  '앞으로도 아이들의 건강한 웃음을 기대하겠습니다\n',
#  '기부를 하는 본인이 더 행복하고 마음이 따뜻해진다는 걸\n',
#  '와 축하축하 작가 감독 배우다들 덕분에 드라마 잘 보고 있어요\n',
#  '누나 예뻐요\n',
#  '그동안 수고 많으셨습니다\n',
#  '유용한 정보인듯합니다\n',
#  '찬성하는 정책이다\n',
#  '어제 나올 때마다 웃은 듯\n',
#  '금연한 돈으로 기부까지\n',
#  '웬만하면 글 안 남기는데 정말 대단하세요♡\n',
#  '멀리서나마 응원하고 있어요\n',
#  '축하드립니다\n',
#  '진짜 둘 보면 저절로 엄마 미소가 지어진다\n',
#  '그래도 이제 밤엔 시원해서 좋아요\n',
#  '근데 피디는 개 웃기다\n',
#  '참 괜찮네\n',
#  '재미있을 듯 파이팅\n',
#  '시체 팔이 실패 개꿀 잼\n',
#  '남자 크루 같았으면 snl 폐지하자고 난리 블루스를 쳤을 텐데\n',
#  '어제 재밌게 봤는데\n',
#  '제가 하고 싶었던 걸 해주시니 가슴이 뻥 뚫리는 기분이네요\n',
#  '노래도 좋은데\n',
#  '특검 확고한 의지가 엿보이네\n',
#  '신곡 반갑네요\n',
#  '꿀이로 구나 둘이 붙어 있는 씬케미 최고\n',
#  '솔직히 안 오니까 좋기만 하다\n',
#  '난 달이랑 태양 보고 지구가 둥근 줄 알았다\n',
#  '아수라가 생각보다 재미가 없었고 러키가 생각보다 너무 재밌어서 입소문으로 대박 난\n',
#  '진짜 존 멋개멋\n',
#  '솔직히 기분 좋다\n',
#  '난무도 만의 콩트 되게 좋아요\n',
#  '축하드려요\n',
#  '여성분들 시청률이 꽤 놓은데 역사를 알고 보는 입장에서 너무 흥미진진합니다\n',
#  '넘어지는 장면은 진짜 혼자 시트콤 찍는 줄\n',
#  '기대보다 빨리 실현되어 너무나 행복하네요\n',
#  '보수의 해체를 축하한다\n',
#  '여름은 끝자락에 시원하고 만\n',
#  '올해 한번 일 내보자 감독님 한화이글스 파이팅\n',
#  '그 와중에 던파는 재밌더라\n',
#  '앗싸꽃 피는 춘삼월 좋은 소식 대한민국 방방곡곡 울려 퍼지겠네\n',
#  '앞으로도 좋은 배우가 되었으면 좋겠다\n',
#  '얼마나 꿈같을까 짝짝짝\n',
#  '님이 진짜 좋아하심\n',
#  '넥센 파이팅\n',
#  '저희 집도 아이들과 소 등 했어요\n',
#  '좋음\n',
#  '새로운 역사의 시작을 준비해주세요\n',
#  '아기들 다행이다\n',
#  '그래 하나 줘야지 축하합니다\n',
#  '그냥 감동이네요\n',
#  '너무나 재미있음\n',
#  '어머님 너무 재미나요\n',
#  '파이팅♡\n',
#  '첫 등장할 때 너무 예뻤음\n',
#  '대상 축하드려요\n',
#  '멋지고 자랑스러운 우리 국민\n',
#  '누나는 식빵 구울 때가 젤 멋있어요\n',
#  '와 다행이다\n',
#  '태극기 걸은 게 맘에 듭니다\n',
#  '골 진짜 멋있게 들어갔다\n',
#  '그래도 인생 드라마는 확정인 듯\n',
#  '대상 후보랑 숏터뷰 형식으로 얘기하는 거웃 겨서 그거 보고 껐다\n',
#  '임신 축하드려요\n',
#  '30초 요리\n',
#  '아이돌 중에서 미모 탑비다 진짜\n',
#  '존잼\n',
#  '안 데려오길 잘했다\n',
#  '완전 뿌듯\n',
#  '너무 귀엽네\n',
#  '생활 속의 작은 기쁨\n',
#  '그러지 말고 한 번 더 보자\n',
#  '이제 연말이네요\n',
#  '면접 안 보고 바로 최종 합격은 아님\n',
#  '국군장병 전우들아 수고해요\n',
#  '아기 엄마들의 전투 육아 스토리를 이모티콘으로 만들어봤어요\n',
#  '애들 편도나 기관지 쪽에 좋은 제품들 주길래 혹하는 마음에 해봤어요\n',
#  '그 여자애가 연예인을 좋아해서 전에 생일 때도 앨범을 사줬는데 좋아하더라고요\n',
#  '부산에 부릉부릉 갔는데 해운대에 바다 보러 가서 맛나게 스파게티도 먹어주시고\n',
#  '일하면서 들었는데 커플 탄생인 거 같더라\n',
#  '외모상으로 똑 부러지고 야무질 거 같은 느낌 드는 여자\n',
#  '어떻게 하다 보니 운 좋게 취업 안 되면 오라는 회사 한 군데를 알게 되었는데요\n',
#  '나 말년휴가 나왔다 복귀하면 제대한다\n',
#  '남중 남고를 지내왔던 저에게 디자인대학은 정말 꿈만 같은 곳이었습니다\n',
#  '오늘도 500원짜리 5개 100원짜리 2개 주웠네\n',
#  '심장이 쿵쾅 쿵쾅 그날을 잊을 수가 없다\n',
#  '4월에 첫 출근한 인턴인데 5월 4일 샌드위치 데이에 회사 쉰다고 하더라고요\n',
#  '아침에 눈뜨자마자\n',
#  '근데 발렌티인데 이 대전 고급 초콜릿이랑 백화점에서 옷 사줬어요 편지도 쓰고요\n',
#  '다음 주부터 사각 턱이랑 광대 눈 상담받으러 상담 투어 갑니다\n',
#  '어차피 전 중국어를 공부할 생각이라 여기 신청했는데 보니까 괜찮은 거 같아서 남겨봅니다\n',
#  '아 아무튼 좋네요 0\n',
#  '귀가 따뜻해\n',
#  '다들 응원 열심히 해봐요\n',
#  '제가 아직 취진 생이라 돈은 별로 없어서 고민 중이었는데 지금 세일도 많이 한다고 하더라고요\n',
#  '여긴 수수료도 안 받더라고요\n',
#  '지금은 22살 아기는 이 제도로 됐어요\n',
#  '꽃다발 하나 선물해보세요\n',
#  '인맥도 환영합니다\n',
#  '교복은 진짜 얘만큼 잘 어울리는 애 없음\n',
#  '오늘은 치즈김밥 줘서 덕분에 먹으면서 아침 맞이했다\n',
#  '나처럼 지금 돌침대에 누워있으니까 시원하기만 한데\n',
#  '빼고 다 내 스타일이야 넌 내 것\n',
#  '천생 여자 같은 느낌이야\n',
#  '사진은 이뻐서\n',
#  '나 자신이 대견해\n',
#  '그걸 해줘야 릴랙스도 되고 복근이 이쁘게 생긴단다\n',
#  '우리다 잘 될 거예요\n',
#  '친구 추가할게요\n',
#  '아 진짜 덕분에 오랜만에 실컷 웃네요\n',
#  '지난 삼성전에서 6실점하고 승리하신 것 너무 축하축하드리고요\n',
#  '우리 모두에게 진정한 도움이 되는 셰프님 국민 셰프님입니다\n',
#  '반찬을 너무 쉽게 척척 만드시네요\n',
#  '재밌고 늘 행복해진답니다\n',
#  '히히 안녕하세요\n',
#  '오빤 언제나 저에겐 최고에 요오홍홍\n',
#  '그리고 대상 축하드립니다\n',
#  '오빠 아프다는 소식 듣고 눈앞이 캄캄했는데 오늘 그 어둠이 조금이라도 사라졌어요\n',
#  '이따 뵈어요\n',
#  '그래도 이름이 있는 것만으로 만족합니다\n',
#  '어제 너무 좋았습니다\n',
#  '건강하시고 행복하세요\n',
#  '흑 역사라 하긴 뭐 한데 그 내가 쓴 댓글 보기 하는 거 있잖아\n',
#  '상큼한 트레이닝복 화보 촬영 중인 나\n',
#  '외모는 충분히 이쁘다\n',
#  '제대해서 좋아\n',
#  '끝까지 응원한다\n',
#  '솔직히 요 신인 거지\n',
#  '잔머리 하나는 진짜 갑인 것 같아요\n',
#  '4개월 조금 넘은 아기입니다\n',
#  '이러는데 너무 귀여워 죽겠다\n',
#  '노래도 좋고\n',
#  '세븐틴에게 조공을 바치며 살아가겠습니다\n',
#  'TV에서 자주 뵙는데 멋지십니다\n',
#  '너무너무 좋다\n',
#  '오늘 대 박세일 가로 스틱 분유사 가지고 왔어요\n',
#  '이것도 아무 말 대잔치인데 기분이 상하지\n',
#  '제주도 여행 계획 중입니다\n',
#  '결과적으로 여자친구가 한번 눈감아준답니다\n',
#  '수고가 많으시네요 참 멋있어요 참 멋져요 앞으로\n',
#  '멋진 님\n',
#  '정말 오랜만에 아름다운 연기를 볼 수 있게 되어서 정말 기뻤어요\n',
#  '메리 크리스마스\n',
#  '오빠의 행동 하나하나가 우리에게 즐거움을 주네요\n',
#  '생일 맞으신 거 정말 진심으로 축하드려요\n',
#  '오빠 감정 최고예요\n',
#  '너무 훌륭했어요\n',
#  '제가 여기 동호회에 클럽을 만들었거든요\n',
#  '서로 의식하게 되고 좋아하게 된 시기가 겹쳐서 너무 신기해요\n',
#  '궁금해서 여기 눈팅하고 있는데 이거 너무 웃김\n',
#  '글 정리 같은 거랄까 그냥 깔끔한 걸 좋아해요\n',
#  '24년 동안 결심 못했던 다이어트님 덕분에 2주 넘게 다이어트 중\n',
#  '무조건 증정이니 해볼 만한 이벤트 같네요\n',
#  '헬스장 몇 년 다녀보니까 느끼는 건데 새해 첫 평일에는 사람들이 엄청 많습니다\n',
#  '안녕하세요\n',
#  '오늘 판에 들어와 보았는데 메인에 있어서 놀랐어요\n',
#  '응원할게요 새해 복 많이 받으세요\n',
#  '항상 팬들이 응원하고 있답니다\n',
#  '선수 너무너무 수고 많았어요\n',
#  '선수가 1루로 복귀한다니 참으로 기쁜 소식이군요\n',
#  '생일 진심으로 축하하고 좋은 하루 보내요\n',
#  '생일 축하합니다\n',
#  '생일 축하해요\n',
#  '2일 후면 팬 된지 딱 1년 되네요\n',
#  '우와 이번 활동 많이 수고했어요\n',
#  '오늘 너무 자랑스럽고요\n',
#  '3월 내내 멤버들 생일이 없어서 축하글 오랜만에 써요\n',
#  '다시 한번 축하축하\n',
#  '유재석 주니어의 탄생을 축하드려요\n',
#  '이번 해투는 가요제 이후로 절제 일로 웃긴 몸 개그와 언변이었다고 생각합니다\n',
#  '님 파이팅입니다\n',
#  '나오신다길래 좋아서 히히 히다 보고 이름을 쳐 봤는데 팬카페가 나오더라고요\n',
#  '언제 어디서나 기분 좋게 바라볼 수 있는 분\n',
#  '진심으로 생일 축하한다\n',
#  '오늘 밤 SBS11시 25분 첫 방송\n',
#  '생일 축하해♡아\n',
#  '오빠 참 좋아요\n',
#  '아시아 투어 건강하게 잘 갔다 와요\n',
#  '선생님 요리 정말 재미있어요\n',
#  '만능 간장으로 채소 요리도 쉽게\n',
#  '맥주 부님 덕분에 요리가 갈수록 스피드하고 맛이 있어지는 거 같아요\n',
#  '오라버니 하늘이 파랗게 있으니 날씨가 좋더라고요\n',
#  '선수의 LG 팬으로서 진심으로 축하드리고요\n',
#  '꼭 본방사수해서 시청 잘할게요\n',
#  '그리고 실검 1위도 축하해요\n',
#  '나도\n',
#  '개설한 지 5주년이 됐네요\n',
#  '앞으로도 무한도전에서 더욱더 좋은 모습 재미있는 모습 기대할게요\n',
#  '진심으로 생일 축하드려요\n',
#  '생일 축하해\n',
#  '형은 언제나 최고였고 앞으로도 최고의 선수일 거예요\n',
#  '아 오늘 생일이네요\n',
#  '파이팅\n',
#  '오빠 오늘 무도 정말 재밌게 봤어요\n',
#  '오늘 드디어 데뷔 600일\n',
#  '덕을 보네요\n',
#  '요리 프로그램이 한 다음날은 우리 집 메뉴가 풍성해집니다\n',
#  '대기록 달성 축하해요\n',
#  '오늘 공개 카페 왔다 갔죠\n',
#  '진짜 너무너무 진심으로 너의 탄생일을 축하한다\n',
#  '웃고 싶을 땐 형만 보는 듯\n',
#  '오빠 생일 축하해요\n',
#  '역시 오빠 생일이니까 사진은 오랜만에 오빠 짧은 머리로\n',
#  '새해가 밝네요\n',
#  '와우 진짜 오랜만에 여기 왔어요\n',
#  '데뷔한 지 얼마 안 된 것 같지만 벌써 1주년이 지나고 오빠도 데뷔하고 두 번째 생일이네요\n',
#  '티브이에서 자주 뵈니 좋습니다\n',
#  '제가 오빠를 좋아한 건 94년 오빠가 데뷔했을 때죠\n',
#  '그렇게 최고 자리에 있으면서도 끊임없이 발전하는 모습이 너무 보기 좋네요\n',
#  '그리고 새해 복 많이 받으세요\n',
#  '형님 사실이면 축하드립니다\n',
#  '생일 축하드리고요\n',
#  '마음이지만 정말로 생일 축하드립니다\n',
#  '항상 건강하시고 이번 우승 축하합니다\n',
#  '백주부님은 사람을 즐겁게 만드는 행복 바이러스\n',
#  '그럼 내일을 위해 고고싱\n',
#  '어제 자기 전만 해도 18등이었는데 지금 4등이 나올랐어요\n',
#  '내일부터 추석 연휴에요 오빠\n',
#  '오늘은 벌써 제가 오빠를 좋아하게 된 지 90일\n',
#  '정말 정말 열심히 하는 모습 보기 좋습니다\n',
#  '방송에서 본 모습이 너무 좋아 보여요\n',
#  '이쁜 아♡\n',
#  '세상에 어떤 일이 있더라도 저에게 있어서는 최고입니다\n',
#  '파이팅\n',
#  '오빠 생일 축하해요♡\n',
#  '오빠 안녕하세요\n',
#  '만능 간장으로 꽈리고추볶음 엄청 맛나서 맛 들여서 매일 해먹고요\n',
#  '95년도에 일본과 친선경기 때 처음 선수를 보고 팬이 되었습니다\n',
#  '그리고 생일 축하해요\n',
#  '그러니깐 내가 초등학교 4학년 때부터 형을 좋아했어요\n',
#  '오늘은 해토 촬영 날이자 무도하는 날\n',
#  '백 선생님 얼굴만 봐도 절로 입가에 미소가\n',
#  '마지막으로 다시 700일 축하해요\n',
#  '컴백까지 건강 챙기시고 멋있는 모습으로 만나요\n',
#  '역시 오빠를 알아보시는 분이 계시군요\n',
#  '독특한 억양이 너무 멋있습니다\n',
#  '일단 400일 축하해\n',
#  '역시 기대를 저버리지 않네요\n',
#  '2010올림픽이 열릴 밴쿠버 경기장에선 세 대륙 첫 우승\n',
#  '아이스쇼로 스트레스가 날아갔어요\n',
#  '이번 아이스쇼에 갔었어요\n',
#  '그래서 선수도 좋아해요\n',
#  '그럼 저는 티켓팅하러\n',
#  '앞으로도 영원히 사람을 사랑할 것을 맹세합니다\n',
#  '세상에 하나뿐인 든든한 총괄리더 생일 축하해\n',
#  '선수 파이팅\n',
#  '주말이 되면 무도 볼 생각에 진짜 좋더라고요 유느님 활약 기대됩니다\n',
#  'LG 파이팅 파이팅\n',
#  '글 남겨요\n',
#  '그렇게 살다 보면 언젠가는 사람들이 알아주는 날이 오는 법이다\n',
#  '다시 한번 정말 축하드립니다\n',
#  '내일모레가 방학이에요\n',
#  '생일 축하해\n',
#  '오빠 아까 해투 잘 봤어요\n',
#  '내일 데뷔 1주년이니까 멤버들 전체한테 한번 적으러 올게요\n',
#  '생일 축하해요\n',
#  '오늘 저녁 시간에도 맥주 부님 만 세요\n',
#  '무한도전 지피지기\n',
#  '그래도 1kg이 빠졌어요\n',
#  '오빠 21번째 생일 정말 축하해요\n',
#  '오빠들1위 축하해요\n',
#  '시간이 늦었지만 오빠 생일 축하해\n',
#  '진심으로 축하해\n',
#  '저는 취미로 요리를 좋아하는 사람인데 제가 평소에 원했던 프로그램입니다\n',
#  '님 덕분에 아빠들의 요리 솜씨가 상향 평준화되어버려서 제 희소성이 떨어져 버렸거든요\n',
#  '엘지 파이팅\n',
#  '존재 자체만으로 큰 기쁨이었어요\n',
#  '너무 축하드려요\n',
#  '그리고 요즘에 너무 뿌듯해요\n',
#  '다음번에는 꼭 1위시 켜드릴 수 있도록 노력하겠습니다\n',
#  '팬들을 위해서 열심히 싸워주십시오\n',
#  '오늘 장이었어요\n',
#  '세븐틴 만세 만세 만만세\n',
#  '다 비켜 우리 오빠가 최고야\n',
#  '축하합니다 축하합니다\n',
#  '세븐틴에게 지금이 소중한 추억으로 기억되고 있는 것 같아내가 다 뿌듯하네\n',
#  '정말 생일 축하해요\n',
#  '앞으로는 다이아 길만 걷게 해줄게요\n',
#  '어제 전주 삼 성문회 회관에서 콘서트 봤지요\n',
#  '오라버니 또다시 5월 셋째 주가 시작하네요\n',
#  '오빠 졸업 축하하고\n',
#  '우리 함께 가요\n',
#  '챔피언 답습니다\n',
#  '32로 삼성에 지고 있다가 선수가 솔로홈런으로 동점을 만들었네요\n',
#  '최고\n',
#  '진심으로 축하합니다\n',
#  '새해 복 많이 받으시고 올해도 건강하시고 파이팅 하세요\n',
#  '프로로 영입한다네요\n',
#  '파이팅\n',
#  '텔레비전에서 수다 떨 때나 애드리브 할 때 눈웃음이 멋져요\n',
#  '오늘 저는 정말 힐링을 했어요\n',
#  '02년도부터 두각을 보이는 선수들 또한 돌아온 가세한다면\n',
#  '정말 기쁩니다\n',
#  '언니가 한 경기를 매일 되풀이하며 보고 있습니다\n',
#  '그래서 바로 다음 카페를 가입하고 메찾사를 가입했습니다\n',
#  '이번에 꼭 1위 시켜줄게요♡\n',
#  '팬카페 지기님 차 한 잔 마시며 잠시 휴식을 취하려 할 때 방 안의 다른 친구 TV를 켜면 자주 눈에 띄시네요 반갑습니다\n',
#  '항상 기다릴 테니까\n',
#  '오빠 이기세로 2008년에도 한자리하는 거야\n',
#  '제가 가입한 지 얼마 안 되고 제가 그렇게 열렬히 카페 활동하지 않지만 가입했다는 것만으로도 기분 좋은 거요\n',
#  '앞으로 더욱 멋진 모습 기대할게요\n',
#  '좋아 올해는 뭔가 필이 온다\n',
#  '광주엔 계속 비가 온다던데\n',
#  '두 손 꼭 잡고 들었어요\n',
#  '언제까지나 응원하고 기억할게요\n',
#  '연습생 때는 그냥 빨리 데뷔했으면 좋겠다 했는데 이젠 일위도 하고 너무 자랑스럽다\n',
#  '방송 잘 보고 있습니다\n',
#  '각자 21살 20살 생일이네요\n',
#  '아 귀여워 이번엔 꼭 보러 가야지\n',
#  '후반으로 갈수록 존잼\n',
#  '결과와 관계없이 그저 멤버들이 즐겁고 행복하게 원 없이 활동하는 모습 보고 싶네요\n',
#  '에 이날도 더운데요 친이랑 시원한 모텔이 나가야겠다\n',
#  '냠냠냠 모든 음식은 맛있게 먹어야 합니다 특히 야식\n',
#  '대박 은근히 섹시한 계속 기다리게 됨\n',
#  '댓글 보고 있는 모양임 죄다 반대 하나씩\n',
#  '혼자서 던지고 치고받고 다하겠구나♡\n',
#  '윤아 연기 잘하고 이쁘고 매력 있어\n',
#  '그 이후로 대폭 망\n',
#  '예쁜 아기랑 행복하게 사세요\n',
#  '힘내세요 선수\n',
#  '아싸 수요일 개이득\n',
#  '임신 축하드려요 누나\n',
#  '오늘 너무 웃겨서 앞니 빠지는 줄 알았음 눈치 보며 흘린 밥풀 주워 먹고 표정\n',
#  '오늘 너무 웃겼어요\n',
#  '주모 연중무휴입니까\n',
#  '왜 난 말하는데 당황하는 모습에 개 웃겼는데\n',
#  '역시 설날엔 설날도\n',
#  '성실하고 묵묵하고 좋지\n',
#  '오이 거 보자마자 대박을 외쳤음\n',
#  '대한민국에서 모르는 사람듵 있을까요\n',
#  '진짜 맨유 시절 역대 최고의 크랙이 지기가 막혔는데 진짜\n',
#  '어짱구엉덩이 네울라울라\n',
#  '그 와중에 게임하는 개웃김\n',
#  '아 진짜 전 잼이었다\n',
#  '기아가 내년에 우승하겠군요 축하합니다\n',
#  '와대 박화이팅\n',
#  '말로 웃겨서 큰소리로 웃게 한 아저씨는 처음\n',
#  '님이 나쁜 놈이 아니라 너무나 좋은 거\n',
#  '공동 수상 진심으로 축하합니다\n',
#  '고소한 참기름 냄새가 솔솔\n',
#  '재밌음\n',
#  '생각만 해도 웃김 기대돼요 파이팅\n',
#  '연기 폭만 하고 먹고살기 힘들지\n',
#  '감방 동기 됐네\n',
#  '어머 언니들이 기사 너무 좋은데 어떡하지\n',
#  '자전거가 최고\n',
#  '형님의 리\n',
#  '근데 진짜 잘생겼네 원빈 급이다\n',
#  '이따가 또 가야지\n',
#  '아 이건 정말 신의 한 수예요\n',
#  '사진 절묘하게 잘 골랐네\n',
#  '정말 기다려지네요 대장 최고\n',
#  '진짜 제일 좋아하는 야구선수 진심 멋지다\n',
#  '조만간 스카우터들 한국방문할 듯\n',
#  '올해 최고 의학드라마는 태양의 후예\n',
#  '이거 성공하면 우리나라 캐릭터 하나 건지는 거임\n',
#  '이런 것 너무 좋아질 투 귀여울 것 같음\n',
#  '갓 현주 연기 좋아요♡♡\n',
#  '내 나왔어요 꺄\n',
#  '축하드립니다\n',
#  '금요일 토요일이 제일로 기다려지는 일인입니다 너무 재미나요\n',
#  '이러다 무투표당선되는 거 아니냐\n',
#  '능력 있는 어른의 모습 멋있어요♡\n',
#  '다행이다 또 충돌 일어날까 봐 10일부터 끌고 왔는데 못 들어오게 하면 더 열받아서 무슨 일 나는데 법원 잘했네 잘했어 아저씨들 고생하셨어요 다치지 마세요\n',
#  '자신 있네 금요일이라 했다\n',
#  '스마트폰 꼭 봐야 편하다 왜냐하면 스마트폰은 내 친구니까 스마트폰 하트\n',
#  '파이팅\n',
#  '걸그룹 대 첩보다 이게 훨씬 더 재미있다\n',
#  '좋았어 우리 동네에 오신다\n',
#  '계주는 역시 방탄소년단\n',
#  '능력자의 메뚜기 바지 벗길 때 가장 기억에 남는다\n',
#  '예쁘게 사는 배우네\n',
#  '기아타이거즈 ♡ ♡♡\n',
#  '유부녀 축하합니다\n',
#  '아침부터 로또번호 불러주네\n',
#  '드디어\n',
#  '잘 어울리는데 그냥 결혼해라\n',
#  '무도 입성이라니까\n',
#  '역시 한국이 제일 안전해\n',
#  '그다지 나 잼일 거 같고 그냥 섭외한다면 섭외능력에 감탄할 뿐 솔직히 재미는 없을 거 같다 족구하고 물공 헤딩하고 그런 거 하고 끝나겠지 오히려 메기 잡기는 꿀 잼일 거 같다\n',
#  '항상 응원하고 있어요\n',
#  '둘 다 잘생겼다\n',
#  'JTBC 같은 언론이 있기에 저러는 거다\n',
#  '케이팝스타 마지막이라 그런가 참가자 실력도 좋고 완전 꿀 잼\n',
#  '싼 맛 엘지 굿 경험자임\n',
#  '착하고 열심히 하는 게 다른 자질보다 백 번 낫다\n',
#  '오랜만에 훈훈한 뉴스네요\n',
#  '결방은 싫지만 연속 방송해주고 스페셜도 보여준다니 그냥 넘어가야지\n',
#  '진짜 호주 가서 외국인들이랑 같이 롤 하는데 한국 사람이라서 영어 잘못한다니까 한국 사람 아냐고 물어봄 무조건\n',
#  '어디서나 인정받는 배우님 자랑스러워요\n',
#  '역시 우린 짱깨와 다른 민족이었어\n',
#  '축하드립니다\n',
#  '혼자 식사하기엔 곰탕이 최고\n',
#  '콘서트 와이프 손잡고 가자고 해야겠다\n',
#  '너무 잘 어울리고 이쁜 커플\n',
#  '정말 웃기다\n',
#  '원인 규명이 되었다니 다행이네요 보완작업 잘 하고 기능 추가해서 완벽한 갤노트 8이 빨리 나오길 기다리고 있겠습니다\n',
#  '이렇게 보니까 잘 어울린다\n',
#  '오래간만에 좋은 소식 들어서 기분 좋네요\n',
#  '오늘날 잘 잡았어 날씨 끝장이다 5000만 집결\n',
#  '다저스 큰일 났네\n',
#  '좋은 연기 보여주세요 응원합니다\n',
#  '슬슬 생길 때 됐지\n',
#  '님짱\n',
#  '너무 재미있음 오늘 보러 갔다 왔는데 또 보고 싶음\n',
#  '재미나네\n',
#  '위원 정말 사이다입니다 멋지십니다\n',
#  '준비 잘해서 좋은 멤버들이랑 데뷔했으면 좋겠다 응원합니다\n',
#  '처음엔 음악 대장의 팬이었다면 이젠 국가 스테인리스강의 팬이다\n',
#  '저런 것이 고소해서 합의금 뜯으면 꿀\n',
#  '축하해\n',
#  '싱그러운 청춘 사극 분위기 너무 좋고 눈 호강도 제대로 한다\n',
#  '이런 거 보면 헬 조선이긴 한데 한국에서 태어난 걸 감사해야 되는구나\n',
#  '레고는 시티 시리즈 가꿀 잼이었는데 도로 판 사서 건물들 세워놓고\n',
#  '빨리 꺼지세요 속이 시원하다\n',
#  '게임방 가서 사광 클릭해서 대기 4600명 뚫고 성공\n',
#  '악 누구인 줄\n',
#  '앞으로는 행복하렴\n',
#  '신곡 지붕킥 하자\n',
#  '평화로운 시위로 믿음을 만들었기에 가능했다고 봅니다\n',
#  '엘지 축하해요 기아 몫까지 최선을 다해 좋은 결과 얻길\n',
#  '그래 아주 잘했어요\n',
#  '시상식 3대 기획사 잔치인데 올해 YG 부재에 방탄이 좋은 기회를 받았네요\n',
#  '오늘 치킨 시켜 먹어야지\n',
#  'sk에서 시구까지 하고 이미 그는 sk 레전드입니다\n',
#  '호구든 거품이든 뒷돈이든 난 모르겠고 영입 참 잘했다\n',
#  '15년 전 영종도 칼국숫집에서 뵈었는데 건강하세요♡♡♡\n',
#  '고유어는 아름답다\n',
#  'VR로 즐길 듯 기대되네\n',
#  '전복 이름 지어준 거 겁나 웃김\n',
#  '너보다 걔가 낫다\n',
#  '확실한 부정 웃겨요\n',
#  '조만간 구속수사\n',
#  '내 아들도 재학생 군 복무 중으로 자랑스럽네요\n',
#  '뒷북 꿀 잼\n',
#  '내 일한 화승 기아 엘지 패하면 재밌어지겠다\n',
#  '굿 꿩 먹고 알 먹고 누이 좋고 매부 좋고\n',
#  '2007년 전국의 텔미 열풍은 잊을 수 없다\n',
#  '비 좀 와라 좋은 현상임 굿굿\n',
#  '난 암전 게임 재밌었음 재치 있더라 귀여웠음\n',
#  '진지하게 기사 읽다가 사진 보고 뿜었다\n',
#  '다른 배우분들도 잘하셨지만 정말 받을만한 분이 받은 겁니다\n',
#  '미리\n',
#  '오 선택 잘했다 롱런하길\n',
#  '커플 대상 응원합니다\n',
#  '보고 싶었어요 멋있는\n',
#  '사이다 속 시원하다\n',
#  '예감 적중\n',
#  '너무 이쁘다♡\n',
#  '능청스럽게 비굴한 연기도 잘하고 귀엽고 사랑스러운 연기도 잘하고 자연스럽게 잘해 잘해 예뻐 죽겠어\n',
#  '생각보다 조합이 상상 안 감 그렇지만 축하합니다\n',
#  '누나 수고했어요\n',
#  '대선 축하합니다\n',
#  'NC 코리안시리즈 진출 축하드립니다\n',
#  '이아 대개 그 좀 할 줄 아네\n',
#  '하야하기 좋은 날씨네요\n',
#  '어제 나온 부부 너무 보기 좋더라 좋았고\n',
#  '검은 사제들에서의 카리스마 짱\n',
#  '역시 명불허전 똥싸개\n',
#  '우리 나란 아직 판매 중 희귀템 구매원하면 사면됨\n',
#  '의사봉 두드리는 소리가 저리 경쾌할 줄 누가 암\n',
#  '하드캐리♡\n',
#  '수원 햇빛 좋다\n',
#  '그나마 다행히 기각 폰은 안됐네 탄핵 폰\n',
#  '운동복처럼 쭉쭉 늘어나는 정장 너무 좋다\n',
#  '나의 멘토이자 우상 파이팅 행복하세요\n',
#  '이형 대상 받는데 왜 내가 다 기분이 좋냐\n',
#  '얼굴 이미 다 팔렸는데 왜 가려\n',
#  '또 둿 목잡네\n',
#  '은근 개장하지\n',
#  '옛날부터 존 날인데 왜 안 뜨나 했었는데 이번에 배역 제대로 맡아서 뜨나 보다\n',
#  '훈훈한 비주얼에 따뜻한 연출 기대할게요\n',
#  '이름 그대로 가요계의 신화\n',
#  '대일본제국 만세 천황폐하 만세\n',
#  '떠난 레전드 감독의 자리를 이어받을 듯\n',
#  '길 가다가 포켓몬고 하다 정신이 팔린 새끼가 지나가다가 똥 밟은 거 본 적 있다 뒤에서 가는데 얼마나 웃기던지\n',
#  '만세 당선 축하합니다\n',
#  '어떤 영화일지 너무 기대됩니다 파이팅\n',
#  '대박 날 만함 시청률 30는 나와줘야지 기존 잼 꿀 잼\n',
#  '존 나야무지게 달리네\n',
#  '진짜 나랑 개그코드가 너무 똑같아서 배꼽 잡고 웃는다 너무 재밌어\n',
#  '응원합니다 파이팅\n',
#  '이참에 화성산업 주식이나 사볼까\n',
#  'Vip룸에서 tv보며 팝콘 먹던 순시 리뜬금 없는 팩폭\n',
#  '좋은 일 했네요\n',
#  '선발 로테이션 지맘대로 조절해가며 충분히 표적 등판시킬 듯\n',
#  '잘생겼다\n',
#  '\n',
#  '슈돌 섭 외력 우주 돌파\n',
#  '존 나 잘하네\n',
#  '앜 진짜 겁나 웃곀\n',
#  '축하드려요\n',
#  '복귀 찬성\n',
#  '파이팅\n',
#  '타령이 제일 웃기네\n',
#  '어야 음악 좋다 다다\n',
#  '개 웃길 듯\n',
#  '축하합니다 너무 잘 됐네요\n',
#  '우린 가장 재밌어\n',
#  '오늘은 일주일 동안 기다렸어요\n',
#  '발가락이 닮았어요\n',
#  '누나 나랑 사귀자\n',
#  '노력하는 모습 보기 좋아요\n',
#  '반함♡ ♡♡\n',
#  '멋지다\n',
#  '경질이나 자진사퇴 기사가 났으면 여권을 불태워버렸을 텐데 한 해 동안 수고 많았어 메이저 가서도 승승장구하기를\n',
#  '둘 다 순수하고 묘한 자기만의 세계가 어울림 어서 결혼 갑시다\n',
#  '눈 해주고 발해줘서 다른 애들 조지는 건 진짜 쩔었다\n',
#  '조금 뻔하긴 하지만 연출이 지린다 진짜\n',
#  '사람 참 괜찮네\n',
#  '남자가 봐도 멋있다 말 진짜 잘한다\n',
#  '켜야 아들 잘생겼다\n',
#  '진심 축하드려요 한국 영화계의 큰 경사네요\n',
#  '선수 축하합니다 진정한 프로 인간승리\n',
#  '형님 얼굴도 멋있으시고 행동도 멋있으십니다\n',
#  '이쁘다 좋아요 노래 잘 부르세요\n',
#  '땀 노예 선수처럼 대박 치길\n',
#  '눈물이 나는 기사네요 모두들 고생하셨습니다\n',
#  '어제 귀여워 죽는 줄\n',
#  '야구는 어디서 하든 똑같다는 말 멋지다\n',
#  '조연들이 좋네요\n',
#  '멋지다\n',
#  '정말 멋있다 마음까지도\n',
#  '어휴 드디어 가네 이제 다시 무도 봐야겠다\n',
#  '역시 갓 짜장\n',
#  '대상 받는 것보다 눈물 나긴 처음\n',
#  '연기 진짜 잘한다 마지막 신보고 눈물이 줄줄 흘렀다\n',
#  '가족 건강하게 해줘\n',
#  '엄마의 힘은 위대하다\n',
#  '너무 대단하시다 감동\n',
#  '하나님의 기적 잘 보았습니다\n',
#  '둘이 결혼하면 안 되나 잘 어울리는데\n',
#  '대한민국 사법정의를 바로 세우기 위해 밤낮없이 일하시는 법관님들 존경합니다 파이팅\n',
#  '예술가는 예술로 사회를 이야기하고 지켜 나가야 할 책임이 있다고 말한 피카소처럼 선생님의 처한 사회와 상황을 외면하지 않겠다는 맹세에 존경을 표합니다\n',
#  'KBS 특파원은 뉴스에서 보니까 지금 중국 상해에서 계속 계시던데 역시나 기자라서 그런지 글과 기사도 참 잘 쓰시네요\n',
#  '무엇보다 연기 앞에서 진지하고 성실한 부분이 박수받아 마땅한 듯\n',
#  '대한 국민 만세\n',
#  '뭔가 이 뉴스가 엄청 위로가 된다\n',
#  '오오 체험기 쓰시다니 노력하시네요\n',
#  '내 이상형인 누나다\n',
#  '선수 그동안 기아에서 정말 수고했어요 삼성가서도 응원 많이 할게요 파이팅\n',
#  '역시 이야\n',
#  '헐온 일 2년 동안 대박 너무 축하드려요 선남선녀\n',
#  '역시 멋진 사람\n',
#  '인생인처럼\n',
#  '우리 대한민국 국민들 정말 위대하십니다\n',
#  '자기관리 철저한 사람의 지가 약해서 실패하는 일인으로 존경스럽습니다\n',
#  '역할도 크다\n',
#  '형사랑 합니다\n',
#  '무엇을 하든 자연스럽고 척이 없는데 그게 다선하고 센스 있어서 너무 좋음\n',
#  '최고다\n',
#  '나는 운동경기장에서 국민의례할 때 국가에 대한 자부심을 느낀다\n',
#  '사극해도 한 번 더 보고 싶네요 강력 추천♡♡\n',
#  '자랑스러운 대한민국 국민들95가 새 역사를 만들 것입니다\n',
#  '얼굴에 한민족의 점잖음이 기품이 묻어나네\n',
#  '두 분 축하드려요 다른 드라마에서 다시 같이 연기하는 것보다 싶네요\n',
#  '감동이네요 파이팅\n',
#  '와 개간지다\n',
#  '나의 황제는이다\n',
#  '토트넘 동료들이 훈련 때 보면 잘한다 함 갑자기 잘하는 게 아니라 원래부터 잘했다 함 놀랄 일도 아니라 함\n',
#  '본방사수할게요\n',
#  '3주간 너무 재밌었어 요만 세\n',
#  '멋있다\n',
#  '음색에는 어떤 특별한 울림이 있어 자꾸 듣고 싶어진다 이번에 정말 개취\n',
#  '진짜 겸손하다\n',
#  '양키스는 좀 먼 이야기 같긴 한데 어쨌든 지금 엘지 진짜 잘 함타팀 팬이지만 이건 정말 인정\n',
#  '멋진 친구네요\n',
#  '신의 얼굴 등골이 오싹하더라 표현 정말 좋았어\n',
#  '역시 재미있음♡♡\n',
#  '한국 좀비 영화 중에선 기대 이상\n',
#  '솔직히 연기 잘함\n',
#  '연기가 잘해\n',
#  '투표 개표가 이렇게 흥미진진할 수가\n',
#  '멋있다\n',
#  '고급스럽게 아름답다\n',
#  '아직도 이렇게 천사같이 좋은 분이 계시다니요\n',
#  '대상 타는 거 보려고 이 시간까지 봤다 정말 기쁘고 속 시원하다 축하드립니다\n',
#  '가슴 뭉클하다\n',
#  '전율이 믿을 수 없어 고마워요 슈 돌\n',
#  '노르웨이 교도소는 한국호텔보다 좋던데 방은 좀 작지만 탈옥 빼고는 웬만큼 할 수 있는 건 다 되는 거 같고 면회실 보고 레스토랑인 줄\n',
#  '감동이네요 눈물 난다\n',
#  '연기 진짜 잘하시던데\n',
#  '진정한 여왕님 말씀 잘 들었습니다\n',
#  '오늘 첼시 경기력 지림\n',
#  '첫사랑이 이루어졌네\n',
#  '밖에서 일하시는 분들 힘내세요 파이팅\n',
#  '때문에 심장 미치잖아\n',
#  '사랑할 수밖에 없는 남자\n',
#  '어느 한 곳이라도 특출나게 크고 있는 이들이 있어 다행이다\n',
#  '날로 잘생겨져가네\n',
#  '의리 한번 죽이네\n',
#  '갑인 듯\n',
#  '나는 이래서 좋다\n',
#  '엄마 미소\n',
#  '극찬한 이유가 있었어\n',
#  '코끝 찡하게 하네요 파이팅\n',
#  '안녕하세 요입니다♡\n',
#  '당연히 받을 줄 알았다 이젠 대한민국을 대표하는 에이스 투수\n',
#  '압도적이다 진짜\n',
#  '멋지십니다 박수\n',
#  '눈치 보지 않고 하고자 하는 말씀 시원시원하게 해주시는 모습 멋있습니다\n',
#  '이 정도면 리버풀 승리\n',
#  '윗입술이 너무 귀여워요\n',
#  '좋은 기사 한참 동안 읽었네요\n',
#  '40대 남자 가수들 중에 음원차트 올킬 할 수 있는 건밖에 없을 듯\n',
#  '명절 부모님 생신 처갓집 어른 생신 어버이날에 당연하다는 듯 집에 가자고 하는 집사람이 정말 너무 고맙네요\n',
#  '연기 존 나 잘해우는 데 너무 슬프더라 개 좋아\n',
#  '너무너무 재미있는 드라마\n',
#  '솔직히 제일 잘했지\n',
#  '과연 좋아했을만하 군\n',
#  '외압에 굴하지 않고 오뚝이처럼 일어선 대한민국의 진정한 영웅이다\n',
#  '대륙은 뭐든 스케일이 남달라\n',
#  '잘생겼다\n',
#  '80년이면 거의 37년을 연구했다는 건데 훌륭하오 일본인이지만 존경스럽소\n',
#  '위대한 대한민국 민중의 역사적 승리의 날로 오늘을 기억하라\n',
#  '진실하게 말하는 모습 인상 깊습니다\n',
#  '어떻게 이런 대사들을 쓸 수 있는지 알다가도 모르겠구나\n',
#  '패션의 완성은 얼굴을 결혼식에서 증명하는구먼\n',
#  '파이널 보스\n',
#  '언니는 백야행 때도 정말 아름다웠다고 생각함\n',
#  '잘한 다♡ ♡♡\n',
#  '너무 귀여우심\n',
#  '멋있어요\n',
#  '축하합니다 자랑스럽네요\n',
#  '수요일 목요일이 기다려집니다 너무 재밌고 본방사수\n',
#  '드디어 가을야구의 주인공으로 자리 잡을 날이 오네요 감사합니다\n',
#  '너무 재미남 너무 존 잘 아 설레는데 코믹한 연기도 너무 잘해\n',
#  '잘 됐네 성공하시길\n',
#  '영화는 다 본 듯 연기 최고야\n',
#  '무도는 제게 참 소중한 프로예요 감사합니다\n',
#  '티브이에 안 나오는 건 잘한 결정 임진 정한 아버지네요\n',
#  '남자인 내가 봐도 잘 생겨 보이는데 여자들은 오죽할까\n',
#  '만세 만만세\n',
#  '맞는 말씀에 찬성 1표\n',
#  '스타끼리의 만남이라 잘 어울리네요\n',
#  '나도 같이 울었음\n',
#  '역시 얼굴 도착해 몸매 도착해 마음씨는 말할 것도 없네\n',
#  '형님 축하\n',
#  '우와 울컥했다 감동\n',
#  '진짜 참다운 선생님들이시네\n',
#  '책장 움직이는 거 멋있었어\n',
#  '진짜 명장이다\n',
#  '우리키 지환 갔지 환은 사랑입니다 문천 재도 멀티홈런 멋졌어요\n',
#  '누나 가슴속에 3천 원쯤은 있는 거잖아요 파이팅\n',
#  '힘들게 돌아온 길 좋은 결과로 이어졌으면 좋겠네요 선수 파이팅\n',
#  '비투비 파이팅 한 곡마저 잘렸지만 계속 응원할게요♡\n',
#  '형님 대단하십니다 존경합니다\n',
#  '제 인생 최고의 드라마였습니다\n',
#  '멋지다 역시\n',
#  '진심 멋지다고 생하셨어요\n',
#  '힘내세요 2017년 파이팅\n',
#  '재밌게 보고 있어요 이렇게 좋은 일을 하시는 걸 보면 정말 마음이 따뜻한 사람 같아요 앞으로도 좋은 활약 기대합니다\n',
#  '그냥 보기만 해도 기분이 좋아지는 매력이 있다 마냥 흐뭇해지더라\n',
#  '진짜 진짜 축하해 진짜 대단하다\n',
#  '어머나 머리 스타일 하나로 이렇게 바뀌는구나 귀엽네\n',
#  '직접 가서 보니 오히려 기부하시던데 어르신들이\n',
#  '여전히 멋있는 모습으로 멋있는 생각을 가지고 있네요 당신의 길을 응원합니다\n',
#  '우리의 꿈과 희망 청소년들 멋있고 고마워 그리고 너네 젊은이 부러워\n',
#  '기부했는데 역시 친하게 지내는 그룹끼리♡방탄소년단 분들 마음씨 너무 착하세요\n',
#  '인간 본받을만한 사람이다\n',
#  '♡ ♡ 멋짐\n',
#  '기대해봅니다 파이팅\n',
#  ...]

# %%
twitter = Twitter() 
morphs = [] 
 
for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('오라버니', 'Noun'), ('해피투게더', 'Noun'), ('봤어요', 'Verb'), ('\n', 'Foreign')], [('우리', 'Noun'), ('모두', 'Noun'), ('LG', 'Alpha'), ('선수', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('선전', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있게', 'Adjective'), ('기를', 'Verb'), ('넣어', 'Verb'), ('줍시다', 'Verb'), ('\n', 'Foreign')], [('웃긴', 'Verb'), ('거', 'Noun'), ('알', 'Noun'), ('죠', 'Josa'), ('\n', 'Foreign')], [('덕분', 'Noun'), ('에', 'Josa'), ('주방', 'Noun'), ('에서', 'Josa'), ('요리', 'Noun'), ('하는', 'Verb'), ('게', 'Noun'), ('엄청', 'Adverb'), ('좋아졌어요', 'Verb'), ('\n', 'Foreign')], [('마지막', 'Noun'), ('순간', 'Noun'), ('손가락', 'Noun'), ('으로', 'Josa'), ('총', 'Noun'), ('을', 'Josa'), ('만들어', 'Verb'), ('쏘실', 'Verb'), ('때', 'Noun'), ('에는', 'Josa'), ('제', 'Noun'), ('가', 'Josa'), ('직접', 'Noun'), ('맞는', 'Verb'), ('것', 'Noun'), ('같습니다', 'Adjective'), ('\n', 'Foreign')], [('어떻게', 'Adjective'), ('여성', 'Noun'), ('요리사', 'Noun'), ('보다', 'Josa'), ('더', 'Noun'), ('인기', 'Noun'), ('가', 'Josa'), ('많으', 'Adjective'), ('신지', 'Noun'), ('저', 'Noun'), ('도', 'Josa'), ('늘', 'Noun'), ('반찬', 'Noun'), ('만들', 'Verb'), ('때', 'Noun'), ('따라', 'Verb'), ('하고', 'Verb'), ('있답니다', 'Adjective'), ('\n', 'Foreign')], [('우리', 'Noun'), ('에게', 'Josa'), ('맛있는', 'Adjective'), ('음식', 'Noun'), ('을', 'Josa'), ('전', 'Noun'), ('하시는', 'Verb'), ('맥주', 'Noun'), ('부', 'Noun'), ('님', 'Suffix'), ('당신', 'Noun'), ('멋져', 'Adjective'), ('\n', 'Foreign')], [('활동', 'Noun'), ('혜택', 'Noun'), ('으로', 'Josa'), ('오션월드', 'Noun'), ('입장권', 'Noun'), ('2', 'Number'), ('매', 'Noun'), ('까지', 'Josa'), ('주는', 'Verb'), ('폴', 'Noun'), ('인', 'Noun'), ('러브', 'Noun'), ('\n', 'Foreign')], [('그리고', 'Conjunction'), ('100일', 'Number'), ('도', 'Foreign'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('응원', 'Noun'), ('합니다', 'Verb'), ('그리고', 'Conjunction'), ('사랑', 'Noun'), ('합니다', 'Verb'), ('파이팅', 'Noun'), ('\n', 'Foreign')], [('형님', 'Noun'), ('이', 'Josa'), ('올해', 'Noun'), ('우리', 'Noun'), ('팀', 'Noun'), ('으로', 'Josa'), ('온다고', 'Verb'), ('해서', 'Verb'), ('얼마나', 'Noun'), ('기뻤는지', 'Adjective'), ('몰라요', 'Verb'), ('\n', 'Foreign')], [('예', 'Noun'), ('500일', 'Number'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('생일', 'Noun'), ('진심', 'Noun'), ('으로', 'Josa'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('축하', 'Noun'), ('\n', 'Foreign')], [('요리', 'Noun'), ('가', 'Josa'), ('차암쉽쥬', 'Noun'), ('\n', 'Foreign')], [('10년', 'Number'), ('뒤', 'Noun'), ('손', 'Noun'), ('편지', 'Noun'), ('쓰고', 'Verb'), ('꼭', 'Noun'), ('이', 'Noun'), ('감회', 'Noun'), ('도', 'Josa'), ('갈게요', 'Verb'), ('\n', 'Foreign')], [('요리', 'Noun'), ('의', 'Josa'), ('매력', 'Noun'), ('에', 'Josa'), ('빠졌어요', 'Verb'), ('\n', 'Foreign')], [('300일', 'Number'), ('너무', 'Adverb'), ('너무', 'Adverb'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('항상', 'Noun'), ('밝은', 'Verb'), ('에너지', 'Noun'), ('덕분', 'Noun'), ('에', 'Josa'), ('힘', 'Noun'), ('이', 'Josa'), ('납니다', 'Verb'), ('\n', 'Foreign')], [('대단하신', 'Adjective'), ('우리', 'Noun'), ('선생님', 'Noun'), ('파이팅', 'Noun'), ('요', 'Josa'), ('\n', 'Foreign')], [('파이팅', 'Noun'), ('\n', 'Foreign')], [('제일', 'Noun'), ('처럼', 'Josa'), ('기쁘고', 'Adjective'), ('좋은데', 'Adjective'), ('\n', 'Foreign')], [('생일', 'Noun'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('덕분', 'Noun'), ('에', 'Josa'), ('요리', 'Noun'), ('가', 'Josa'), ('즐거워요', 'Adjective'), ('\n', 'Foreign')], [('800일', 'Number'), ('축하', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign')], [('이런', 'Adjective'), ('오늘', 'Noun'), ('신문', 'Noun'), ('을', 'Josa'), ('보니', 'Verb'), ('엘지', 'Noun'), ('가', 'Josa'), ('올', 'Verb'), ('시즌', 'Noun'), ('을', 'Josa'), ('포기', 'Noun'), ('한다고', 'Verb'), ('나왔더라고요', 'Verb'), ('\n', 'Foreign')], [('내일', 'Noun'), ('생일', 'Noun'), ('이라', 'Josa'), ('한번', 'Noun'), ('가보려고요', 'Verb'), ('\n', 'Foreign')], [('너무', 'Adverb'), ('너무', 'Adverb'), ('좋아요', 'Adjective'), ('\n', 'Foreign')], [('역시', 'Noun'), ('프로', 'Noun'), ('입니다', 'Adjective'), ('\n', 'Foreign')], [('1', 'Number'), ('위', 'Noun'), ('한', 'Verb'), ('것', 'Noun'), ('너무', 'Adverb'), ('축하', 'Noun'), ('해요', 'Verb'), ('♡', 'Foreign'), (' ...

# %%
noun_list3=[] 
for sentence in morphs :
    for word, tag in sentence : 
        if tag in ['NNG','NNP'] : 
            noun_list3.append(word) 
print(noun_list3)
# Out:
# []

# %%
count3 = Counter(noun_list3)
print(count3)
# Out:
# Counter()
