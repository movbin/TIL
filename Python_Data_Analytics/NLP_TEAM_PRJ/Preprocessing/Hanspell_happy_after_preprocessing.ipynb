# %%
import pandas as pd
df = pd.read_excel('C:/Users/dlrpa/Downloads/happy_preprocessing_after.xlsx')

df.head()
# Out:
#                                         Sentence Emotion
# 0                                 오라버니 해피투게더 봤어요      행복
# 1                우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.      행복
# 2                                     웃긴거 알죠~?ㅋㅋ      행복
# 3                        덕분에 주방에서 요리하는게 엄청 좋아졌어요      행복
# 4   마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ      행복

# %%
df['Sentence']
# Out:
# 0                                      오라버니 해피투게더 봤어요
# 1                     우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                          웃긴거 알죠~?ㅋㅋ
# 3                             덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4        마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#                             ...
# 6028                                  유느님 내일이면 하네요~^^
# 6029                               너에게 편지를 안 쓸 수가 없네.
# 6030                                  개그계 큰 대모 잘 봤습니다
# 6031                                        오라버니  봤어요
# 6032                                   오라버니 해피투게더 봤어요
# Name: Sentence, Length: 6033, dtype: object

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# Collecting git+https://github.com/ssut/py-hanspell.git
#   Cloning https://github.com/ssut/py-hanspell.git to c:\users\dlrpa\appdata\local\temp\pip-req-build-x2pqs0mo
# Requirement already satisfied: requests in c:\users\dlrpa\anaconda3\lib\site-packages (from py-hanspell==1.1) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests->py-hanspell==1.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests->py-hanspell==1.1) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests->py-hanspell==1.1) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests->py-hanspell==1.1) (2.10)
#   Running command git clone -q https://github.com/ssut/py-hanspell.git 'C:\Users\dlrpa\AppData\Local\Temp\pip-req-build-x2pqs0mo'

# %%
sentence = pd.DataFrame() # 빈 데이터프레임 생성

# %%
sentence['original'] = df['Sentence'] # 불러온 엑셀에서 문장만 sentence 데이터프레임의 original 열에 추가

sentence.head()
# Out:
#                                         original
# 0                                 오라버니 해피투게더 봤어요
# 1                우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                     웃긴거 알죠~?ㅋㅋ
# 3                        덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4   마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ

# %%
# 문장의 앞뒤 공백을 제거한 new_sentence를 만들자
new_sentence = []

for s in sentence['original']:
    new_sentence.append(s.strip())

# %%
new_sentence
# Out:
# ['오라버니 해피투게더 봤어요',
#  '우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.',
#  '웃긴거 알죠~?ㅋㅋ',
#  '덕분에 주방에서 요리하는게 엄청 좋아졌어요',
#  '마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ',
#  '어떻게 여성 요리사 보다 더 인기가 많으신지...저도 늘 반찬 만들때 따라하고 있답니다.',
#  '우리에게 맛있는 음식을 전하시는 백주부님 당신 멋져',
#  '활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러버!',
#  '글구 100일도 축하해요...ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '응원합니다.그리고..사랑합니다.  화이팅!!!!',
#  '형님이 올해 우리팀으로 온다고 해서 얼마나 기뻤는지 몰라요',
#  '예 ~ 500일 축하해요',
#  '생일진심으로 축하해요',
#  '축하~!!!',
#  '요리가 차~암 쉽쥬~~~~^^',
#  '10년 뒤 손편지 쓰고 꼭 음감회도 갈게요!',
#  '요리의 매력에 빠졌어요',
#  '300일 너무너무 축하해요 ^^',
#  '항상 밝은 에너지 덕분에 힘이 납니다!!!',
#  '대단하신 우리 선생님, 화이팅요!!',
#  '화이팅!!^^',
#  '제 일처럼 기쁘고 좋은데....',
#  '생일 축하해요',
#  '덕분에 요리가 즐거워요~',
#  '800일 축하해요',
#  '이런, 오늘 신문을 보니 엘지가 올시즌을 포기한다구 나왔더라고요!!!',
#  '내일 생일이라 한번 가보려구요..ㅎㅎ~~',
#  '너무 너무 좋아요!!',
#  '역시 프로입니다 ㅎㅎ',
#  '1위 한 것 너무 축하해요 !♡',
#  '앞으로 언제나 함께 있을게요!',
#  '건강한 하루요~~~',
#  '하루에 2만명 넘고 너무 좋겠네요!!',
#  '7500일 축하해요',
#  '축하드려요.',
#  '그게 훨씬 귀엽고 더 어려보여요 진짜~',
#  '정말 행복해요.',
#  '딸바보 되시겠네요',
#  '*^^*화이팅~ (^^)/',
#  '화이팅~!!',
#  '항상 좋은 일 있길 바랄게요ㅎㅎㅎㅎ',
#  '오빠의 유쾌한 웃음소리가 들리는듯 하네요...',
#  '선수 화이팅!',
#  '매번 좋은 정보 감사합니다.',
#  '오늘이  600일이 되는 날 이에요♡♡',
#  '오늘이 바로 세븐틴 700일이 되는 날이에요!!',
#  '대상 수상 축하해요',
#  '생일 진심 축하드려요 ㅜㅜ!!!',
#  '세븐틴 예쁘다!!',
#  '무한도전에서 연기 넘 잘하셨어요...',
#  '자랑스럽네요~~',
#  '응원할게요^^',
#  '요즘 대세시죠.',
#  '울 오빠는 일등 신랑감!',
#  '꼭 봤으면 하는 영화 1위.',
#  '님을 보고 요리에 대해 관심이 생겼어요!!',
#  '오빠 생일축하해요',
#  '일과처럼 들어오는 카페가 되었네요.',
#  '나이에 상관 없이 진짜 열심히 뛰어 주는 우리 아저씨 화이팅입니다!!',
#  '오늘 콘서트 했는데 다치지 말고 숙소 잘 들어가요',
#  '날씨는 춥고 행복한 일도 없지만 그래도 우리 모두 화이팅 입니다.',
#  '님 응원도 하구요',
#  '나도 외국에서 응원할게',
#  '게다가 위트도 있으시고 편안한 인상 너무 좋습니다',
#  '형님의 생일을 진심으로 축하축하합니다....',
#  '팬클럽 창단식해요!!!!!!!!!!ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어색하면서도  건방지지만  병풍같은 형님 정말 축하드립니다  ㅋㅋ',
#  '이번에 1루수로 기용하신 것 너무 잘하셨네요.',
#  '너무반갑습니다.',
#  '움직이는 물체를 100% 잡아내니 야간에 가게에 혼자 있어서 무섭지가 않아요!',
#  '일단 다른말이 필요 없을듯...님 수고하셧습니다.!!',
#  '기분 좋은 맘으로 요리를 하면 맛도 업!',
#  '오빠가 선수의 위치에서 떠나는 그날까지~',
#  '늘 웃음을주는 님 생일을진심으로 축하합니다!~~^^♥♥♥',
#  '마음도 넓고 굳세니 잘 할 거임^^',
#  '벌써 9월 5일이라는 시간이 다가왔네요!',
#  '오늘 하루도 수고하셨어요!',
#  '다른 사람들이 오빠보고 다 진상이라고 해도  전  오빠를 좋아할 거에요',
#  '그럼 오빠 오늘 하루도 행쇼~♥',
#  '누나 생일 축하드려요',
#  '항상 응원합니다♥♥♥',
#  '내일과 또 제가 가는 내일모레 팬미팅도 멤버들과  함께 즐거운 추억 많이 만들어요~~',
#  '전 개인적으로 수록곡중에 웃음꽃이라는 노래가 참 좋은데 오늘 뮤직뱅크에서 이렇게 들으니까 또 기분이 새롭네요!',
#  '세븐틴 보컬팀 리더, 천재 작곡가  생일축하해요',
#  '화이팅 선수♥ 항상 당신을 응원합니다~',
#  '요즘 부쩍.^-^',
#  '진짜 많이 기다렸던 공개카페가 드디어 열렸어요',
#  '카페에서 몇 번 뵈었죠?',
#  '형님이 열애설이 진짜라면 축하드리고요..',
#  '오빠들 덕에 재미있는 크리스마스이브가 이렇게 마무리되서 기쁘고 오빠들도 메리크리스마스!!!',
#  '오늘은 무한도전하는날~',
#  '2016년 마무리 이쁘게하고 2017년은 또 새롭게 같이 시작해봐요??',
#  '음식도 웃으면서 기분 좋게 만들어야 더 맛있죠?',
#  '같이 가요',
#  '님 멋지세요^^',
#  '정말 재미있어요~^^',
#  '저두 오빠 무지 좋아해요 ^^---------------------',
#  '우하하하하하하그럼..',
#  '본인이 만족하고 행복해하니 팬 입장으로서도 뿌듯하네요.',
#  '정말 멋졌어요!',
#  '태어나줘서 너무 고맙고 세븐틴이어서 너무 고마워요',
#  '너무도 이쁘고 멋진 미소이심',
#  '다음 시즌때는 도시락 싸들고 응원 갈게요',
#  '화이팅 대한민국 만세!!!',
#  '요즘은 스포츠 뉴스를 보면 넘 기분 좋은거 있죠?',
#  '최우수상은 커녕 우수상도 못 받으셔서 mbc 뭐 이런데가 다 있나 했더니, 대상을 받으실 줄이야.',
#  '다시한번 생일축하하고.',
#  '신바람 나는 LG!!!',
#  '400일 정말 축하해!!',
#  '하지만 괜찮아요!!!',
#  '정말 진심으로축하드려요♥♥♥♥♥',
#  '그리고 발렌타인데이♡ ㅎㅎ',
#  '노래 정말 좋고 수고했어요!!!!',
#  '암튼 올시즌 첫 홈런 축하드립니다~~~',
#  '다음 시즌땐 고~~',
#  '게다가 곧있으면 생일!!',
#  '우히히.......  어제 무한도전 너무 재밌게 봤어요',
#  '내일 시험 끝나니까 내일 편지는 더 길게 쓸게요!',
#  '그리고 열심히 노래들어서 꼭 1등 시켜줄게요ㅎㅎ',
#  '홍홍홍홍  왜 이렇게 잘생겨졌냐면서..',
#  '아쉽지만 축하해요',
#  '하하하 결혼도 축하하고요!!',
#  '안녕~오늘 더쇼 1위 진짜진짜 축하하고!',
#  '생일축하해요ㅎ',
#  '1시간 동안 재밌게 잘 볼게요',
#  '오빠 생일 축하해요!!!',
#  '잊지 못할 크리스마스 선물 줘서 진짜 고맙고 앞으로도 절대 잊지 못할 것 같아요ㅎㅎ',
#  '이제 확실히 폼 떨어진줄 알았더니 귀신같이 다시 골 머신됨 ㅋㅋㅋㅋ',
#  '기자 싱글벙글 곧 댓글 1500개',
#  '유명짤 하나 탄생했네 ㅋㅋㅋ',
#  '역쉬 ~~^^',
#  '축하합니다. 행복하세요^^',
#  '나이스 4명깔았다',
#  '이 젊은이들이 있기에.... 아직은 희망을 가져봅니다....',
#  '엘지져서 기분좋은사람??',
#  '화이팅!!!',
#  '덕분에 너무 재미 있었음',
#  '오늘 촬영하는거 봤는데 존나 잘생김',
#  'ㅋㅋㅋ봐라 얼마나억울하냐',
#  '또 이걸 해냅니다~^^',
#  '축하해요♥♥♥♥♥♥',
#  '올해는 케베스의 해였네 누굴 줘도 이상하지 않아. 다 인정이야',
#  '캬!! 장관이고 자연의 아름다움이 느껴지네',
#  '이제 시작이다!!',
#  '오 엠비씨 자네 왔는가 ㅋ',
#  '연예인들 전부이러면 악플러들 많이 사라질텐데 잘햇다',
#  '기상캐스터 머리 보니 날씨 짐작이 갑니다^^',
#  '여기 댓글도 아주 난리났네 대박나자!!',
#  '인물도 곱고 맘씨도 아름다워라~~♡♡♡',
#  '최고~~^^',
#  '너 진짜 웃겨 인정 이제야 재능을 살리는듯',
#  '진짜 이쁘다',
#  '노래는 지금들어도 정말 좋은데 다시 재결합을 한다니까 너무 기대되네요!',
#  '잘 되어서 기분좋네!',
#  '너무 귀엽고 웃김 ㅋㅋㅋ',
#  '결혼하고 싶어요',
#  '어머님들 표정이 진짜 재밌었음. 진짜 리얼 표정 ㅎㅎㅎ',
#  '오락가락이 붙었다!!!!!ㅋㅋㅋ',
#  '우리나라는 양호한거네 위로가 된다',
#  '이런 저질프로가 폐지되어서 정말 행복합니다. 대한민국 만세',
#  '진짜 고생했다 받을만했음 ㅊㅋㅊㅋ',
#  '정말 대단하고 멋지십니다~♥',
#  '후반에 중앙이동이 신의 한수였다',
#  '나도 친구분처럼 가장 웃기다고 생각 했었는데 지금은 정말 멋있는 개그맨이 된 듯',
#  '삼촌 축하해요!!♡',
#  '아는형님 진짜 개재밋음ㅋㅋ',
#  '언제봐도 늘 멋져요~♡',
#  '경기가 기대된다ㅎㅎ',
#  '18년 뒤면 그래도 살아잇네 다행',
#  '힘내세요!!♥♥♥',
#  '내 고향 울진!',
#  '더울 땐 사무실이 짱....',
#  '흥해랏^^~~~~',
#  '풍악을 울려라~~!!',
#  '오호호호 ! 내일 하는군요!',
#  '화이팅!!! ㅠㅅㅠ',
#  '축하합니다!!',
#  '요즘 배우 참 이쁘던데~~^^',
#  '신범죄구단 엔씨 ㅋㅋㅋㅋㅋㅋㅋㅋ 축하한다',
#  '정말 국내에선 톱타자보다 못했으나 국제경기에 가면 상당히 강했나보네~ 내년 시즌 기대해도 좋다.',
#  '미안하다 우리가 승리다',
#  '연기 너무 잘하셔서 호감!!',
#  '연기는 연기고 사생활은 사생활 일 뿐~~축하!',
#  '오 드디어 ㅋㅋ 열일하는 ㅋㅋ',
#  '축하드려요',
#  '대전 날씨 매우 맑음.',
#  '똑똑하다 그랬는데... ㅊㅋㅊㅋ',
#  '기부천사 !!!',
#  '어제 너무 재밌게봤어요!오늘도 기대합니다!',
#  '머머리아재들 희소식 노벨상감',
#  '화이팅!!!',
#  '연기 너무 잘해요~!!',
#  '조기에 빠른 대처를 하신 기장 및 승무원 그리고 지시에 따라주신 승객까지.. 모두 잘하셨습니다!',
#  '오늘 지렸다...ㅠㅠㅠㅠㅠㅠ',
#  '보면서 너무 흐뭇함~~',
#  '너무 잘하는데 더 더 잘되라~!ㅎ',
#  '축하드려요~~!',
#  '흥해라 흥해라 ~~',
#  '오늘 12시에 음원 나와요^^많이 들어주세요~',
#  '좋아요!!!!맨날 들어야지~~~~~♥?힘!!',
#  '멋지다 추진력~~!!',
#  '수술 찬성할 때 정말 리액션 귀여웠음',
#  '얼굴부터 마음까지 예쁜 우리 언니! 응원할게요!!!',
#  '연말에 배우 볼수 있다 ...좋다~~~',
#  '기아가 영입할듯?35년 기아팬이??',
#  '대상 축하드립니다',
#  '무한상사 야유회 때 정말 웃겼는데.. 아쉽네요',
#  '이 나이에 이 정도 활약하는거 보면 전성기 때 epl갔으면 씹어 먹었을 듯.',
#  'ㅋㅋㅋㅋ난 코빅에서부터 좋았어 ㅋㅋ 이대로 고정까지 가라 ㅋㅋ근데 안티가 별로 없네 ㅋㅋ 머리스타일이 초딩 같음 ㅋㅋㅋ 까불까불한 초딩 ㅋㅋ',
#  '나이스샷 ~~~~~',
#  '이태원 바에서 봤는데 성격 엄청 좋아보임 ㅎㅎ 물론 얼굴도 예쁨 행쇼',
#  '공민왕 후손인가 ㅋㅋ',
#  '연기 인정하죠 매력적이고',
#  '너무도 착하고 천사 같은 화이팅',
#  '좋은 관계 잘 유지하세요. 결혼까지 가면 좋지만 ...^^',
#  '차우찬가지고 쥐레발은 좀 너무하지않냐 ㅋㅋㅋㅋㅋㅋㅋ',
#  '어딜가나 박자 놓치는 고문관 한둘은 나오는데 오늘 집회 촛불 소등 완벽했음.',
#  '물 들어오니까 제트엔진 달았네',
#  '여전히 두산이 최강이네 이리보고 저리봐도 4명이 다 잘해 ㅎㅎ',
#  '핸드폰 인증보다 아이핀인증이 아주 조금 더 편하더라.',
#  '임신이면 누가 뭐라하냐? 둘 다 성인인데 축하할 일이지!!',
#  '아직도 안 믿기지만 항상 응원할게♡♡♡',
#  '연기 너무 잘해요~ 너무 보고싶어요!',
#  '수상 축하드립니다~~',
#  '기대 기대 믿고 봅니다 ♡',
#  '앞으로 많이 행복하자',
#  '특검 잘하고있다!!!',
#  '기아가 승리한다.ㅇㅇ',
#  '멋지다 화이팅 오래 살아라',
#  '오늘도 남의 불행에 저절로 웃음이 나옵니다^^',
#  '저거다. 저게 바로 내가 기다리던 내 햄버거야',
#  '이쁘다 ㅠㅡㅠ 잘 되어서 흥하길!!',
#  '이거 보면 진짜 자기관리가 대단하다 최고의 선수다움',
#  '추워서 좋다',
#  '축하해♡♡♡!!',
#  '이 기사 개꿀잼',
#  'ㅋㅋㅋㅋㅋㅋㅋ졸라 웃긴다 ㅎ 주사 ㅋㅋㅋ',
#  '어려워지기 전에 기능 통과하고 쉬워진 도로주행 통과... 후진 따위 안하고 통과. 앙 개꿀띠',
#  '너무 몰입 되어서 오랜만에 좋은 드라마 봅니다~~연기를 너무 잘하세요',
#  '노래가 좋아',
#  '멋진~~!!',
#  '6만 원짜리 중고 자전거 사서 3달째 출퇴근하는데 배도 들어가고 자전거 값은 뽑음ㅋ',
#  '너무 신선하고 재밌어서...',
#  '배우 응원하고 기대합니다!',
#  '진짜 골키퍼 하드케리로 승점5점 땄네 ㅋㅋ',
#  '우리 집은 xp 아직도 잘 쓰는 중ㅋㅋ 사이트 안 되는 건 크롬 써서 하고',
#  '봐라 결국 돌아오잖니ㅋㅋㅋㅋㅋ',
#  '감사합니다',
#  '무조건 1번을 외치던 우리 아버지도 이제 슬슬 욕하기 시작ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '폭스바겐 같은 삼류기업이랑은 as나 서비스의 질이 틀리구먼 허허..',
#  '무조건 본다~~~^^파이팅~-ㅎㅎ',
#  '예전에 술마시고 냉장고에 볼일 본 사연 웃겼는데',
#  '대놓고 ppl이 어색하지 않은 요상한 드라마 ㅋㅋㅋㅋㅋ',
#  '축하해요 언니!!',
#  '응원합니다!!!! 꼭 대상 받으시길♥',
#  '???첼시가 이길텐데',
#  '믿고보는 감독님 빨리 보고싶다',
#  '기대기대~~왕기대~',
#  '역시 실력자들 !!!',
#  '오랜만에 시원하다~',
#  '완전 귀요미.',
#  '무도는 레전드만 내보내도 6개월은 떼울 수 있음ㅋㅋㅋ',
#  '멋져 멋져 다 멋져',
#  '멋지다 금메달감이다',
#  '악마의 연기 선곡은 진짜 신의 한수, 중간에 흉내 내는 건 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '구속 안된 게 내가 기분이 좋네 ~^^',
#  '더더더 흥해라 ㅊㅋㅊㅋ',
#  '축하드려요^^♡♡',
#  '사이다다',
#  '속이 다 시원합니다',
#  '기자님 예쁘세요',
#  '역시 ~ 알아서 잘해주네요~~ 쭉쭉 갑시다ㅎ',
#  '티벳가기 편하겠네',
#  '오 그렇네 재밌었던 영화',
#  '막내야! 돌아와서 반가웠어~~ 앞으로 더 분발하자.',
#  '날씨 좋~다~!!!!',
#  '화이팅!!!항상 응원할게요!!!!!!',
#  '기사를 잘 쓰시네요 ㅎㅎ 본방사수~',
#  '역시 명불허전 박효갓',
#  '족발 예약한 시간 됐구나~~',
#  '재미나겠어요~ 화이팅',
#  '진짜 눈 깜빡이는 시간도 아까운 드라마~~~',
#  '나오니 더욱 재미나겠네요..기다려집니다',
#  '회복하셨다니 다행입니다. 응원합니다!',
#  '믿고보는 배우~~본방사수',
#  '비가 촉촉히 와서 좋네요',
#  '프로야구 발전을 위해서 1라운드만 하기로 했습니다!!',
#  '잘생겼다. 귀엽고 섹시하고 매력이 많아',
#  '대단하다 대단해 ....',
#  '크면 좋은것이다..아빠를 자랑스럽게 생각할수 있어~ㅋ',
#  '진짜 재밌었다.마지막까지',
#  '삿포로 맥주 너무맛있다ㅜㅡㅜ',
#  '축하한다 축하한다 멋지다 멋지다',
#  '안 본 사이 더 예뻐 지셨어요.',
#  '여태 본 의학드라마 중 단연최고~',
#  '미쳐 활동 때 배추머리는 대박 카리스마 개쩔어',
#  '대박ㅠ못 하는게 뭐예요?',
#  '돌아가면서 뽀뽀 해주고 싶다 ♡',
#  '콜라도 마셔보고 저 영감 땡 잡았네',
#  '홈런에 무너져버렸네 엔씨 축하드려요',
#  '엘지 화이팅입니다!!',
#  '저희도 형님 오실 때마다 반갑고 좋습니다.',
#  '라이브 듣고 완전 소름.  기대된당!!!',
#  '예능이 무한도전 이전과 이후로 나뉘듯 드라마도 도깨비 이전과 이후로 나뉠 듯 정말 기똥찬 드라마 나왔네요^^',
#  '노래는 시바가 훨씬 좋다.. 그리고..귀엽고 좋다.. 활동을 몇 번만 더 하면 역주행한다',
#  'X맨 부활인가요?',
#  '존재감 쩔었음ㅎㅎㅎ',
#  '진심으로 축하드려요~ ㅎㅎ대박나세요 ㅎㅎㅎ',
#  '야식은 치킨이 진리군 ㅋ',
#  '완전 웃김 재밌어 스트레스빵',
#  '두 분 축하드려요! 나도 결혼하고 싶다 ㅜㅜ',
#  '축구 잘해.',
#  '날씨 관심 없고 기상캐스터 보러 온당 데헿',
#  '항상 행복하세요 좋은 곡으로 만나요~',
#  '우연적으로 파여진 흔적가지고 망상이 심한 사람들 보면 참 ,ㅋㅋ 개울가에 굴러다니는 돌도 잘 찾아보슈 재미난 모양 많수다',
#  '도전한 자는 멋지다^^',
#  '난 남잔데  멋진 모습 보는게 더 좋더라...암 낫 게이',
#  '한화에서 유일하게 관리받는분 ㅋㅋㅋㅋㅋㅋ',
#  '신선하다 그리고 지루하지 않아 보면서 힐링이 되는 기분이다..',
#  '나라를 구한다는 게 이런거지...',
#  '아 막판에 ses컨셉 콘서트보고 배꼽 빠지는 줄....',
#  '둘 다 잘생겼으니까 인기있지 ㅋㅋㅋ',
#  '지금 생각하면 유익한 프로그램이었던 듯',
#  '드라마화가 뭐 오나귀가 좀 특별나게 재밌었지만 이것도 좀 재밋어요',
#  '이렇다 저렇다 기자들의 말이 많지만 무한도전 특유의 재미가 있으니 그냥 믿고 봅니다.',
#  '우리 변호사님 최고라지요!!',
#  '난 일단 비쥬얼 짱인',
#  '기사에 임신으로 두 배의 기쁨이라니ㅠ',
#  '누가 봐도 아버지와 딸인데??ㅋㅋㅋㅋㅋㅋㅋ',
#  '미세먼지에 시달리다 보니 장맛비 소식이 이렇게 반갑네요!!',
#  '하면서 비교하면서 재밌었는데 ㅋㅋㅋㅋ"',
#  '기도하는 입보다 돕는 손이 더 이쁘다.',
#  '보면 떠올라 ㅋ',
#  '너무 예쁘고 사랑스러워요~',
#  '몰랐는데 훤칠하고 멋있음',
#  '진심으로 축하해요.',
#  '토트넘의 승리...!',
#  '요즘 최고 재미 나도 노래도 멋졌음',
#  '기사 볼 때마다 그냥 흐뭇하다 ㅋㅋㅋ',
#  '앞으로도 아이들의 건강한 웃음을 기대하겠습니다.',
#  '기부를 하는 본인이 더 행복하고 마음이 따뜻해진다는 걸~~~^^',
#  '와 축하축하 작가 감독 배우 다들 덕분에 드라마 잘 보고 있어요.',
#  '누나 예뻐요ㄹㅇㄹㅇㄹㅇㄹㅇ',
#  '그동안 수고 많으셨습니다..',
#  '유용한 정보인듯 합니다~~^^',
#  '찬성하는 정책이다!',
#  '어제 나올 때마다 웃은듯ㅋㅋㅋㅋㅋㅋ',
#  '금연한 돈으로 기부까지 ^^',
#  '왠만하면 글 안 남기는데 정말 대단하세요 ♡',
#  '멀리서나마 응원하고있어요 ㅎㅎ',
#  '축하드립니다.',
#  '진짜 둘 보면 저절로 엄마미소가 지어진다ㅋ',
#  '그래도 이제 밤엔 시원해서 좋아요',
#  '근데 피디는 개웃기다',
#  '참 괜찮네~',
#  '재미있을듯 화이팅.',
#  '시체팔이 실패 개꿀잼 ㅋㅋㅋㅋ',
#  '남자크루 같았으면 snl 폐지하자고 난리부르스를 쳤을텐데ㅋㅋ',
#  '어제 재밌게 봤는데',
#  '제가 하고 싶었던 걸 해주시니 가슴이 뻥 뚫리는 기분이네요',
#  '노래도 좋은데',
#  '특검,,, 확고한 의지가 엿보이네!!',
#  '신곡반갑네요ㆍ',
#  '꿀이로구나 둘이 붙어있는 씬 케미 최고',
#  '솔직히 안 오니까 좋기만 하다.',
#  '난 달이랑 태양보고 지구가 둥근줄 알았다 ㅋㅋㅋㅋㅋㅋ',
#  '아수라가 생각보다 재미가없엇고 럭키가 생각보다 너무 재밋어서 입소문으로 대박남ㅋㅋㅋ',
#  '진짜 존멋 개멋',
#  '솔직히 기분 좋다 ㅎㅎ',
#  '난 무도만의 콩트 되게 좋아요',
#  '축하드려요',
#  '여성분들 시청률이 꽤 놓은데 역사를 알고 보는 입장에서 너무 흥미진진합니다',
#  '넘어지는 장면은 진짜 혼자 시트콤 찍는 줄ㅋㅋㅋㅋ',
#  '기대보다 빨리 실현되어 너무나 행복하네요!!',
#  '보수의 해체를 축하한다',
#  '여름은 끝자락에 시원하고만~~',
#  '올해 한번 일 내보자~~감독님, 한화이글스 화이팅!!',
#  '그 와중에 던파는 재밌더라',
#  '앗싸 꽃 피는 춘삼월 좋은 소식 대한민국 방방곡곡 울려퍼지겠네',
#  '앞으로도 좋은 배우가 되었으면 좋겠다.',
#  '얼마나 꿈같을까 짝짝짝',
#  '님이 진짜 좋아하심ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '넥센 화이팅',
#  '저희 집도 아이들과 소등했어요^^',
#  '좋음.',
#  '새로운 역사의 시작을 준비해주세요!!',
#  '애기들 다행이다 ㅠㅠ',
#  '그래 하나 줘야지 축하합니다',
#  '그냥 감동이네요...',
#  '너무나 재미있음',
#  '어머님 너무 재미나요',
#  '화이팅♡',
#  '첫 등장할때 너무 예뻤음',
#  '대상 축하드려요.',
#  '멋지고 자랑스런 우리 국민!!',
#  '누나는 식빵 구울 때가 젤 멋있어요',
#  '와 다행이다!!!!!!',
#  '태극기 걸은 게 맘에 듭니다 !!!!',
#  '골 진짜 멋있게 들어갔다',
#  '그래도 인생드라마는 확정인 듯',
#  '대상 후보랑 숏터뷰 형식으로 얘기하는거 웃겨서 그거보고 껐다 ㅋㅋㅋㅋ',
#  '임신 축하드려요.',
#  '30초 요리ㅋㅋㅋㅋ',
#  '아이돌 중에서 미모 탑이다진짜!!',
#  '존잼 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋ안 데려오길 잘햇다ㅋㅋㅋ',
#  '완전 뿌듯 ~~',
#  '너무 귀엽네 ㅋㅋㅋㅋ',
#  '생활 속의 작은 기쁨 ㅎㅎ',
#  '그러지 말고 한번 더 보자!!ㅎㅎ',
#  '이제 연말이네요~',
#  '면접 안 보고 바로 최종합격은 아님?',
#  '국군장병 전우들아 수고해요 ~ㅋ',
#  '아기엄마들의 전투육아 스토리를 이모티콘으로 만들어 봤어요.',
#  '애들 편도나 기관지 쪽에 좋은 제품들 주길래 혹 하는 마음에 해봤어요 ㅎㅎㅎ',
#  '그 여자애가 연예인을 좋아해서 전에 생일 때도 앨범을 사줬는데 좋아하더라고요.',
#  '부산에 부릉부릉 갔는데~~ 해운대에~~바다 보러가서~~맛나게 스파게티도 먹어주시구~~',
#  '일 하면서 들었는데 커플 탄생인 거 같더라ㅋㅋㅋㅋㅋㅋ',
#  '외모상으로 똑 부러지고 야무질 거 같은 느낌 드는 여자',
#  '어떻게 하다보니 운 좋게?취업 안되면 오라는 회사 한 군데를 알게 되었는데요',
#  '나 말년휴가 나왔다 복귀하면 제대한다 ㅋㅋㅋㅋ',
#  '남중 남고를 지내왔던 저에게 디자인 대학은 정말 꿈만 같은 곳이었습니다.',
#  '오늘도 500원짜리 5개? 100원짜리 2개 주웠네 ~~~~',
#  '심장이 쿵쾅쿵쾅 그날을 잊을 수가 없다.............',
#  '4월에 첫 출근한 인턴인데 5월 4일 샌드위치데이에 회사 쉰다고 하더라구요.ㅎㅎ',
#  '아침에 눈 뜨자마자 ㅋㅋㅋ',
#  '근데 발렌테인데이 때 전 고급초콜릿이랑 백화점에서 옷 사줬어요 편지도 쓰고요.',
#  '다음 주부터 사각턱이랑 광대 눈 상담 받으러 상담투어 갑니다 ㅋㅋ',
#  '어차피 전 중국어를 공부할 생각이라 여기 신청했는데 보니까 괜찮은 거 같아서 남겨 봅니다 ~!',
#  '아.. 아무튼 좋네요0',
#  '귀가 따뜻해.ㅎㅎ',
#  '다들 응원 열심히 해봐요ㅎㅎ~~',
#  '제가 아직 취준생이라 돈은 별로 없어서 고민중이었는데 지금 세일도 많이 한다고 하더라고요',
#  '여긴 수수료도 안 받더라고요 ㅋㅋ',
#  '지금은 22살 아기는 이제 돌 됐어요',
#  '꽃다발 하나 선물해 보세요^^~~',
#  '인맥도 환영합니다^^',
#  '교복은 진짜 얘 만큼 잘 어울리는 애 없음',
#  '오늘은 치즈 김밥 줘서 덕분에 먹으면서 아침 맞이했다.',
#  '나처럼 지금 돌침대에 누워 있으니까 시원하기만 한데',
#  '빼고 다 내 스타일이야 넌 내꺼♥♥♥',
#  '천상여자 같은 느낌이야.',
#  '사진은 이뻐서ㅎ',
#  '내 자신이 대견해.',
#  '그걸 해줘야 릴렉스도 되고 복근이 이쁘게 생긴단다 ㅋㅋ',
#  '우리 다 잘 될 거 예요!',
#  '친구추가 할게요!!',
#  '아 진짜 덕분에 오랜만에 실컷 웃네요',
#  '지난 삼성전에서 6실점하고 승리 하신 것 너무 축하축하 드리구요',
#  '우리모두에게  진정한 도움이 되는 셰프님 - 국민셰프님  입니다.',
#  '반찬을 너무 쉽게 척척 만드시네요~',
#  '재밌고 늘 행복해진답니다',
#  '히히 안녕하세요',
#  '오빤 언제나 저에겐 최고에요 , 오홍홍',
#  '그리고 대상 축하드립니다~~~~',
#  '오빠 아프다는 소식 듣고 눈앞이 캄캄 했는데 오늘 그 어둠이 조금이라도 사라졌어요',
#  '이따 뵈어요!!',
#  '그래도이름이 있는것만으로 만족합니다!',
#  '어제 너무 좋았습니다.',
#  '건강하시고... 행복하세요!!',
#  'ㅋㅋㅋㅋㅋㅋ흑역사라 하긴 뭐한데 그 내가 쓴 댓글 보기 하는거 있잖아',
#  '상큼한 트레이닝복 화보 촬영중인 나!',
#  '외모는 충분히 이쁘다..',
#  '제대해서 좋아~~~~',
#  '끝까지 응원한다 !!',
#  '솔직히 여신인 거지???',
#  '잔머리 하나는 진짜 갑인 것 같아요 ㅋㅋㅋ',
#  '4개월 조금 넘은 아기입니다~',
#  '이러는데 너무 귀여워 죽겟다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '노래도 좋고',
#  '세븐틴에게 조공을 바치며 살아가겠습니다...',
#  'TV에서 자주 뵙는데 멋지십니다',
#  '너무너무 좋다',
#  '오늘 대박 세일가로 스틱 분유 사가지고 왔어요.',
#  '이것도 아무 말 대잔치인데 기분 요상하지 ?? ㅋㅋㅋㅋㅋㅋ',
#  '제주도 여행 계획 중입니다',
#  '결과적으로 여친이 한번 눈 감아준답니다.',
#  '수고가 많으시네요..참 멋있어요...참..멋져요..!!!앞으로..',
#  '멋진 님!',
#  '정말 오랫만에  아름다운 연기를 볼 수 있게 되어서 정말 기뻤어요.',
#  '메리크리스마스!!!!~      ㅋ',
#  '오빠의 행동 하나 하나가 우리에게 즐거움을 주네요.',
#  '생일 맞으신거 정말 진심으로 축하드려요.',
#  '><!오빠 감정 최고예요',
#  '너무 훌륭했어요!!!',
#  '제가 여기 동호회에 클럽을 만들었거든요..',
#  '서로 의식하게 되고 좋아하게 된 시기가 겹쳐서 너무 신기해요',
#  '궁금해서 여기 눈팅하고있는데 이거 너무 웃김 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '글 정리 같은 거랄까 그냥 깔끔한 걸 좋아해요 ..',
#  '24년동안 결심못했던 다이어트 님 덕분에 2주 넘게 다이어트 중!',
#  '무조건 증정이니 해볼만 한 이벤트 같네요~',
#  '헬스장 몇 년 다녀보니까 느끼는 건데 새해 첫 평일에는 사람들이 엄청 많습니다ㅋ',
#  '안녕하세요~^-^!',
#  '오늘 판에 들어와 보았는데 메인에 있어서 놀랐어요^^',
#  '응원할게요~새해 복 많이 받으세요!! ㅋㅋ',
#  '항상 팬들이 응원하고있답니다..',
#  '선수 너무너무 수고 많았어요!!!',
#  '선수가 1루로 복귀 한다니 참으로 기쁜 소식이군요.',
#  '생일 진심으로 축하하고 좋은 하루 보내요^^',
#  '생일 축하합니다~~!!',
#  '생일축하해요!',
#  '2일 후면 팬 된지 딱 1년 되네요ㅎㅎ',
#  '우와 이번 활동 많이 수고했어요ㅠㅠ',
#  '오늘 너무 자랑스럽구요...',
#  '3월내내 맴버들 생일이 없어서 축하 글 오랜만에 써요ㅠㅠ',
#  '다시 한번 축하축하~~',
#  '유재석 주니어의 탄생을 축하드려요~',
#  '이번 해투는 가요제 이후로 절 제일로 웃긴, 몸 개그와 언변이었다고 생각합니다!',
#  '님  파이팅 입니다 ^^',
#  '나오신다길래 좋아서 히히히 다보구 이름을 쳐봤는데 펜카페가 나오더라고요^^!',
#  '언제 어디서나 기분 좋게 바라 볼수 있는 분!!',
#  '진심으로 생일 축하한다',
#  '오늘 밤 SBS 11시 25분 첫 방송~!!!',
#  '생일 축하해 ♡ 아!',
#  '오빠 참 좋아요.///^-^',
#  '아시아투어 건강하게 잘 갔다 와요!!',
#  '선생님 요리 정말 재미있어요.',
#  '만능간장으로 채소요리도 쉽게~~',
#  '백주부님 덕분에 요리가 갈수록 스피드하고 맛이 있어지는거 같아요~^^*',
#  '오라버니 하늘이 파랗게 있으니 날씨가 좋더라고요',
#  '선수의 LG팬으로써 진심으로 축하 드리고요.',
#  '꼭 본방사수해서 시청 잘 할게요^^',
#  '그리고 실검 1위도 축하해요????',
#  '나도!!!',
#  '개설한지 5주년이 됐네요 !',
#  '앞으로도 무한도전에서 더욱 더 좋은 모습 재미있는 모습 기대 할게요~>ㅁ<',
#  '진심으로 생일 축하드려요!!!',
#  '생일축하해 ,,',
#  '형은 언제나 최고였고 앞으로도 최고의 선수일 거예요.',
#  '아 오늘 생일이네요 ㅋㅋ',
#  '화이팅!!!',
#  '오빠, 오늘 무도 정말재밌게 봤어요 ㅎㅎ!!',
#  '오늘 드디어 데뷔 600일~~~',
#  '덕을 보네요',
#  '요리 프로그램이 한 다음 날은 우리 집 메뉴가 풍성해집니다.',
#  '대기록 달성 축하해요.',
#  '오늘 공개카페 왔다 갔죠~',
#  '진짜 너무너무 진심으로 너의 탄생일을 축하한다ㅠㅠㅠㅠ',
#  '웃고 싶을땐 형만 보는듯..ㅋㅋㅋㅋ)',
#  '오빠 생일축하해요!!!',
#  '역시 오빠 생일이니까 사진은 오랜만에 오빠 짧은 머리로~',
#  '새해가 밝네요',
#  '와우 진짜 오랜만에 여기 왔어요ㅠㅠ',
#  '데뷔한지 얼마 안된 것 같지만 벌써 1주년이 지나고 오빠도 데뷔하고 두 번째 생일이네요.',
#  '티비에서 자주 뵈니 좋습니다',
#  '제가 오빠를 좋아한 건  94년 오빠가 데뷔했을 때죠!',
#  '그렇게 최고 자리에 있으면서도 끊임 없이 발전하는 모습이 너무 보기 좋네요...',
#  '그리고 새해 복 많이 받으세요 ㅋㅋㅋ',
#  '형님 사실이면 축하드립니다',
#  '생일 축하 드리고요~~',
#  '마음이지만 정말로 생일 축하드립니다.',
#  '항상 건강하시고 이번 우승 축하합니다^^**',
#  '백주부님은 사람을 즐겁게 만드는 행복 바이러스..ㅎ',
#  '그럼 내일을위해 고고싱!! ㅋ',
#  '어제 자기 전만 해도 18등이었는데 지금 4등이나 올랐어요!',
#  '내일부터 추석 연휴에요~~  오빠!!',
#  '오늘은 벌써 제가 오빠를 좋아하게 된 지 90일!!',
#  '>_<  정말정말 열심히 하는 모습 보기 좋습니다.',
#  '방송에서 본 모습이 너무 좋아보여요.',
#  '이쁜아♡',
#  '세상에 어떤일이 있더라도 저에게 있어서는 최고입니다.!!',
#  '홧팅!^^',
#  '오빠 생일축하해요♡',
#  '오빠 안녕하세요!',
#  '만능간장으로 꽈리고추 볶음 엄청 맛나서 맛 들려서 매일 해 먹고요',
#  '95년도에 일본과 친선경기 때 처음 선수를 보고 팬이되었습니다.',
#  '그리고 생일 축하해요~~~^^',
#  '그러니깐 내가 초등학교 4학년 때부터 형을 좋아했어요!!',
#  '오늘은 해투 촬영날이자 무도 하는 날!!',
#  '백쌤 얼굴만 봐도 절로 입가에 미소가~',
#  '마지막으로 다시 700일 축하해요????',
#  '컴백까지 건강 챙기시고 멋있는 모습으로 만나요?',
#  '역시 오빠를 알아보시는 분이 계시군요..^^',
#  '독특한 억양이 너무  멋있습니다',
#  '일단 400일 축하해!!',
#  '역시 기대를 져버리지 않네요.',
#  '2010 올림픽이 열릴 벤쿠버 경기장에선 사대륙 첫 우승!!',
#  '아이스쇼로 스트레스가 날아갔어요~',
#  '이번 아이스쇼에 갔었어요!!!',
#  '그래서 선수도 좋아해요.......',
#  '그럼 저는 티켓팅 하러!!',
#  '앞으로도 영원히 사람을 사랑할 것을 맹세합니다',
#  '세상에 하나 뿐인 든든한 총괄리더 생일 축하해.',
#  '선수!!! 화이팅!!!ㅎㅎ',
#  '주말이 되면 무도 볼 생각에 진짜 좋더라고요 유느님 활약 기대됩니다',
#  'LG화이팅.... 화이팅',
#  '글 남겨요 ㅋㅋ',
#  '그렇게 살다보면 언젠가는 사람들이 알아주는 날이 오는 법이다.',
#  '다시 한번 정말 축하드립니다~!!',
#  '내일모레가 방학이에요!!!',
#  '생일 축하해♥♥',
#  '오빠 아까 해투 잘 봤어요ㅋㅋ',
#  '내일 데뷔 1주년이니까 멤버들 전체한테 한번 적으러 올게요',
#  '생일 축하해요!!',
#  '오늘 저녁시간에도 백주부님 만세요~~~',
#  '무한도전 지피지기!!',
#  '그래도 1kg이 빠졌어요~',
#  '오빠 21번째 생일 정말 축하해요',
#  '오빠들 1위 축하해요!!!!',
#  '시간이 늦었지만 오빠 생일 축하해!!',
#  '진심으로 축하해!',
#  '저는 취미로 요리를 좋아하는 사람인데....제가 평소에 원했던 프로그램입니다.',
#  '님 덕분에 아빠들의 요리 솜씨가 상향 평준화되어 버려서 제 희소성이 떨어져 버렸거든요.',
#  '엘지 파이팅!',
#  '존재 자체만으로 큰 기쁨이었어요',
#  '너무 축하드려요 ㅠㅠ',
#  '그리고 요즘에 너무 뿌듯해요..',
#  '다음 번에는 꼭 1위 시켜드릴 수 있도록 노력하겠습니다♥',
#  '팬들을 위해서 열심히 싸워 주십시오....^^',
#  '오늘 짱이었어요~',
#  '세븐틴 만세 만세 만만세!!!',
#  '다 비켜 우리 오빠가 최고야ㅜㅜㅜ',
#  '축하합니다~ 축하합니다~',
#  '세븐틴에게 지금이 소중한 추억으로 기억되고 있는 것 같아 내가 다 뿌듯하네ㅎㅎ',
#  '정말 생일 축하해요',
#  '앞으로는 다이아 길만 걷게 해줄게요!!',
#  '어제 전주 삼성 문회회관에서 콘서트 봤지요.',
#  '오라버니 또 다시 5월 셋째 주가 시작 하네요',
#  '오빠 졸업 축하하고!!',
#  '우리 함께 가요 !',
#  '챔피언 답습니다!',
#  '3:2로 삼성에 지고 있다가 선수가 솔로 홈런으로 동점을 만들었네요.',
#  '최고!^^',
#  '진심으로 축하합니다.',
#  '새해 복 많이 받으시고 올해도 건강하시고 화이팅하세요^^',
#  '프로로 영입한다네요',
#  '화이팅!!!!!!!!!!',
#  '텔레비전에서  수다 떨 때나 애드리브 할 때  눈웃음이 멋저요 ^^',
#  '오늘 저는 정말 힐링을 했어요!!',
#  '02년도부터 두각을 보이는 선수들 또한 돌아온 가세한다면..',
#  '정말 기쁩니다.',
#  '언니가 한 경기를 매일 되풀이 하며 보고 있습니다.',
#  '그래서 바로 다음카페를 가입하고 메찾사를 가입했습니다~',
#  '이번에 꼭 1위 시켜줄게요 ♡',
#  '팬 카페지기님, 차 한잔 마시며 잠시 휴식을 취하려 할 때 방안의 다른 친구 TV를 켜면 자주 눈에 띄시네요. 반갑습니다.',
#  '항상 기다릴테니까!',
#  '오빠~~~이 기세로~~~2008년에도~~~ 한 자리 하는거야~~~!!!',
#  '제가 가입한 지 얼마 안되고, 제가 그렇게 열렬히 카페 활동하지 않지만,  가입했다는 것 만으로도 기분 좋은 거요..',
#  '앞으로 더욱 멋진 모습 기대할게요ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '좋아 올해는 뭔가 필이 온다^^',
#  '광주엔 계속 비가 온다던데..',
#  '두 손 꼭 잡고 들었어요.',
#  '언제까지나 응원하고 기억할게요!!!^^',
#  '연습생 때는 그냥 빨리 데뷔했으면 좋겠다 했는데 이젠 일위도 하고 너무 자랑스럽다!!',
#  '방송 잘보고 있습니다..',
#  '각자 21살, 20살 생일이네요 ,,!',
#  '아 귀여워~~~~이번엔 꼭 보러가야지',
#  '후반으로갈수록 존잼 ㅎ',
#  '결과와 관계없이..그저 멤버들이..즐겁고 행복하게 원 없이 활동하는 모습..보고싶네요!!ㅎㅎ',
#  '에이 날도 더운데 여친이랑 시원한 모텔이나 가야겠다 ㅎㅎ',
#  '냠냠냠 모든 음식은 맛있게 먹어야 합니다.특히 야식',
#  '대박^^은근히 섹시한 계속 기다리게 됨 ㅎ',
#  '댓글 보고 있는 모양임. 죄다 반대 하나씩ㅋㅋㅋ',
#  '혼자서 던지고 치고 받고 다 하겠구나^♡^~',
#  '윤아 연기 잘하고 이쁘고 매력있어~~!',
#  '그 이후로 다 폭망..ㅋㅋㅋㅋㅋ',
#  'ㅎㅎㅎ예쁜 아기랑 행복하게 사세요~~~',
#  '힘내세요 선수',
#  '아싸 수요일 개이득 ㅎㅎ',
#  '임신 축하드려요 누나',
#  '오늘 너무 웃겨서 앞니 빠지는 줄 알았음! 눈치 보며 흘린 밥풀 주워 먹고 표정 ㅋㅋ',
#  '오늘 너무 웃겼어요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주모!! 연중무휴입니까??',
#  '왜 난 말하는데 당황하는 모습에 개웃겼는데 ㅋㅋㅋㅋ',
#  '역시 설날엔 설날도',
#  '성실하고 묵묵하고 좋지',
#  '오 이거 보자마자 대박을 외쳤음',
#  '대한민국에서 모르는 사람듵 있을까요?',
#  '진짜 맨유시절 역대 최고의 크랙이지...... 기가 막혔는데 진짜 ㅋㅋㅋ',
#  '어 ?짱구 엉덩이네 울라울라',
#  '그 와중에 게임하는 개웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아진짜 존잼이었다',
#  '기아가 내년에 우승하겠군요, 축하합니다.',
#  '와 대박 화이팅^^',
#  '말로 웃겨서 큰 소리로 웃게 한 아저씨는 처음',
#  '님이 나쁜 놈이 아니라 넘나 좋은거~~',
#  '공동수상 진심으로 축하합니다!!',
#  '고소한 참기름 냄새가 솔솔',
#  '재밌음ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋ 생각만 해도 웃김 기대돼요 화이팅!',
#  '연기 폭망하고 먹고살기 힘들지? ㅋㅋ',
#  '감방동기됐네',
#  '어머? 언니들 이 기사 너무 좋은데 어떡하지?',
#  '자전거가 최고',
#  '형님.. 의리 !!!',
#  '근데 진짜 잘생겼네ㅋㅋ 원빈 급이다',
#  'ㅋㅋㅋ 이따가 또 가야지ㅋㅋㅋ',
#  '아...이건 정말 신의 한 수 예요!!',
#  '사진 절묘하게 잘 골랐네ㅋㅋㅋ',
#  '정말 기다려지네요.대장 최고^^',
#  '진짜 제일 좋아하는 야구선수. 진심 멋지다.',
#  '조만간 스카우터들 한국 방문할 듯ㅎ',
#  '올해 최고 의학 드라마는 태양의 후예~ ㅇㅇ',
#  '이거 성공하면 우리나라 캐릭터 하나 건지는 거임!!!',
#  '이런 것 너무 좋아ㅋㅋㅋㅋ 질투 귀여울 것 같음ㅋㅋㅋㅋ',
#  '갓현주 연기 좋아요♡♡',
#  '내가 왔어요 ~ 꺄',
#  '축하드립니다. ㅋㅋ',
#  '금요일 토요일이 제일로 기다려지는 일인 입니다 너무 재미나요',
#  '이러다 무 투표 당선되는거 아니냐 ㅋㅋㅋㅋㅋ',
#  '능력 있는 어른의 모습.. 멋있어요♡',
#  '다행이다. 또 충돌 일어날까봐 10일부터 끌고 왔는데 못들어오게 하면 더 열 받아서 무슨 일 나는데 법원 잘했네..잘했어. 아저씨들 고생하셨어요. 다치지마세요.',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ자신있네 금요일이라 했다?',
#  '스마트폰 꼭 봐야 편하다 왜냐하면 스마트폰은 내 친구니까 스마트폰 하트',
#  '화이팅',
#  '걸그룹 대첩보다 이게 훨씬 더 재미있다',
#  '좋았어 우리 동네에 오신다',
#  '계주는 역시 방탄소년단!!!',
#  '능력자의 메뚜기 바지 벗길때 가장 기억에 남는다. ㅋㅋㅋㅋㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ',
#  '예쁘게 사는 배우네.',
#  '기아 타이거즈~!!!♡♡♡',
#  '유부녀 축하합니다 ^^',
#  '아침부터 로또번호 불러주네...ㅋㅋ',
#  '드디어...',
#  '잘 어울리는데 그냥 결혼해라 ㅎㅎ',
#  '무도 입성이라니!!! 꺄~~~~',
#  '역시 한국이 제일 안전해 ^.^',
#  '그다지 노잼일 거 같고... 그냥 섭외한다면 섭외능력에 감탄할 뿐 솔직히 재미는 없을 거 같다.. 족구하고 물공 헤딩하고 그런 거 하고 끝나겠지.. 오히려 메기 잡기는 꿀잼 일 거 같다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '항상 응원하고있어요~!',
#  '둘 다 잘 생겼다^^',
#  'JTBC 같은 언론이 있기에 저러는 거다.',
#  '케이팝스타 마지막이라 그런가 참가자 실력도 좋고 완전 꿀잼^^',
#  '싼 맛 엘지 굿....경험자임..',
#  '착하고 열심히 하는 게 다른 자질보다 백번 낫다',
#  '오랜만에 훈훈한 뉴스네요~',
#  '결방은 싫지만 연속 방송해주고, 스페셜도 보여준다니 그냥 넘어가야지^^',
#  'ㅋㅋㅋㅋㅋㅋ 진짜 호주가서 외국인들이랑 같이 롤하는데 한국사람이라서 영어 잘 못한다니까 한국사람? 아냐고 물어 봄 무조건 ㅋㅋㅋㅋㅋㅋ',
#  '어디서나 인정 받는 배우님 자랑스러워요!!???',
#  '역시 우린 짱깨와 다른 민족이었어.',
#  '축하드립니다 !!!!!!',
#  '혼자 식사 하기엔 곰탕이 최고??',
#  '콘서트 와이프 손잡고 가자고 해야겠다.',
#  '너무 잘 어울리고 이쁜 커플 ㅎㅎ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ 존나 웃기다 ㅋㅋㅋㅋㅋ',
#  '원인규명이 되었다니 다행이네요. 보완작업 잘하고 기능 추가해서 완벽한 갤노트8이 빨리 나오길 기다리고 있겠습니다.',
#  '이렇게 보니까 잘 어울린다♥',
#  '간만에 좋은소식 들어서 기분 좋네요.',
#  '오늘 날 잘 잡았어. 날씨 끝짱이다. 5000만 집결',
#  '다저스 큰일났네 ㅋㅋ',
#  '좋은 연기 보여주세요 응원합니다^^',
#  'ㅎㅎ 슬슬 생길 때 됐지',
#  '님 짱!!! ㅋ',
#  '너무 재미있음 오늘 보러 갔다 왔는데..또 보고싶음',
#  '재미나네 ㅋㅋ',
#  '위원 정말 사이다입니다.. 멋지십니다.',
#  '준비 잘해서 좋은 멤버들이랑 데뷔했으면 좋겠다!! 응원합니다!!',
#  '처음엔 음악대장의 팬이었다면 이젠 국가스텐의 팬이다',
#  '저런 것 고소해서 합의금 뜯으면 꿀^^',
#  '축하해~~~!!',
#  '싱그러운 청춘사극 분위기 너무 좋고 눈 호강도 제대로 한다ㅋㅋㅋㅋ',
#  '이런 거 보면 헬조선이긴 한데 한국에서 태어난 걸 감사해야 되는구나',
#  '레고는 시티 시리즈가 꿀잼이었는데 ㅋㅋㅋ 도로 판 사서 건물들 세워놓고',
#  '빨리 꺼지세요~~속이 시원하다',
#  '게임방 가서 광클릭해서 대기 4600명 뚫고 성공',
#  '악 누구인줄 ㅎㅎ',
#  '앞으로는 행복하렴.',
#  '신곡 지붕킥하자!!!!!!!',
#  '평화로운 시위로 믿음을 만들었기에 가능했다고 봅니다!',
#  '엘지 축하해요 기아 몫까지 최선을 다해 좋은 결과 얻길^^',
#  '그래 아주 잘했어요',
#  '시상식 3대 기획사 잔치인데 올해 YG부재에 방탄이 좋은기회를 받았네요.',
#  '오늘 치킨 시켜 먹어야지',
#  'sk에서 시구까지 하고 이미 그는 sk레전드입니다',
#  '호구든 거품이든 뒷돈이든 난 모르겠고 영입 참 잘했다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '15년 전 영종도 칼국수 집에서 뵈었는데..건강하세요^^~♡♡♡',
#  '고유어는 아름답다!',
#  'VR로 즐길듯..기대되네..',
#  '전복 이름 지어준거 겁나웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '너보다 걔가 낫다!',
#  '확실한부정 웃겨요ㅋ',
#  '조만간 구속수사?ㅋ',
#  '내 아들도 재학생(군복무 중)으로 자랑스럽네요',
#  '뒷북 꿀잼 ㅋㅋㅋㅋ',
#  '내일 한화 승 기아 엘쥐 패하면 재밌어지겟다 ㅋㅋ',
#  '굿... 꿩먹고 알먹고 누이 좋고 매부 좋고',
#  '2007년 전국의 텔미 열풍은 잊을 수 없다',
#  '비 좀 와라 좋은 현상임 굿굿',
#  '난 암전게임 재밌었음 재치있더라 귀여웠음ㅋㅋㅋ',
#  '진지하게 기사 읽다가 사진 보고 뿜었다ㅋㅋㅋㅋㅋㅋ',
#  '다른 배우분들도 잘하셨지만....정말 받을 만한 분이 받은 겁니다^~^',
#  '미리 ㅊㅋㅊㅋ',
#  '오 선택잘했다 롱런하길~',
#  '커플 대상 응원합니다!!!!!!!!!!',
#  '보고 싶었어요 멋있는',
#  '사이다~~~속 시원하다',
#  '예감적중!!',
#  '너무 이쁘다♡',
#  '능청스럽게 비굴한 연기도 잘 하고 귀엽고 사랑스러운 연기도 잘 하고 자연스럽게 잘해 잘해 예뻐 죽겠어~',
#  '생각보다 조합이 상상 안 감 ㅎㅎ 그치만 축하합니다',
#  '누나 수고했어요 ㅠㅠㅠ',
#  '대선 축하합니다......',
#  'NC 코리안시리즈 진출 축하드립니다.',
#  '이 아재 개그 좀 할 줄 아네 ㅋ',
#  '하야하기 좋은 날씨네요..',
#  '어제 나온 부부 너무 보기 좋더라~~좋았고 ^^',
#  '검은사제들에서의 카리스마~짱!!!',
#  '역시 명불허전 똥싸개 ㅋㅋㅋ',
#  '우리나란 아직 판매중!! 희귀템 구매 원하면 사면 됨!!!',
#  '의사봉 두드리는 소리가 저리 경쾌할 줄 누가 암? ㅋㅋ',
#  '하드캐리♡',
#  '수원 햇빛 좋다',
#  '그나마 다행이 기각폰은 안됐네 ㅋㅋㅋ 탄핵폰 ㅊㅋㅊㅋ',
#  '츄리닝처럼 쭉쭉 늘어나는 정장 너무 좋다',
#  '나의 멘토이자 우상 화이팅~~~행복하세요~~~',
#  '이 형 대상받는데 왜 내가 다 기분이 좋냐 ㅋ',
#  '얼굴 이미 다 팔렸는데 왜 가려 ㅋㅋㅋ',
#  '또 둿목 잡네 ㅋㅋㅋ',
#  '은근 개잘하지',
#  '옛날부터 존잘인데 왜 안 뜨나 했었는데 이번에 배역 제대로 맡아서 뜨나보다 ㅎㅎ',
#  '훈훈한 비주얼에 따뜻한 연출 기대할게요!!',
#  '이름 그대로 가요계의 신화.. !',
#  '대일본제국 만세~ 천황폐하 만세~',
#  '떠난 레전드 감독의 자리를 이어받을 듯!!!!',
#  '길 가다가 포켓몬고 하다 정신이 팔린 새끼가 지나가다가 똥 밟은 거 본적있다. 뒤에서 가는데 얼마나 웃기던지 ㅋㅋㅋㅋㅋ',
#  '만세 당선 축하합니다.',
#  '어떤 영화일지 너무 기대됩니다  화이팅',
#  'ㄹㅇ대박 날 만함...시청률 30%는 나와줘야지...개존잼 꿀잼 ㅇㅈ',
#  '존나 야무지게 달리네.ㅋㅋㅋㅋㅋㅋ',
#  '진짜 나랑 개그코드가 너무 똑같아서 배꼽 잡고 웃는다 너무 재밌어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '응원합니다. 화이팅',
#  '이참에 화성산업 주식이나 사볼까?ㅎㅎ',
#  'Vip 룸에서 tv 보며 팝콘 먹던 순시리 뜬금없는 팩폭 ㅋㅋㅋㅋ',
#  '좋은일 했네요 ^^',
#  '선발 로테이션 지 맘대로 조절해가며 충분히 표적 등판 시킬 듯...',
#  '잘생겼다~',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '슈돌 섭외력 우주돌파',
#  '존나 잘하네ㄷㄷ',
#  '앜ㅋㅋㅋ진짜 겁나 웃곀ㅋㅋㅋㅋㅋㅋ',
#  '축하드려요 ㅎㅎ.ㅎ',
#  '복귀 찬성~~!!',
#  '화이팅',
#  '타령이 제일 웃기네 ㅋㅋㅋㅋㅋ',
#  '야 음악 좋다!!!!!다!!!!!다!!!!',
#  '개웃길 듯ㅋㅋㅋㅋㅋㅋ',
#  '축하합니다~~너무 잘됐네요.',
#  '우린 가장 재밌어 ㅋㅋ',
#  '오늘은 일주일동안 기다렸어요~~♥♥♥',
#  '발가락이 닮았어요~',
#  '누나 나랑 사귀자ㅋㅋㅋ',
#  '노력하는 모습 보기 좋아요',
#  '반함~~~~~~♡♡♡',
#  '멋지다',
#  '경질이나 자진사퇴 기사가 났으면 여권을 불태워 버렸을텐데 ㅜㅜ한 해 동안 수고 많았어~~ ㅋㅋ메이저 가서도 승승장구 하기를!!',
#  '둘 다 순수하고 묘한 자기만의 세계가 어울림ㅎㅎ어서 결혼갑시다^^',
#  '눈 해주고 발 해줘서 다른 애들 조지는 건 진짜 쩔었다 ㅠㅠ',
#  '조금 뻔하긴 하지만 연출이 지린다 진짜',
#  '사람 참 괜찮네',
#  'ㅋㅋ 남자가 봐도 멋있다 말 진짜 잘한다.',
#  '키야 아들 잘생겼다',
#  '진심 축하드려요 한국영화계의 큰 경사네요',
#  '선수 축하합니다 진정한 프로 인간승리',
#  '형님 얼굴도 멋있으시고 행동도 멋있으십니다',
#  '이쁘다.좋아요^^노래 잘 부르세요!',
#  '땀노예 ㅜㅜ선수처럼 대박치길',
#  '눈물이 나는 기사네요.. 모두들 고생하셨습니다',
#  '어제 귀여워 죽는 줄ㅜㅜㅜㅜㅜㅜㅜ',
#  '야구는 어디서 하든 똑같다는 말 멋지다.',
#  '조연들이 좋네요.',
#  '멋지다...',
#  '완전 멋있다! 마음까지도',
#  '어휴 드디어 가네 이제 다시 무도 봐야겠다.',
#  '역시 갓짜장',
#  '대상 받는 것 보고 눈물나긴 처음',
#  '연기 진짜 잘한다.마지막 씬 보고 눈물이 줄줄 흘렀다.',
#  '가족 건강하게 해줘',
#  '엄마의 힘은 위대하다',
#  '너무 대단하시다 감동 ㅠ',
#  '하나님의 기적 잘 보았습니다',
#  '둘이 결혼하면 안 되나 잘 어울리는데',
#  '대한민국 사법정의를 바로 세우기 위해 밤낮 없이 일하시는 법관님들 존경합니다. 화이팅',
#  '예술가는 예술로 사회를 이야기하고 지켜 나가야 할 책임이 있다고 말한 피카소처럼 선생님의 처한 사회와 상황을 외면하지 않겠다는 맹세에 존경을 표합니다',
#  'KBS 특파원은 뉴스에서 보니까 지금 중국 상해에서 계속 계시던데 역시나 기자라서 그런지 글과 기사도 참 잘 쓰시네요',
#  '무엇보다 연기 앞에서 진지하고 성실한 부분이 박수 받아 마땅한 듯.',
#  '대한국민 만세',
#  '뭔가 이 뉴스가 엄청 위로가 된다ㅠ',
#  '오오...체험기 쓰시다니 노력하시네요',
#  '내 이상형인 누나다!!!!!!!!!!!!!!!!!',
#  '선수 그동안 기아에서 정말 수고 했어요~~삼성 가서도 응원 많이 할게요~^^화이팅!!',
#  '역시 이야 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '헐 . . .왠일 ! 2년동안 ??대박 . . . . . . 너무 축하드려요♥선남선녀',
#  '역시 멋진 사람',
#  '인생은 처럼!',
#  '우리 대한민국 국민들 정말 위대하십니다.',
#  '자기관리 철저한 사람 의지가 약해서 실패하는 일인으로 존경스럽습니다.',
#  '역할도 크다',
#  '형 사랑합니다 ㅠㅠ',
#  '무엇을 하든 자연스럽고 척이 없는데 그게 다 선하고 센스있어서 너무 좋음..',
#  '짱이다ㅠㅠ',
#  '나는 운동경기장에서 국민의례할 때 국가에 대한 자부심을 느낀다',
#  '사극 해도 한번 더 보고싶네요 강력 추천♡♡',
#  '자랑스런 대한민국 국민들 95%가 새 역사를 만들 것입니다 !!!',
#  '얼굴에 한민족의 점잖음이 기품이 묻어나네',
#  '두 분 축하드려요 다른 드라마에서 다시 같이 연기하는 것 보고싶네요^^',
#  '감동이네요^^ 화이팅!!',
#  '와 개간지다 ㅜㅜㅜㅜ',
#  '나의 황제는 이다.',
#  '토트넘 동료들이 훈련 때 보면 잘한다 함. 갑자기 잘하는 게 아니라 원래부터 잘했다 함 .놀랄 일도 아니라 함',
#  '본방사수 할게요^^',
#  '3주간 너무 재밌었어요 만세',
#  '멋있다..',
#  '음색에는 어떤 특별한 울림이 있어 자꾸 듣고 싶어진다. 이번에  완전 개취',
#  '진짜 겸손하다 ㅜㅜㅜㅜㅜㅜㅜ',
#  '양키스는 좀 먼 이야기 같긴 한데 어쨌든 지금 엘지 진짜 잘함 타 팀 팬이지만 이건 정말 인정',
#  '멋진 친구네요',
#  '신의 얼굴‥ 등골이 오싹하더라 표현 정말 좋았어 !!',
#  'ㅎㅎ 역시 재미있음!!!♡♡',
#  '한국 좀비영화 중에선 기대 이상',
#  '솔직히 연기 잘함',
#  '연기 개 잘해!!!',
#  '투표개표가 이렇게 흥미진진 할 수가...',
#  '멋있다~~~',
#  '고급스럽게 아름답다',
#  '아직도 이렇게 천사같이 좋은 분이 계시다니요ㅠ',
#  '대상 타는거 보려고 이 시간까지 봤다. 정말 기쁘고 속 시원하다. 축하드립니다',
#  '가슴 뭉클하다.!',
#  '전율이 ㄷㄷㄷㄷ 믿을 수 없어 ㅠ 고마워요 슈돌',
#  '노르웨이 교도소는 한국 호텔보다 좋던데 방은 좀 작지만 탈옥 빼고는 웬만큼 할 수 있는 건 다 되는 거 같고 면회실 보고 레스토랑인줄',
#  '감동이네요..눈물 난다',
#  '연기 진짜 잘 하시던데',
#  '진정한 여왕님 말씀 잘 들었습니다',
#  '오늘 첼시 경기력 지림',
#  '첫 사랑이 이루어졌네^^',
#  '밖에서 일하시는 분들 힘내세요 ^^ 화이팅',
#  '때문에 심장 미치잖아ㅠㅠㅠ',
#  '사랑할 수밖에 없는 남자',
#  '어느 한 곳이라도 특출나게 크고 있는 이들이 있어 다행이다',
#  '날로 잘생겨져가네',
#  '의리 한번 죽이네~',
#  '갑인듯....',
#  '나는 이래서 좋다',
#  '엄마미소ㅠㅜㅜㅜㅜㅜ',
#  '극찬한 이유가 있었어',
#  '코끝 찡하게하네요...화이팅!!!',
#  '안녕하세요~ 입니다~^^♡',
#  '당연히 받을 줄 알았다 이젠 대한민국을 대표하는 에이스 투수!!!',
#  '압도적이다 진짜',
#  '멋지십니다. 박수...',
#  '눈치보지 않고 하고자 하는 말씀 시원시원하게 해주시는 모습, 멋있습니다!',
#  '이 정도면 리버풀 승리',
#  '윗입술이 너무귀여워요 ㅎㅎ',
#  '좋은기사..한참동안 읽었네요^^',
#  '40대 남자가수들 중에 음원차트 올킬 할 수 있는 건  밖에 없을 듯',
#  '명절, 부모님 생신, 처갓집 어른 생신, 어버이날에 당연하다는 듯 집에 가자고 하는 집사람이 정말 너무 고맙네요.',
#  '연기 존나 잘해 우는데 너무 슬프더라ㅠㅠ개좋아ㅠㅠ',
#  '너무 너무 재미있는 드라마~!!',
#  '솔직히 제일 잘 했지',
#  '과연 좋아했을만하군',
#  '외압에 굴하지 않고 오뚜기처럼 일어선 대한민국의 진정한 영웅이다.',
#  '대륙은 뭐든 스케일이 남달라;;',
#  '잘생겼다......',
#  '80년이면 거의 37년을 연구했다는건데. 훌륭하오. 일본인이지만 존경스럽소.',
#  '위대한 대한민국 민중의 역사적 승리의 날로 오늘을 기억하라!',
#  '진실하게 말하는 모습 인상 깊습니다...',
#  '어떻게 이런 대사들을 쓸 수 있는지 알다가도 모르겠구나..',
#  "패션의 완성은 얼굴'을 결혼식에서 증명하는구만",
#  '파이널 보스!!!',
#  '언니는 백야행 때도 정말 아름다웠다고 생각 함',
#  '잘한다~~♡♡♡',
#  '너무 귀여우심',
#  '멋잇어요~~',
#  '축하합니다. 자랑스럽네요.',
#  '수요일, 목요일이 기다려집니다 ^^너무 재밌고 본방사수',
#  '드디어 가을야구의 주인공으로 자리 잡을 날이 오네요 감사합니다',
#  '너무 재미남ㅠㅠ 너무 존잘에 설레는데 코믹한 연기도 너무 잘해ㅋㅋ',
#  '잘 됐네 성공 하시길',
#  '영화는다 본 듯 연기짱이야',
#  '무도는 제게 참 소중한 프로예요!!감사합니다',
#  '티비에 안 나오는 건 잘한 결정임... 진정한 아부지네요~',
#  '남자인 내가 봐도 잘생겨 보이는데 여자들은 오죽할까 ㅋㅋ',
#  '만세 만만세.',
#  '맞는 말씀에 찬성 1표!',
#  '스타끼리의 만남이라 잘 어울리네요',
#  '나도 같이 울었음....',
#  '역시 얼굴도 착해 몸매도 착해 마음씨는 말할 것도 없네 ^^',
#  '형님 축하 ㅋㅋㅋㅋㅋㅋㅋ',
#  '우와 울컥 했다.ㅜㅠ 감동',
#  '진짜 참다운 선생님들이시네',
#  '책장 움직이는 거 멋있었어',
#  '진짜 명장이다..',
#  '우리 킹지환 갓지환은 사랑입니다 ♥? 문천재도 멀티홈런 멋졌어요 ^^',
#  '누나 가슴속에 3천원쯤은 있는 거잖아요!! 화이팅',
#  '힘들게 돌아온 길...좋은 결과로 이어졌으면 좋겠네요. 선수 화이팅!',
#  '비투비 화이팅 ㅠㅠㅠ 한 곡마저 짤렸지만 계속 응원할게요!ㅠㅠ♡',
#  '형님 대단하십니다... 존경합니다',
#  '제 인생 최고의 드라마였습니다',
#  '멋지다 역시',
#  '진심 멋지다! 고생하셨어요',
#  '힘내세요 2017년 화이팅!',
#  '재밌게 보고 있어요!! 이렇게 좋은 일을 하시는 걸 보면 정말 마음이 따뜻한 사람 같아요! 앞으로도 좋은 활약 기대합니다~~',
#  '그냥 보기만해도 기분이 좋아지는 매력이 있다. 마냥 흐뭇해지더라~',
#  '진짜 진짜 축하해ㅠㅠㅠ진짜ㅠㅠㅠ대단하다!!!',
#  '어머나~머리 스타일 하나로 이렇게 바뀌는구나~~귀엽네~~~',
#  '직접 가서 보니 오히려 기부하시던데 어르신들이',
#  '여전히 멋있는 모습으로 멋있는 생각을 가지고 있네요!! 당신의 길을 응원합니다!!',
#  '우리의 꿈과 희망 청소년들 멋있고 고마워~그리고 너네 젊은이 부러워~',
#  '기부했는데 ㅎㅎ 역시 친하게 지내는 그룹끼리♡ 방탄소년단 분들 마음씨 너무 착하세요!',
#  '인간 본받을만한 사람이다',
#  '♡♡ 멋짐..',
#  '기대해봅니다~~화이팅!!',
#  ...]

# %%
sentence['new'] = pd.DataFrame(new_sentence)  # 공백 제거한 new_sentence를 sentence df에 new가 열로 추가

# %%
sentence.head()
# Out:
#                                         original  \
# 0                                 오라버니 해피투게더 봤어요
# 1                우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                     웃긴거 알죠~?ㅋㅋ
# 3                        덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4   마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#
#                                             new
# 0                                오라버니 해피투게더 봤어요
# 1               우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                    웃긴거 알죠~?ㅋㅋ
# 3                       덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ

# %%
# 희진님이 정답 데이터 있는 데이터로 실험해주신 '가장 정확도가 높은 버전'으로 데이터를 변경
# 정규방정식을 통해 바꾼다.

# 정확도가 높은 버전 = ♡를 제외한 특수문자만 제거한, 원본 데이터를 최대한 살린 상태로 진행
withoutmark = []
withoutmark = sentence['new'].str.replace('[^가-힣A-Za-z0-9♡]', '') 

# 이렇게 써도 열이 추가 되는 것인지 써본다. ㅇㅇ된다. 
# sentence['hanspell_without_mark'] = sentence['new'].str.replace('[^가-힣 ]', '') # 한글 외 문자 및 자음, 모음 제거

# %%
sentence['without_mark'] = pd.DataFrame(withoutmark)

# %%
sentence.head(20)
# Out:
#                                              original  \
# 0                                      오라버니 해피투게더 봤어요
# 1                     우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                          웃긴거 알죠~?ㅋㅋ
# 3                             덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4        마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
# 5   어떻게 여성 요리사 보다 더 인기가 많으신지...저도 늘 반찬 만들때 따라하고 있답니다.
# 6                        우리에게 맛있는 음식을 전하시는 백주부님 당신 멋져
# 7                    활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러버!
# 8                           글구 100일도 축하해요...ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 9                          응원합니다.그리고..사랑합니다.  화이팅!!!!
# 10                   형님이 올해 우리팀으로 온다고 해서 얼마나 기뻤는지 몰라요
# 11                                      예 ~ 500일 축하해요
# 12                                        생일진심으로 축하해요
# 13                                             축하~!!!
# 14                                   요리가 차~암 쉽쥬~~~~^^
# 15                           10년 뒤 손편지 쓰고 꼭 음감회도 갈게요!
# 16                                       요리의 매력에 빠졌어요
# 17                                  300일 너무너무 축하해요 ^^
# 18                            항상 밝은 에너지 덕분에 힘이 납니다!!!
# 19                                대단하신 우리 선생님, 화이팅요!!
#
#                                                   new  \
# 0                                      오라버니 해피투게더 봤어요
# 1                     우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                          웃긴거 알죠~?ㅋㅋ
# 3                             덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4        마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
# 5   어떻게 여성 요리사 보다 더 인기가 많으신지...저도 늘 반찬 만들때 따라하고 있답니다.
# 6                        우리에게 맛있는 음식을 전하시는 백주부님 당신 멋져
# 7                    활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러버!
# 8                           글구 100일도 축하해요...ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 9                          응원합니다.그리고..사랑합니다.  화이팅!!!!
# 10                   형님이 올해 우리팀으로 온다고 해서 얼마나 기뻤는지 몰라요
# 11                                      예 ~ 500일 축하해요
# 12                                        생일진심으로 축하해요
# 13                                             축하~!!!
# 14                                   요리가 차~암 쉽쥬~~~~^^
# 15                           10년 뒤 손편지 쓰고 꼭 음감회도 갈게요!
# 16                                       요리의 매력에 빠졌어요
# 17                                  300일 너무너무 축하해요 ^^
# 18                            항상 밝은 에너지 덕분에 힘이 납니다!!!
# 19                                대단하신 우리 선생님, 화이팅요!!
#
#                           without_mark
# 0                         오라버니해피투게더봤어요
# 1              우리모두LG선수들이선전할수있게기를넣어줍시다
# 2                                웃긴거알죠
# 3                  덕분에주방에서요리하는게엄청좋아졌어요
# 4      마지막순간손가락으로총을만들어쏘실때에는제가직접맞는것같습니다
# 5   어떻게여성요리사보다더인기가많으신지저도늘반찬만들때따라하고있답니다
# 6               우리에게맛있는음식을전하시는백주부님당신멋져
# 7              활동혜택으로오션월드입장권2매까지주는폴인러버
# 8                          글구100일도축하해요
# 9                     응원합니다그리고사랑합니다화이팅
# 10           형님이올해우리팀으로온다고해서얼마나기뻤는지몰라요
# 11                           예500일축하해요
# 12                          생일진심으로축하해요
# 13                                  축하
# 14                             요리가차암쉽쥬
# 15                   10년뒤손편지쓰고꼭음감회도갈게요
# 16                          요리의매력에빠졌어요
# 17                        300일너무너무축하해요
# 18                     항상밝은에너지덕분에힘이납니다
# 19                       대단하신우리선생님화이팅요

# %%
# without_mark열로 hanspell 패키지 적용
# %time

from hanspell import spell_checker

hanspell_result = []

for s in sentence['without_mark']:  
    hanspell = spell_checker.check(s) # hanspell 활용하여 띄어쓰기 및 맞춤법 검사
    hanspell_result.append(hanspell.checked)
# Out:
# Wall time: 0 ns

# %%
print(hanspell_result)
# Out:
# ['오라버니 해피투게더 봤어요', '우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다', '웃긴 거 알죠', '덕분에 주방에서 요리하는 게 엄청 좋아졌어요', '마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다', '어떻게 여성 요리사보다 더 인기가 많으신지 저도 늘 반찬 만들 때 따라 하고 있답니다', '우리에게 맛있는 음식을 전하시는 맥주 부님 당신 멋져', '활동 혜택으로 오션월드 입장권 2매까지 주는 폴 인 러브', '그리고 100일도 축하해요', '응원합니다 그리고 사랑합니다 파이팅', '형님이 올해 우리 팀으로 온다고 해서 얼마나 기뻤는지 몰라요', '예 500일 축하해요', '생일 진심으로 축하해요', '축하', '요리가차암쉽쥬', '10년 뒤 손 편지 쓰고 꼭 이 감회도 갈게요', '요리의 매력에 빠졌어요', '300일 너무너무 축하해요', '항상 밝은 에너지 덕분에 힘이 납니다', '대단하신 우리 선생님 파이팅요', '파이팅', '제일처럼 기쁘고 좋은데', '생일 축하해요', '덕분에 요리가 즐거워요', '800일 축하해요', '이런 오늘 신문을 보니 엘지가 올 시즌을 포기한다고 나왔더라고요', '내일 생일이라 한번 가보려고요', '너무너무 좋아요', '역시 프로입니다', '1위 한 것 너무 축하해요♡', '앞으로 언제나 함께 있을게요', '건강한 하루요', '하루에 2만 명 넘고 너무 좋겠네요', '7500일 축하해요', '축하드려요', '그게 훨씬 귀엽고 더 어려 보여요 진짜', '정말 행복해요', '딸 바보 되시겠네요', '파이팅', '파이팅', '항상 좋은 일 있길 바랄게요', '오빠의 유쾌한 웃음소리가 들리는듯하네요', '선수 파이팅', '매번 좋은 정보감사합니다', '오늘 이 600일이 되는 날이에요♡♡', '오늘이 바로 세븐틴 700일이 되는 날이에요', '대상 수상 축하해요', '생일 진심 축하드려요', '세븐틴 예쁘다', '무한도전에서 연기 너무 잘 하셨어요', '자랑스럽네요', '응원할게요', '요즘 대세시죠', '울 오빠는 일 등 신랑감', '꼭 봤으면 하는 영화 1위', '님을 보고 요리에 대해 관심이 생겼어요', '오빠 생일 축하해요', '일과처럼 들어오는 카페가 되었네요', '나이에 상관없이 진짜 열심히 뛰어주는 우리 아저씨 파이팅입니다', '오늘 콘서트 했는데 다치지 말고 숙소 잘 들어가요', '날씨는 춥고 행복한 일도 없지만 그래도 우리 모두 파이팅입니다', '님 응원도 하고요', '나도 외국에서 응원할게', '게다가 위트도 있으시고 편안한 인상 너무 좋습니다', '형님의 생일을 진심으로 축하축하합니다', '팬클럽 창단식 해요', '어색하면서도 건방지지만 병풍 같은 형님 정말 축하드립니다', '이번에 1루수로 기용하신 것 너무 잘하셨네요', '너무 반갑습니다', '움직이는 물체를 100 잡아내니 야간에 가게에 혼자 있어서 무섭지가 않아요', '일단 다른 말이 필요 없을 듯님 수고하셨습니다', '기분 좋은 맘으로 요리를 하면 맛도 업', '오빠가 선수의 위치에서 떠나는 그날까지', '늘 웃음을 주는 님 생일을 진심으로 축하합니다', '마음도 넓고 굳세니 잘할 거임', '벌써 9월 5일이라는 시간이 다가왔네요', '오늘 하루도 수고하셨어요', '다른 사람들이 오빠 보고 다진 상이라고 해도 전 오빠를 좋아할 거예요', '그럼오빠오늘하루도행쇼', '누나 생일 축하드려요', '항상 응원합니다', '내일과 또 제가 가는 내일모레 팬미팅도 멤버들과 함께 즐거운 추억 많이 만들어요', '전개 인적으로 수록곡 중에 웃음꽃이라는 노래가 참 좋은데 오늘 뮤직뱅크에서 이렇게 들으니까 또 기분이 새롭네요', '세븐틴 보컬팀 리더 천재 작곡가 생일 축하해요', '파이팅 선수 항상 당신을 응원합니다', '요즘 부쩍', '진짜 많이 기다렸던 공개 카페가 드디어 열렸어요', '카페에서 몇 번 뵈었죠', '형님이 열애설이 진짜라면 축하드리고요', '오빠들 덕에 재미있는 크리스마스이브가 이렇게 마무리돼서 기쁘고 오빠들도 메리 크리스마스', '오늘은 무한도전하는 날', '2016년 마무리 이쁘게 하고 2017년은 또 새롭게 같이 시작해봐요', '음식도 웃으면서 기분 좋게 만들어야 더 맛있죠', '같이 가요', '님 멋지세요', '정말 재미있어요', '저도 오빠 무지 좋아해요', '우하하하 하하하 그럼', '본인이 만족하고 행복해하니 팬 입장으로서도 뿌듯하네요', '정말 멋졌어요', '태어나 줘서 너무 고맙고 세븐틴이어서 너무 고마워요', '너무도 이쁘고 멋진 미소이심', '다음 시즌 때는 도시락 싸 들고 응원 갈게요', '파이팅 대한민국 만세', '요즘은 스포츠 뉴스를 보면 너무 기분 좋은 거 있죠', '최우수 상은커녕 우수상도 못 받으셔서 mbc 뭐 이런 데가 다 있나 했더니 대상을 받으실 줄이야', '다시 한번 생일 축하하고', '신바람 나는 LG', '400일 정말 축하해', '하지만 괜찮아요', '정말 진심으로 축하드려요', '그리고 밸런타인데이♡', '노래 정말 좋고 수고했어요', '암튼 올 시즌 첫 홈런 축하드립니다', '다음 시즌 땐 고', '게다가 곧 있으면 생일', '우히히 어제 무한도전 너무 재밌게 봤어요', '내일 시험 끝나니까 내일 편지는 더 길게 쓸게요', '그리고 열심히 노래 들어서 꼭 1등 시켜줄게요', '홍홍홍홍왜이렇게잘생겨졌냐면서', '아쉽지만 축하해요', '하하하 결혼도 축하하고요', '안녕 오늘 더쇼 1위 진짜 진짜 축하하고', '생일 축하해요', '1시간 동안 재밌게 잘 볼게요', '오빠 생일 축하해요', '잊지 못할 크리스마스 선물 줘서 진짜 고맙고 앞으로도 절대 잊지 못할 것 같아요', '이제 확실히 폼 떨어진 줄 알았더니 귀신같이 다시 골 머신 됨', '기자 싱글벙글 곧 댓글 1500개', '유명 짤 하나 탄생했네', '역시', '축하합니다 행복하세요', '나이스 4명 깔았다', '이 젊은이들이 있기에 아직은 희망을 가져봅니다', '엘지 져서 기분 좋은 사람', '파이팅', '덕분에 너무 재미있었음', '오늘촬영하는거봤는데존나잘생김', '봐라 얼마나 억울하냐', '또 이걸 해냅니다', '축하해요', '올해는 케 베스의 하였네 누굴 줘도 이상하지 않아다 인정이야', '캬장관이고자연의아름다움이느껴지네', '이제 시작이다', '오 엠비시 자네 왔는가', '연예인들 전부 이러면 악플러들 많이 사라질 텐데 잘했다', '기상캐스터 머리 보니 날씨 짐작이 갑니다', '여기 댓글도 아주 난리 났네 대박 나자', '인물도 곱고 맘씨도 아름다워라♡♡♡', '최고', '너 진짜 웃겨 인정 이제야 재능을 살리는 듯', '진짜 이쁘다', '노래는 지금 들어도 정말 좋은데 다시 재결합을 한다니까 너무 기대되네요', '잘 되어서 기분 좋네', '너무 귀엽고 웃김', '결혼하고 싶어요', '어머님들 표정이 진짜 재밌었음 진짜 리얼 표정', '오락가락이 붙었다', '우리나라는 양호한 거네 위로가 된다', '이런 저질 프로가 폐지되어서 정말 행복합니다 대한민국 만세', '진짜 고생했다 받을만했음', '정말 대단하고 멋지십니다', '후반에 중앙이 동이 신의 한 수였다', '나도 친구분처럼 가장 웃기다고 생각했었는데 지금은 정말 멋있는 개그맨이 된 듯', '삼촌 축하해요♡', '아는 형님 진짜 개 재밌음', '언제 봐도 늘 멋져요♡', '경기가 기대된다', '18년 뒤면 그래도 살아 잇네 다행', '힘내세요', '내 고향 울진', '더울 땐 사무실이 짱', '흥해라', '풍악을 울려라', '오호호호 내일 하는군요', '파이팅', '축하합니다', '요즘 배우 참 이쁘던데', '신범죄 구단 엔씨 축하한다', '정말 국내에선 톱타자보다 못했으나 국제경기에 가면 상당히 강했나 보네 내년 시즌 기대해도 좋다', '미안하다 우리가 승리다', '연기 너무 잘하셔서 호감', '연기는 연기고 사생활은 사생활일 뿐 축하', '오 드디어 열 일하는', '축하드려요', '대전 날씨 매우 맑음', '똑똑하다 그랬는데', '기부천사', '어제 너무 재밌게 봤어요 오늘도 기대합니다', '머 머리 아재들 희소식 노벨상감', '파이팅', '연기 너무 잘해요', '조기에 빠른 대처를 하신 기장 및 승무원 그 ...

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dlrpa\anaconda3\lib\site-packages (3.0.4)
# Requirement already satisfied: jdcal in c:\users\dlrpa\anaconda3\lib\site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in c:\users\dlrpa\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
type(hanspell_result)
# Out:
# list

# %%
sentence['hanspell_result'] = pd.DataFrame(hanspell_result)

# %%
sentence.head()
# Out:
#                                         original  \
# 0                                 오라버니 해피투게더 봤어요
# 1                우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                     웃긴거 알죠~?ㅋㅋ
# 3                        덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4   마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#
#                                             new  \
# 0                                오라버니 해피투게더 봤어요
# 1               우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                    웃긴거 알죠~?ㅋㅋ
# 3                       덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#
#                       without_mark                             hanspell_result
# 0                     오라버니해피투게더봤어요                              오라버니 해피투게더 봤어요
# 1          우리모두LG선수들이선전할수있게기를넣어줍시다             우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다
# 2                            웃긴거알죠                                     웃긴 거 알죠
# 3              덕분에주방에서요리하는게엄청좋아졌어요                    덕분에 주방에서 요리하는 게 엄청 좋아졌어요
# 4  마지막순간손가락으로총을만들어쏘실때에는제가직접맞는것같습니다  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\dlrpa\AppData\Local\Temp\pip-req-build-fy60z0fx'
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\dlrpa\appdata\local\temp\pip-req-build-fy60z0fx
# Requirement already satisfied: tensorflow==2.4.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from pykospacing==0.4) (2.4.0)
# Requirement already satisfied: keras>=2.4.3 in c:\users\dlrpa\anaconda3\lib\site-packages (from pykospacing==0.4) (2.4.3)
# Requirement already satisfied: h5py==2.10.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from pykospacing==0.4) (2.10.0)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.7 in c:\users\dlrpa\anaconda3\lib\site-packages (from h5py==2.10.0->pykospacing==0.4) (1.19.5)
# Requirement already satisfied: six in c:\users\dlrpa\anaconda3\lib\site-packages (from h5py==2.10.0->pykospacing==0.4) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.2.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.32.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.1.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.12)
# Requirement already satisfied: absl-py~=0.10 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.12.0)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (2.4.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.7.4.2)
# Requirement already satisfied: gast==0.3.3 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.3.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.15.8)
# Requirement already satisfied: wheel~=0.35 in c:\users\dlrpa\appdata\roaming\python\python38\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.36.2)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorflow==2.4.0->pykospacing==0.4) (2.4.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\dlrpa\anaconda3\lib\site-packages (from keras>=2.4.3->pykospacing==0.4) (1.5.0)
# Requirement already satisfied: pyyaml in c:\users\dlrpa\anaconda3\lib\site-packages (from keras>=2.4.3->pykospacing==0.4) (5.3.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\dlrpa\appdata\roaming\python\python38\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (53.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\dlrpa\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dlrpa\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dlrpa\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dlrpa\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dlrpa\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.1.0)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
# Hanspell 진행 후에도 띄어쓰기가 안 되어 있는 문장만 뽑아 
# PyKoSpacing(띄어쓰기 패키지) 진행한다. 
# %%time

from pykospacing import spacing

spacing_sentence = []

for s in sentence['hanspell_result']:
    if ' ' not in s:                   # 띄어쓰기가 없다면
        print(s)
        kospacing_sentence = spacing(s) # pykospacing으로 띄어쓰기 해라
        spacing_sentence.append(kospacing_sentence)
    else:
        spacing_sentence.append(s)      # 띄어쓰기가 되어 있다면, 그대로 spacing_sentence에 추가해라
# Out:
# 축하
# 요리가차암쉽쥬
# 파이팅
# 축하드려요
# 파이팅
# 파이팅
# 자랑스럽네요
# 응원할게요
# 그럼오빠오늘하루도행쇼
# 홍홍홍홍왜이렇게잘생겨졌냐면서
# 역시
# 파이팅
# 오늘촬영하는거봤는데존나잘생김
# 축하해요
# 캬장관이고자연의아름다움이느껴지네
# 최고
# 힘내세요
# 흥해라
# 파이팅
# 축하합니다
# 축하드려요
# 기부천사
# 파이팅
# 축하드려요
# 난코빅에서부터좋았어이대로고정까지가라근데안티가별로없네머리스타일이초딩같음까불까불한초딩
# 이태원바에서봤는데성격엄청좋아보임물론얼굴도예쁨행쇼
# 축하해♡♡♡
# 어려워지기전에기능통과하고쉬워진도로주행통과후진따위안하고통과앙개꿀띠
# 멋진
# 감사합니다
# 완전귀요미
# 축하드려요♡♡
# 사이다다
# 역시명불허전박효갓
# 미쳐활동때배추머리는대박카리스마개쩔어
# 존재감쩔었음
# 날씨관심없고기상캐스터보러온당데헿
# 우연적으로파여진흔적가지고망상이심한사람들보면참개울가에굴러다니는돌도잘찾아보슈재미난모양많수다
# 축하드립니다
# 꿀이로구나둘이붙어있는씬케미최고
# 진짜존멋개멋
# 축하드려요
# 앗싸꽃피는춘삼월좋은소식대한민국방방곡곡울려퍼지겠네
# 좋음
# 파이팅♡
# 존잼
# 오빤언제나저에겐최고에요오홍홍
# 궁금해서여기눈팅하고있는데이거너무웃김
# 안녕하세요
# 나도
# 파이팅
# 그럼내일을위해고고싱
# 파이팅
# 챔피언답습니다
# 최고
# 파이팅
# 그래서바로다음카페를가입하고메찾사를가입했습니다
# 후반으로갈수록존잼
# 대한민국에서모르는사람듵있을까요
# 어짱구엉덩이네울라울라
# 그와중에게임하는개웃김
# 와대박화이팅
# 재밌음
# 축하드립니다
# 파이팅
# 기아타이거즈♡♡♡
# 드디어
# 축하드립니다
# 님짱
# 재미나네
# 축하해
# 미리
# 우리나란아직판매중희귀템구매원하면사면됨
# 하드캐리♡
# 또둿목잡네
# 존나야무지게달리네
# Vip룸에서tv보며팝콘먹던순시리뜬금없는팩폭
# 선발로테이션지맘대로조절해가며충분히표적등판시킬듯
# 잘생겼다
#
# 슈돌섭외력우주돌파
# 존나잘하네
# 앜진짜겁나웃곀
# 축하드려요
# 파이팅
# 반함♡♡♡
# 멋지다
# 눈해주고발해줘서다른애들조지는건진짜쩔었다
# 멋지다
# 역시이야
# 인생인처럼
# 최고다
# 본방사수할게요
# 멋있다
# 양키스는좀먼이야기같긴한데어쨌든지금엘지진짜잘함타팀팬이지만이건정말인정
# 멋있다
# 안녕하세요입니다♡
# 연기존나잘해우는데너무슬프더라개좋아
# 잘생겼다
# 잘한다♡♡♡
# 멋있어요
# ♡♡멋짐
# 참새삼대단하게느껴진다사진속에모습참훈훈한광경이네
# 두번정도결정력아쉬운거빼고다좋았다갓흥민
# 하시는사업항상응원합니다투잡하신다해도찬성입니다
# 아졸귀탱들♡♡♡♡
# 개지리겠다존멋본방사수해야지
# 이분음색이갑말할때도노래할때랑목소리가똑같은데너무섹시하고예쁘세요
# 끝사랑개존좋
# 맨탈갑
# 대단했어
# 사랑스럽습니다
# 축하축하
# 막정말리스펙해요
# 크흡작년에이직해서다니고있고집안이어려워서엄마도와준거때문에돈못모았는데천만원이눈앞에있어서기쁘네요오예
# 고마워
# 멋져멋져멋져
# 역시누님은넘사벽이에요
# 정말짱입니다
# 대박
# 비교를하면안되는넘사벽감독
# 수준
# 와아아아아아아아아아아아아정말진짜남자다
# 음색쩐다
# 에이핑크♡영원하자
# 이쁘다
# 엘지가독립군지원한회사였다는게왠지어울린다엘지흥해라
# 위엄
# 대단합니다
# 대단하다
# 존경스럽다
# 알고보면정말훈훈남
# 개이쁨
# 캬욕찰지게터트려주네
# 클래스
# 그냥꽃길만쭉걷자우리
# 월드클래스다
# JTBC진심쩐다권력에맞서네
# 갓세정대단하다
# 뭔들♡
# 와이쁘다
# 기대합니다♡
# 아씨제맘대로잘뻗고잘생겼네아휴흥
# 고마워
# 대단해요
# 고맙습니다
# 축하합니다
# 연기들이개쩔어요
# 와대단하다
# 멋지다
# 연기가점점훌륭멋집니다
# 캬멋지다
# 예뻐졌다
# 그렇게흠잡을데는없는것짱
# 파이팅
# 멋있다
# 진짜
# 멋지세요
# 대박
# 파이팅
# 최고이십니다
# 잘했다
# 직가님진찌배우신분원년멤버그대로가야의미가있다는말에전적으로동의합니다
# 별로안좋아했는데이번사건으로호감생겼다화난얼굴존나잘생겼더라
# 덕분이지
# 조합
# 인정합니다
# 배우인생작은아닐수도있겠지만진짜내인생작될각이네요
# 인정
# 오늘드디어태극기가좃불을눌렀다
# 단역배우들연기력도넘사벽
# 축하드립니다
# 드디어
# 응원할게
# 리스펙트
# 리스펙트
# 멋있다
# 등장
# 나댓글천개넘는거다읽을거왜냐구댓글속에서도나를울려
# 존경스럽습니다
# 와그래도스케일존나크네
# 파이팅
# 존나멋있어
# 탈아시아급
# 갓효신
# 대박
# 아주쩔어
# 귀여워
# 파이팅
# 감격이에요
# 감격했음
# 멋있군요
#
# 응원합니다
# 멋지십니다
# 자랑스러워요
# 영원하라
# 파이팅
# 캬영화한장면같다
# 수고하셨습니다
# 축하한다
# 대단하네
# 최고
# 오늘공쩐다이러다메이져갈거같다
# 맛있겠다
# 오늘진짜존나재밌다다음주도완전기대됨
# 멋있어라
# 분량늘려주세요이언니매력쩔어
# 응원합니다
# 역시우리형대인배인성
# 축하한다
# 갓재석님진짜존경함
# 박그네는순시리한테물어보고국사를펼쳤지만특검은국민들목소리만듣고합니다
# 섹시하네
# 아름답네요
# 대인배네대인배
# 캐스팅쩐다
# 리스펙트
# 소름역시갓효신
# 가빈
# 드라마존나재밌다액션에사극에뽀뽀씬에저승씨랑터널에서걸어주시고종합선물세트였네
# 명장이었다
# 간신으로나오신분되게순박해보였는데역시배우셔서그런지연기가함
# 감동이다
# 지금까지경기보면암걸리는기분이었는데엊그제는진짜존나잘했다
# 쩔어
# 최고
# 오마이걸
# 만세
# 멋있다
# 초특급귀요미
# 멋지다
# 감사합니다
# 백쌤께서도우리나라새로떠오르는음식계조리사계의태양으로우뚝서시길바랍니다
# 응원해드려요
# 대세
# 오로지뿐입니다
# 잘하더라
# 실물봤는데분위기개쩔고이쁜듯
# 와대단하다
# 대박
# 선생님유일한적통후계자
# 복받으시길
# 갓영표촌철살인지렸다
# 존경했습니다
# 0709시즌은진짜넘사벽
# 경건한치느님치멘
# 이쁘다
# 쩐다세배세리머니뜻을외국에서알면어썸거릴듯
# 내가아는스트레칭은몸쭉쭉늘려서근육풀어주는건데스트레칭은스쿼트랑런지라니역시운동선수는다르긴다르네
# 예쁘다
# 민주주의
# 사랑입니다
# 대박갓소라
# 존나멋있어
# 동생존경합니다소아암환자를돌보는당신아름답습니다
# 잘했구먼
# 파이팅
# 오아이무대개쩐다
# 최고
# 개간지
# 평화시위합시다
# 멋지다
# 위엄보소캬
# 축복합니다
# 감동적이에요
# 진짜이번에역대급이었고헤어져서울때나도같이펑펑울었다
# 갓윤아연기개쩐다
# 존나그래픽좋은세상임0
# 파이팅
# 멋집니다
# 안녕하세요님
# 우연히연아양경기모습을보게되었어요
# 감동이었습니다
# 으엉엉선수
# 주부로서요리의젬뱅인저를요리의신세계로이끌어주신백주부님제게는신입니다
# 오빠는짱먹고
# 짱입니다
# 오예박그네대통령님good
# 감사합니다
# 고생하셨습니다
# 엄마사랑합니다
# 수고하셨습니다
# 고맙습니다
# 감사합니다
# 감사합니다
# 수고하셨어요
# 감사했었습니다
# 감사합니다
# 감사
# 감사해요
# 감사
# 감사합니다
# 감사합니다
# 감사합니다
# 축하합니다
# 감사합니다
# 감사합니다
# 수고하셨어요
# 감사해요
# 감사합니다
# 감사해요
# 감사합니다
# 파이팅♡♡특검
# 존나재밌어꿀잼요즘나의낙♡♡
# 이번주도우리흥쩔었다진짜
# 감사해요
# 존경합니다
# 감사합니다
# 감사합니다
# 멋있는귀요미오빠를낳아주셔서감사합니다
# 감사합니다
# 감사합니다
# 감사드려요
# 감사합니다
# 백주부님레시피로맨날요리해주는우리남편저도열심히배우려고노력중이에요늘감사드려요
# 감사드려요
# 감사해요
# 감사해요
# 감사합니다
# 감사
# 감사합니다
# 고마워요한국정부보다낫네
# 감사합니다
# 갓윤미래
# 감사합니다
# 감사합니다
# 감사합니다
# 감사합니다
# 감사합니다
# 감사합니다
# 웃는모습보는것만으로도힐링되지않나요
# 감사합니다
# 감사해요
# 감사드려요
# 감사합니다
# 감사해요
# 언제나웃는모습과먹방의진수를보여주어감사합니다
# 파이팅
# 수고했습니다
# 감사합니다
# 감사합니다
# 수고하셨습니다
# 갓근형선생님건강한모습으로우리곁에서항상멋진연기보여주세요
# 특검
# 감사합니다
# 감사합니다
# 감사드립니다
# 감사합니다
# 감사드려요
# 감사해요
# 파이팅
# 감사합니다
# 감사합니다♡
# 감사합니다
# 감사드립니다
# 감사해요
# 덕분입니다
# 고맙습니다
# 감사했어요
# 파이팅
# 응원합니다
# 자랑스럽네
# 응원합니다♡♡
# 하나님
# 고마워
# 칭찬해
# 감사해요
# 감사합니다
# 감사합니다
# 감사해요
# 너무쉽게알려주시는백주부님화이팅
# 감사합니다
# 감사합니다
# 감사합니다
# 감사해요
# 감사합니다
# 감사드립니다
# 감사드립니다
# 백주부님화이팅
# 재미있었어요
# 특검짱청와대고소한번해보던가똥뀐놈이성낸다더니특검승
# 만세
# 역대급한번가자
# 뭐지저씹존귀탱이는
# 이렇게활용하야지갓신욱
# 잘생겼다
# 앗싸이제면접기준이달라져서나같은오크도길이열리겠군
# 누가봐도메달가능성전혀없겠는데웃고간다푸하하하하
# 파이팅
# 압승
# 잡아볼까
# 응원해요
# 축하합니다
# 나이스
# 기대됩니다
# 기다렸어
# 개이쁨
# 환영합니다
# 헐설마우리나라에서멘부커상수상자가나올줄이야정말놀랍다근데나멘부커상을오늘처음알음
# 잘했다
# 축하합니다
# 데려갈기셐
# 너무예쁘고연기도짱대박
# 막판5분이존나재밌다
# 오늘보러갔다가갓영미에게걸크러쉬당하고옴
# 자전거존나재밌어
# 축하드립니다
# 오랜만이네
# 짱
# 짱입니다
# 축하드려요
# 축하드립니다
# 응원합니다
# 부자겠네
# 재밌어요
# 아이폰이지
# 역시대인배우리형갓날두
# 힘내세요서로모르고오행산쌓이느니이런속시원한해명글좋네요
# 안녕하세요
# 축하드려요
# 대행님
# 파이팅
# 귀여웠는데
# 야호
# 친구가
# 연한파랑하늘색이아니라슈밤
# 부탁드리겠습니다
# 안녕하세요
# 파이팅
# 사랑합니다
# 안녕하세요
# 축하합니다
# 파이팅이에요
# Happybrithdaytoyou
# 오빠
# 축하드려요
# 아자아자화이팅
# 오빠
# 자랑스러워요
# 오빠
# 오빠
# 빛내줄게
# 화이팅요
# 응원할게
# 만세
# 항상건강이우선이니까컴백준비보다건강관리잘하기D
# 기회다
# 엘지
# 파이팅♡♡♡♡♡
# 멋지다
#
# 재밌음
# 기대됩니다
# 축하해요♡
# 응원합니다
# 도깨비♡♡♡
# 골
# 미쳤닼섭외라니왘앀
# 만세
# 축하합니다
# 대단하다
# 응약쟁이삼고
# 볼때마다폭소만발너무나핵잼
# 존나재밌어
# 축하해요
# 부들부들
# 캬이제욕못하겠네
# 반갑습니다
# 아침부터기분좋다촬영도무사히끝내길화이팅
# 송어축제때도브로맨스좋았는데
# 축제
# 그래도토종이태평양건너미국에서짱먹는다고하니이상하게뿌듯하구만
# 역대급빈집인데1위못하는클라스
# 멌있다
# 고생했지요
# 축하드립니다부럽네욬
# 파이팅
# 헐
# 갓흥민아주찬양해
# 보러갔다가입덕한1인300만축하드려요
# 축하드려요
# 축하해요
# 선생님
# 나이스
# 만세
# 더러운박그네의추악한진실이나오는구나
# 컴백
# 그리고휴대폰선없어서훨씬편해진다
# 파이팅
# 엠비시짱♡♡아
# 귀엽고
# 겁나웃기더라
# 웃긴다
# 달래
# 축하하네
# 우하하하
# 똑같고
# 대단함
#
# 혼자술먹는것꿀잼
# 난파란색빠돌이라이번에중고차살때운좋게파란색걸림아싸
# 맛있음
# 딱보니팬들엌
# 밸런타인데이라서
# 대통령되었으니덕질끝판왕아니겠습니까
# 어제첼시전보다존나재밋다
# 안녕하세요
# 존나빙하고뭐고네새끼굶어죽게내버려둘거임알아서잘하셈존나사랑해
# 안녕하세요
# 자랑스러워요
# 파이팅입니다
# 파이팅
# 축하해요
# 축하드려요
# 파이팅
# 우오아아아그동안콘서트준비들하시느라수고많으셨습니다
# 왕팬이에요
# 잘생겼어요♡♡
# 완전대박축하해요
# 지금은
# 멋져요
# 축하해요
# 오빠
# 파이팅
# 축하해요
# 첫방22프로그램라는데역대급이네냄새가
# 개랑은무조건강등각이네개랑새끼들꼬시다
# 와대박진짜행복했음좋겠어요
# 재밌어
# 좋아요
# 파이팅
# 맞네요
# 대단하다진짜으으으으으으리
# 얘는그냥기계라고봐도됨축구기계인성도좋음머리도좋음안티없음레전드오브레전드인생모토멘토퍼펙트휴먼
# 오랜만이네
# 입학
# 다행
# 잘생겨다
# 밀당보다직진이더매력쩔음
# 와이파이짱짱맨
# 본다
# 어쩌냐개처발렸네
#
# 환영합니다
# 위대했다
# 멋지고앙♡♡♡♡♡♡♡
# 너무좋아했었는데세자저하도존나멋있어
# 축하한다
# 재밌겠다
# 짱짱맨
# 느님이시다
#
# 진짜네요
# 멋있음
# 질문만받으면어버버버울먹어버버버
# 축하드려요
# 축하해요
# 기춘이좆됐네
# 귀요미들
# 재미난다
# 멋있다
# 개이득
# 잘한다
# 잘생겼어
# 잘했네요
# 꼴좋다
# 멋지십니다
# 이뻐죽겠네
# 축하해요
# 역시짱
# 파이팅
# 안녕하세요
#
# 파이팅♡
# 파이팅
# 파이팅
# Wall time: 31.8 s

# %%
sentence['spacing_result'] = pd.DataFrame(spacing_sentence)

# %%
sentence.head()
# Out:
#                                         original  \
# 0                                 오라버니 해피투게더 봤어요
# 1                우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                     웃긴거 알죠~?ㅋㅋ
# 3                        덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4   마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#
#                                             new  \
# 0                                오라버니 해피투게더 봤어요
# 1               우리 모두 LG선수들이 선전할 수 있게 기를 넣어줍시다.
# 2                                    웃긴거 알죠~?ㅋㅋ
# 3                       덕분에 주방에서 요리하는게 엄청 좋아졌어요
# 4  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다ㅎㅎ
#
#                       without_mark  \
# 0                     오라버니해피투게더봤어요
# 1          우리모두LG선수들이선전할수있게기를넣어줍시다
# 2                            웃긴거알죠
# 3              덕분에주방에서요리하는게엄청좋아졌어요
# 4  마지막순간손가락으로총을만들어쏘실때에는제가직접맞는것같습니다
#
#                               hanspell_result  \
# 0                              오라버니 해피투게더 봤어요
# 1             우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다
# 2                                     웃긴 거 알죠
# 3                    덕분에 주방에서 요리하는 게 엄청 좋아졌어요
# 4  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다
#
#                                spacing_result
# 0                              오라버니 해피투게더 봤어요
# 1             우리 모두 LG 선수들이 선전할 수 있게 기를 넣어줍시다
# 2                                     웃긴 거 알죠
# 3                    덕분에 주방에서 요리하는 게 엄청 좋아졌어요
# 4  마지막 순간 손가락으로 총을 만들어 쏘실 때에는 제가 직접 맞는 것 같습니다

# %%
sentence.to_excel('C:/Users/dlrpa/Desktop/one_off_happy_result.xlsx')
